# %% [markdown]
# uncomment if executing in google colab

# %%
# ! pip uninstall pyro-ppl
# ! pip install pyro-ppl==1.5.1
# ! unzip fonts.zip 
# ! unzip claptchagen.zip
# ! unzip csis
# ! cp csis.py /usr/local/lib/python3.7/dist-packages/pyro/infer

# %%
import random
import string
import os
import torch.nn as nn
import torch
import torch.nn.functional as F
import pyro
import numpy as np
import pyro.optim as optim
import pyro.distributions as dist
import pyro.infer
import pyro.optim

from torch.autograd import Variable
from pyro.infer import SVI, Trace_ELBO, TraceGraph_ELBO
from PIL import Image
from claptchagen.claptcha import Claptcha
from torch.distributions import constraints
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from pyro.infer import Predictive
import matplotlib.pyplot as plt
print(pyro.__version__)

captcha_folder = 'generated_captchas'
captchaHeight = 32
captchaWidth = 100
captchaMarginX = 4
captchaMarginY = 4
batch_size = 8

#char_dict = string.ascii_lowercase
char_dict = string.digits
USE_CUDA = True
MAX_N = 2 # maximum number of letters in a captcha 
MIN_N = 1 # minimum number of letters in a captcha
MIN_NOISE = 0.00 # minimum noise
MAX_NOISE = 0.00 # maximum noise
smoke_test = False
num_steps = 1000 if not smoke_test else 10
TrainingSample = 5000 if not smoke_test else 100 # number of captchas generated for training

def randomString():
    """
    return a string with <num_char> random letters
    """
    k = random.randint(MIN_N, MAX_N) # sample number of characters
    
    rndLetters = (random.choice(char_dict) for _ in range(k))
    
    pad_spaces = MAX_N - k # pad the string so the captcha is close to center
    space = " " * (pad_spaces // 2)
    
    return space + "".join(rndLetters) + space

def ramdomNoise():
    """
    return a float between MIN_NOISE, MAX_NOISE
    """
    return random.uniform(MIN_NOISE, MAX_NOISE)

def generate_random_captcha(n, save=False):
    """
    generate n random captchas,
    return a list of texts on the captchas
    """
    # Initialize Claptcha object with random text, FreeMono as font, of size
    # 100x30px, using bicubic resampling filter and adding a bit of white noise
    c = Claptcha(randomString, "fonts/FreeSans.ttf", (captchaWidth, captchaHeight), (captchaMarginX, captchaMarginY),
             resample=Image.BILINEAR, noise=0)
    captcha_generated = [ [] for i in range(MAX_N)]
    for i in range(n):
        c.noise = ramdomNoise()
        if save:
            text, _ = c.write(os.path.join(captcha_folder, 'captcha{}.png'.format(i)))
            os.rename(os.path.join(captcha_folder, 'captcha{}.png'.format(i)),os.path.join(captcha_folder, '{}.png'.format(text + "_" + str(i))))
        text, image = c.image
        text = text.strip()
        image = np.array(image)[:, :, 0] # the generator is gray scale, only keep one channel is enough
        captcha_generated[len(text) - 1].append((text, image, c.noise))
    return captcha_generated
    
captcha_generated = generate_random_captcha(TrainingSample, save=False)
for lst in captcha_generated:
    print("number of samples in group", len(lst))
    # print some sample captcha information generated
    for i, t in enumerate(lst):
        print("text", t[0], "captcha shape", t[1].shape, "noise", t[2])
        if i >= 10:
            break
# Out:
# 1.5.1
# number of samples in group 2471
# text 7 captcha shape (32, 100) noise 0.0
# text 9 captcha shape (32, 100) noise 0.0
# text 8 captcha shape (32, 100) noise 0.0
# text 9 captcha shape (32, 100) noise 0.0
# text 7 captcha shape (32, 100) noise 0.0
# text 4 captcha shape (32, 100) noise 0.0
# text 7 captcha shape (32, 100) noise 0.0
# text 6 captcha shape (32, 100) noise 0.0
# text 7 captcha shape (32, 100) noise 0.0
# text 5 captcha shape (32, 100) noise 0.0
# text 9 captcha shape (32, 100) noise 0.0
# number of samples in group 2529
# text 12 captcha shape (32, 100) noise 0.0
# text 21 captcha shape (32, 100) noise 0.0
# text 46 captcha shape (32, 100) noise 0.0
# text 86 captcha shape (32, 100) noise 0.0
# text 64 captcha shape (32, 100) noise 0.0
# text 43 captcha shape (32, 100) noise 0.0
# text 64 captcha shape (32, 100) noise 0.0
# text 34 captcha shape (32, 100) noise 0.0
# text 65 captcha shape (32, 100) noise 0.0
# text 40 captcha shape (32, 100) noise 0.0
# text 14 captcha shape (32, 100) noise 0.0

# %%
def render_image(chars, fonts="fonts/FreeSans.ttf", size=(captchaWidth, captchaHeight), 
                 margin=(captchaMarginX, captchaMarginY), resample=Image.BILINEAR, noise=0.3, use_cuda=False):
    #noise = noise.data.item()
    #print(chars, noise)
    pad_spaces = MAX_N - len(chars)
    space = " " * (pad_spaces // 2)
    chars = space + chars + space
    render = Claptcha(chars, fonts, size, margin, resample=resample, noise=noise)

    
    _ , rendered_image = render.image
    rendered_image = np.array(rendered_image)[:,:,0] # the generator is gray scale, only keep one channel is enough
    rendered_image = np.subtract(np.divide(rendered_image, 255), 0.5)
    rendered_image = torch.from_numpy(rendered_image)
    if use_cuda:
        rendered_image = rendered_image.cuda()
    return rendered_image

# %%
class CaptchaDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, raw_captchas, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.raw_captchas = raw_captchas
        self.transform = transform

    def __len__(self):
        return len(self.raw_captchas)

    def __getitem__(self, idx):
        label = self.raw_captchas[idx][0]
        image = self.raw_captchas[idx][1]
        noise = self.raw_captchas[idx][2]
        
        image = np.subtract(np.divide(image, 255), 0.5)
        image = torch.from_numpy(image).float()

        if self.transform:
            image = self.transform(image)

        return label, image, noise

# %%
def make_loarders(BATCH_SIZE, raw_samples):
    dataloaders = [] # dataloaders for different num of char
    for lst in raw_samples:
        if lst:
            ds = CaptchaDataset(lst)
            dataloader = DataLoader(ds, batch_size=BATCH_SIZE,
                                    shuffle=True, num_workers=0, drop_last=True)
            dataloaders.append(dataloader)
    return dataloaders

def make_batches(dataloaders):
    all_batches = []
    for dl in dataloaders:
        for i_batch, sample in enumerate(dl):
            all_batches.append(sample)
    random.shuffle(all_batches)
    random.shuffle(all_batches)
    return all_batches

TrainLoaders = make_loarders(BATCH_SIZE=batch_size, raw_samples=captcha_generated)

# %%
class NoiseNet(nn.Module):

    def __init__(self, img_size, out_size = 1):
        """
        Network for learning noise in a captcha
        """
        super(NoiseNet, self).__init__()
        
        self.img_size = img_size
        self.fc0 = nn.Linear(img_size[0] * img_size[1], img_size[0] * img_size[1])
        self.fc1 = nn.Linear(img_size[0] * img_size[1], 1024)

        self.fc21 = nn.Linear(1024, out_size)
        self.fc22 = nn.Linear(1024, out_size)
        self.softplus = nn.Softplus()
    
    def forward(self, img):
        img = img.reshape(-1, self.img_size[0] * self.img_size[1])
        hidden = F.relu(self.fc0(img))
        hidden = self.fc1(hidden)
        # mean of noise, used in normal distribution
        mean =  torch.tanh(self.fc21(F.relu(hidden)))
        # std used in normal distribution
        sigma = self.softplus(self.fc22(F.relu(hidden)))
        return mean, sigma

# %%
class NumNet(nn.Module):
    def __init__(self, img_size, out_size = 3):
        """
        Network for learning N, number of letters in a captcha
        """
        super(NumNet, self).__init__()
        self.neural_net = nn.Sequential(
            nn.Linear(img_size[0] * img_size[1], img_size[0] * img_size[1] * 2),
            nn.ReLU(),
            nn.Linear(img_size[0] * img_size[1] * 2, 256),
            nn.ReLU(),
            nn.Linear(256, out_size),
            nn.LogSoftmax(dim=1))
  
    def forward(self, img):
        img = torch.reshape(img, (img.shape[0], img.shape[1] * img.shape[2]))
        prob = self.neural_net(img)
        return prob

# %%
class CharNetSingle(nn.Module):
    def __init__(self, img_size, output_size, hidden_size=512, N_num_class=10, input_size=1024, num_layers=1):
        """
        Network for letters in a captcha, given the noise and number of letters
        """
        super(CharNetSingle, self).__init__()
        self.img_size = img_size
        self.N_num_class = N_num_class
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.input_size = input_size
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, nonlinearity='relu', dropout=0.2)
        
        # output proposal layers
        self.linear_layers = nn.ModuleList([nn.Linear(hidden_size, output_size) for i in range(N_num_class)])

        #self.dropout = nn.Dropout()
        
        # observe layers
        self.conv1 = nn.Conv2d(1, 32, 3)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.pfc1 = nn.Linear(8832, 2048)
        self.pfc2 = nn.Linear(2048, 1024)
        self.convBN1 = nn.BatchNorm2d(32)
        self.convBN2 = nn.BatchNorm2d(64)
        self.h_0 = nn.Parameter(torch.zeros(self.num_layers, 1, self.hidden_size))
        #self.c_0 = nn.Parameter(torch.zeros(self.num_layers, 1, self.hidden_size)) # define if use LSTM

    def forward(self, img, N, noise_batched):
        BATCH_SIZE = img.shape[0]
        i = torch.arange(0, int(N))
        if USE_CUDA:
            i = i.cuda()
        i_onehot = F.one_hot(i, num_classes=self.N_num_class).float() # one hot format of N and index of letter
        i_onehot = torch.reshape(i_onehot, (N, 1, self.N_num_class)).repeat(1, BATCH_SIZE, 1)
        N_onehot = F.one_hot(N-1, num_classes=self.N_num_class).repeat(N, BATCH_SIZE, 1).float()
        
        # observe layers
        img = torch.reshape(img, (BATCH_SIZE, 1, self.img_size[0], self.img_size[1]))

        img = self.pool(F.relu(self.convBN1(self.conv1(img))))
        img = self.pool(F.relu(self.convBN2(self.conv2(img))))
        
        img = torch.reshape(img, (BATCH_SIZE, 8832))

        img = F.relu(self.pfc1(img))
        
        img = F.relu(self.pfc2(img))
        
        img = torch.reshape(img, (1, BATCH_SIZE, 1024))
        
        img = img.repeat(N, 1, 1)
        
        # cat observed images, N, i and noise 
        noise_batched = noise_batched.repeat(N, 1, 1)

        x = torch.cat((img, N_onehot, i_onehot, noise_batched), dim=2)
        x = torch.reshape(x, (N, BATCH_SIZE, self.input_size))

        h_0_contig = self.h_0.expand(self.num_layers, BATCH_SIZE, self.hidden_size).contiguous()

        outputs, hn = self.rnn(x, h_0_contig)
        
        # probosal layer, map to output shape
        outputs = torch.stack([self.linear_layers[i](outputs[i]) for i in range(outputs.shape[0])])

        outputs = F.log_softmax(outputs, dim=2)
        
        # transpose to <Batch, Length of Sequence, Character Space>
        outputs = torch.transpose(outputs, 0, 1)
        
        return outputs

# %%
def inference(t, use_cuda=False):
    """
    one epoch of inference (iterate the training set once)
    """
    loss = 0
    length = TrainingSample
    loss_group = []
    all_batches = make_batches(TrainLoaders)
    for i_batch, sample_batched in enumerate(all_batches):
        
        img = sample_batched[1]
        if use_cuda:
            img = img.cuda()
        IMG = {"captcha" : img}
        imme_loss = svi.step(observations=IMG)
        loss += imme_loss / length

    print("loss at epoch {} is {}".format(t, loss))
    return loss

# %%
def test_old(n = 0, use_train=False, verbose=False, use_cuda=False):
    """
    benchmarking performance on customized or training set
    """
    if use_train:
        TestLoaders = make_loarders(BATCH_SIZE=1, raw_samples=captcha_generated)
    else:
        test_captcha_generated = generate_random_captcha(n, save=False)
        TestLoaders = make_loarders(BATCH_SIZE=1, raw_samples=test_captcha_generated)
    
    total_correct = 0
    char_correct = 0
    total_char = 0
    all_batches = make_batches(TestLoaders)
    for i_batch, t in enumerate(all_batches):

        label = t[0][0]
        gt_noise = t[2][0]
        img = t[1]

        if use_cuda:
            img = img.cuda()
        
        IMG = {"captcha" : img}
        
        num_p = captchaModel.numNet(img)
        N = dist.Categorical(num_p[0]).sample()
        N = torch.add(N, captchaModel.num_char_domain[0])
        #sig = torch.tensor(0.0001)
        #h0 = dist.Normal(N_predicted/max(captchaModel.num_char_domain), sig).sample(torch.Size((len(captchaModel.char_dict) * captchaModel.rnn_num_layer,)))
        noise_mean, noise_sig = captchaModel.noiseNet(img)
        noise = dist.Normal(noise_mean, noise_sig).sample()
        noise = captchaModel._map_to_noise_range(noise)
        
        charP = captchaModel.charNetSingle(img, N, noise)
        
        charP = charP[0]
        if use_cuda:
            charP.cpu()
        
        chars = ""
        for i in range(N):
            cp = charP[i]
            c_index = int(dist.Categorical(cp).sample())
            chars += captchaModel.char_dict[c_index]
        correct = 0
        
        for p_char, t_char in zip(chars, label):
            if p_char == t_char:
                correct += 1
        if not verbose:
            print("N_predicted:", int(N), "| Actual N:", len(label), "| Predicted Noise:", round(float(noise), 3), "| Actual Noise:", round(float(gt_noise), 3), "| Predicted Text:", chars, "| Actual Text:", label, "| Correct:", correct)
        if correct == len(label) and int(N) == len(label):
            total_correct += 1
        char_correct += correct
        total_char += len(label)
    num_test_samples = i_batch + 1
    accuracy = total_correct / num_test_samples
    char_accuracy = char_correct / total_char
    print("use_train =", use_train, "Total correct:", total_correct, "accuracy:{}/{}=".format(total_correct, num_test_samples), accuracy, "char_accuracy:{}/{}=".format(char_correct, total_char), char_accuracy)

# %%
def test(n = 0, use_train=False, verbose=False, use_cuda=False):
    """
    benchmarking performance on customized or training set
    """
    if use_train:
        TestLoaders = make_loarders(BATCH_SIZE=1, raw_samples=captcha_generated)
    else:
        test_captcha_generated = generate_random_captcha(n, save=False)
        TestLoaders = make_loarders(BATCH_SIZE=1, raw_samples=test_captcha_generated)
    
    total_correct = 0
    char_correct = 0
    total_char = 0
    all_batches = make_batches(TestLoaders)
    for i_batch, t in enumerate(all_batches):

        label = t[0][0]
        gt_noise = t[2][0]
        img = t[1]

        if use_cuda:
            img = img.cuda()
        
        IMG = {"captcha" : img}
        #print("label", label, end=" ")

        # get returned sampling from posterior 
        with torch.no_grad():

          posterior_sample = Predictive(captchaModel.model, guide=captchaModel.guide, num_samples=1)(IMG)
          #print(posterior_sample)
          N = torch.squeeze(posterior_sample["num_char"]) + captchaModel.num_char_domain[0]
          noise = captchaModel._map_to_noise_range(torch.squeeze(posterior_sample["noise"]))
          char_indices = posterior_sample["chars"][0][0]
          #print(noise,char_indices)
        if use_cuda:
            char_indices.cpu()
        chars = ""
        for i in range(len(char_indices)):
            c = char_indices[i]
            chars +=  captchaModel.char_dict[c]
        correct = 0
        
        for p_char, t_char in zip(chars, label):
            if p_char == t_char:
                correct += 1
        if not verbose:
            print("N_predicted:", int(N), "| Actual N:", len(label), "| Predicted Noise:", round(float(noise), 3), "| Actual Noise:", round(float(gt_noise), 3), "| Predicted Text:", chars, "| Actual Text:", label, "| Correct:", correct)
        if correct == len(label) and int(N) == len(label):
            total_correct += 1
        char_correct += correct
        total_char += len(label)
    num_test_samples = i_batch + 1
    accuracy = total_correct / num_test_samples
    char_accuracy = char_correct / total_char
    print("use_train =", use_train, "Total correct:", total_correct, "accuracy:{}/{}=".format(total_correct, num_test_samples), accuracy, "char_accuracy:{}/{}=".format(char_correct, total_char), char_accuracy)

# %%
def test_cycle(use_cuda):
    
    # disable dropout
    #captchaModel.numNet.eval()
    #captchaModel.charNetSingle.eval()
    test(use_train=True, verbose=True, use_cuda=use_cuda)
    test(1000, use_train=False, verbose=True, use_cuda=use_cuda)
    #test(10, use_train=True, verbose=False, use_cuda=use_cuda)
    test(10, use_train=False, verbose=False, use_cuda=use_cuda)
    # enable dropout
    #captchaModel.numNet.train()
    #captchaModel.charNetSingle.train()

def optimize(use_cuda=False):
    """
    Training/Inferencing Stage
    """
    loss_sequence = []
    pause = 5
    print("Optimizing...")
    for t in range(1, num_steps + 1):
        L = inference(t, use_cuda)
        loss_sequence.append(L)
        if (t % pause == 0) and (t > 0):
            test_cycle(use_cuda=use_cuda)
    plt.plot(loss_sequence)
    plt.title("loss")
    plt.show()

# %%
class CaptchaModel(nn.Module):
    """
    network, model and guide wrapper class
    """
    def __init__(self, use_cuda=False):
        super().__init__()
        self.num_char_domain = torch.arange(MIN_N, MAX_N + 1)
        if use_cuda:
            self.num_char_domain = self.num_char_domain.cuda()

        self.numNet = NumNet((captchaHeight, captchaWidth), len(self.num_char_domain))
        self.noiseNet = NoiseNet((captchaHeight, captchaWidth), 1)
        self.char_dict = char_dict # letter dictionary
        self.rnn_hidden_size = 512
        self.rnn_num_layer = 2
        self.charNetSingle = CharNetSingle((captchaHeight, captchaWidth), len(self.char_dict), N_num_class=max(self.num_char_domain), input_size=1024 + max(self.num_char_domain) * 2 + 1, hidden_size=self.rnn_hidden_size, num_layers=self.rnn_num_layer)
        self.noise_constraint = torch.distributions.constraints.interval(MIN_NOISE, MAX_NOISE)
        if use_cuda:
            self.cuda()
        self.use_cuda = use_cuda
    
    def _map_to_noise_range(self, input):
        """
        map input number to the valid noise range
        """
        input = torch.distributions.transform_to(self.noise_constraint)(input)
        return input

    def guide(self, observations={"captcha": torch.rand(1, captchaHeight, captchaWidth)}):
        pyro.module("guide", self)
        img = observations["captcha"].float()
        
        # posterior to the number of letters
        prob = self.numNet(img)
        prob = torch.mean(prob, dim=0)
        N_index = pyro.sample("num_char", dist.Categorical(prob))
        N_index = torch.add(N_index, self.num_char_domain[0])
        
        with pyro.plate("data", img.shape[0]):
            
            # posterior to the noise
            noise_mean, noise_sig = self.noiseNet(img)
            noise_batch = pyro.sample("noise", dist.Normal(noise_mean, noise_sig).to_event(1))
            noise_batch = self._map_to_noise_range(noise_batch)
            
            # posterior to the characters, given number of letters and noise
            charP = self.charNetSingle(img, N_index, noise_batch)
            pyro.sample("chars", dist.Categorical(charP).to_event(1))
    
    def model(self, observations={"captcha": torch.rand(1, captchaHeight, captchaWidth)}):
        
        BS = observations["captcha"].shape[0]
        
        num_p = torch.tensor(1 / len(self.num_char_domain)).repeat(len(self.num_char_domain))
        
        if self.use_cuda:
            num_p = num_p.cuda()
        
        # sample the number of characters
        N_index = pyro.sample("num_char", dist.Categorical(num_p))
        N_index = torch.add(N_index,  self.num_char_domain[0])
        
        with pyro.plate("data", BS):
            
            noise_mean = torch.tensor((MAX_NOISE - MIN_NOISE) / 2).repeat((BS, 1))
            noise_sig = torch.tensor(0.5).repeat((BS, 1))

            if self.use_cuda:
                noise_mean = noise_mean.cuda()
                noise_sig = noise_sig.cuda()

            # sample the noise
            noise_batch = pyro.sample("noise", dist.Normal(noise_mean, noise_sig).to_event(1))
            noise_batch = self._map_to_noise_range(noise_batch)

            num_c = torch.tensor(1 / len(self.char_dict)).repeat((BS, N_index, len(self.char_dict)))
            if self.use_cuda:
                    num_c = num_c.cuda()
                    
            # sample the character indices
            c = pyro.sample("chars", dist.Categorical(num_c).to_event(1)) # maybe 2 here
            rendered_images = []
            for i in range(c.shape[0]):
                chars = ""
                for j in range(N_index):
                    chars += self.char_dict[c[i][j]]
        
                rendered_image = render_image(chars, noise=float(noise_batch[i]), use_cuda=self.use_cuda)
                rendered_images.append(rendered_image)
                
        rendered_images = torch.stack(rendered_images)
        sigma = torch.tensor(0.000001)
        if self.use_cuda:
                sigma = sigma.cuda()

        pyro.sample("captcha", dist.Normal(rendered_images, sigma).to_event(2), obs=observations["captcha"])

captchaModel = CaptchaModel(USE_CUDA)

optimiser = pyro.optim.Adam({'lr': 2e-5})
svi = SVI(captchaModel.model, captchaModel.guide, optimiser, loss=Trace_ELBO())
#csis = pyro.infer.CSIS(captchaModel.model, captchaModel.guide, optimiser, num_inference_samples=1)


optimize(USE_CUDA)
test_cycle(USE_CUDA)
# Out:
# Optimizing...
# loss at epoch 1 is 186140810127940.47
# loss at epoch 2 is 157587544101030.88
# loss at epoch 3 is 146218650866592.56
# loss at epoch 4 is 128266317079634.66
# loss at epoch 5 is 120712649873813.75
# use_train = True Total correct: 517 accuracy:517/5000= 0.1034 char_accuracy:1138/7529= 0.1511488909549741
# use_train = False Total correct: 111 accuracy:111/1000= 0.111 char_accuracy:230/1480= 0.1554054054054054
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 65 | Actual Text: 28 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 0 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 8 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 36 | Actual Text: 08 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 59 | Actual Text: 31 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 38 | Actual Text: 60 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 7 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 49 | Actual Text: 93 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 3 | Actual Text: 6 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 7 | Actual Text: 4 | Correct: 0
# use_train = False Total correct: 0 accuracy:0/10= 0.0 char_accuracy:0/15= 0.0
# loss at epoch 6 is 114778326050780.31
# loss at epoch 7 is 115977839145387.77
# loss at epoch 8 is 112150757047314.28
# loss at epoch 9 is 138965204465557.44
# loss at epoch 10 is 109132070056623.5
# use_train = True Total correct: 583 accuracy:583/5000= 0.1166 char_accuracy:1259/7529= 0.16722008234825342
# use_train = False Total correct: 114 accuracy:114/1000= 0.114 char_accuracy:237/1490= 0.15906040268456376
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 83 | Actual Text: 51 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 06 | Actual Text: 96 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 28 | Actual Text: 33 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 5 | Actual Text: 9 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 73 | Actual Text: 13 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 35 | Actual Text: 97 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 46 | Actual Text: 46 | Correct: 2
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 36 | Actual Text: 63 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 83 | Actual Text: 61 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 3 | Actual Text: 5 | Correct: 0
# use_train = False Total correct: 1 accuracy:1/10= 0.1 char_accuracy:4/18= 0.2222222222222222
# loss at epoch 11 is 107975299953443.47
# loss at epoch 12 is 107649857319718.53
# loss at epoch 13 is 109360395822260.4
# loss at epoch 14 is 104926143777622.08
# loss at epoch 15 is 104968359493860.58
# use_train = True Total correct: 640 accuracy:640/5000= 0.128 char_accuracy:1363/7529= 0.18103333776065877
# use_train = False Total correct: 132 accuracy:132/1000= 0.132 char_accuracy:287/1503= 0.19095143047238855
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 62 | Actual Text: 93 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 78 | Actual Text: 73 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 5 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 93 | Actual Text: 61 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 9 | Actual Text: 0 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 8 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 98 | Actual Text: 94 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 90 | Actual Text: 58 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 08 | Actual Text: 95 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 01 | Actual Text: 21 | Correct: 1
# use_train = False Total correct: 0 accuracy:0/10= 0.0 char_accuracy:3/17= 0.17647058823529413
# loss at epoch 16 is 102105218188845.97
# loss at epoch 17 is 99311925289896.92
# loss at epoch 18 is 98361703095011.1
# loss at epoch 19 is 112463099687492.55
# loss at epoch 20 is 134897438041153.03
# use_train = True Total correct: 620 accuracy:620/5000= 0.124 char_accuracy:1585/7529= 0.21051932527560102
# use_train = False Total correct: 124 accuracy:124/1000= 0.124 char_accuracy:310/1512= 0.20502645502645503
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 33 | Actual Text: 30 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 9 | Actual Text: 9 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 03 | Actual Text: 26 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 97 | Actual Text: 64 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 73 | Actual Text: 10 | Correct: 0
# N_predicted: 2 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 13 | Actual Text: 1 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 63 | Actual Text: 36 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 33 | Actual Text: 27 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 5 | Actual Text: 8 | Correct: 0
# use_train = False Total correct: 2 accuracy:2/10= 0.2 char_accuracy:4/16= 0.25
# loss at epoch 21 is 98941806840357.73
# loss at epoch 22 is 91469285593897.31
# loss at epoch 23 is 92707697751672.56
# loss at epoch 24 is 91832704582310.98
# loss at epoch 25 is 89909717234199.9
# use_train = True Total correct: 889 accuracy:889/5000= 0.1778 char_accuracy:1881/7529= 0.24983397529552398
# use_train = False Total correct: 167 accuracy:167/1000= 0.167 char_accuracy:376/1495= 0.25150501672240805
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 3 | Actual Text: 9 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 7 | Actual Text: 7 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 9 | Actual Text: 8 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 07 | Actual Text: 63 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 38 | Actual Text: 50 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 63 | Actual Text: 92 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 34 | Actual Text: 68 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 27 | Actual Text: 21 | Correct: 1
# use_train = False Total correct: 3 accuracy:3/10= 0.3 char_accuracy:4/15= 0.26666666666666666
# loss at epoch 26 is 87938436556805.89
# loss at epoch 27 is 90189584445635.75
# loss at epoch 28 is 85805967718037.56
# loss at epoch 29 is 85993465734650.89
# loss at epoch 30 is 84250048902686.03
# use_train = True Total correct: 989 accuracy:989/5000= 0.1978 char_accuracy:2118/7529= 0.2813122592641785
# use_train = False Total correct: 188 accuracy:188/1000= 0.188 char_accuracy:404/1498= 0.2696929238985314
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 58 | Actual Text: 02 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 9 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 5 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 8 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 7 | Actual Text: 7 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 3 | Actual Text: 5 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 9 | Actual Text: 0 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 7 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 36 | Actual Text: 88 | Correct: 0
# use_train = False Total correct: 2 accuracy:2/10= 0.2 char_accuracy:2/12= 0.16666666666666666
# loss at epoch 31 is 81911324304461.2
# loss at epoch 32 is 81545122666143.94
# loss at epoch 33 is 81054318541974.47
# loss at epoch 34 is 80813022181019.53
# loss at epoch 35 is 78861483259187.97
# use_train = True Total correct: 962 accuracy:962/5000= 0.1924 char_accuracy:2057/7529= 0.2732102536857484
# use_train = False Total correct: 197 accuracy:197/1000= 0.197 char_accuracy:427/1513= 0.2822207534699273
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 89 | Actual Text: 59 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 64 | Actual Text: 04 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 3 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 48 | Actual Text: 40 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 7 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 21 | Actual Text: 27 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 81 | Actual Text: 31 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 0 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 53 | Actual Text: 05 | Correct: 0
# use_train = False Total correct: 1 accuracy:1/10= 0.1 char_accuracy:6/16= 0.375
# loss at epoch 36 is 79635443820299.6
# loss at epoch 37 is 80852352954217.66
# loss at epoch 38 is 77507996601990.77
# loss at epoch 39 is 78169406562496.06
# loss at epoch 40 is 76793861900535.86
# use_train = True Total correct: 1187 accuracy:1187/5000= 0.2374 char_accuracy:2429/7529= 0.3226192057378138
# use_train = False Total correct: 243 accuracy:243/1000= 0.243 char_accuracy:461/1485= 0.31043771043771046
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 59 | Actual Text: 86 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 40 | Actual Text: 48 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 48 | Actual Text: 97 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 6 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 69 | Actual Text: 86 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 33 | Actual Text: 27 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 3 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 5 | Correct: 0
# use_train = False Total correct: 2 accuracy:2/10= 0.2 char_accuracy:3/15= 0.2
# loss at epoch 41 is 75437353193856.88
# loss at epoch 42 is 73985814987740.61
# loss at epoch 43 is 74857254490154.5
# loss at epoch 44 is 72407671319765.02
# loss at epoch 45 is 72542326026029.34
# use_train = True Total correct: 1222 accuracy:1222/5000= 0.2444 char_accuracy:2570/7529= 0.34134679240270954
# use_train = False Total correct: 226 accuracy:226/1000= 0.226 char_accuracy:477/1513= 0.3152676801057502
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 81 | Actual Text: 67 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 80 | Actual Text: 30 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 66 | Actual Text: 38 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 36 | Actual Text: 38 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 78 | Actual Text: 79 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 83 | Actual Text: 86 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 6 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 3 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# use_train = False Total correct: 3 accuracy:3/10= 0.3 char_accuracy:7/16= 0.4375
# loss at epoch 46 is 69680766078055.57
# loss at epoch 47 is 70275280853188.43
# loss at epoch 48 is 69295458246157.766
# loss at epoch 49 is 67607375325539.45
# loss at epoch 50 is 68511654008782.06
# use_train = True Total correct: 1319 accuracy:1319/5000= 0.2638 char_accuracy:2707/7529= 0.359543100013282
# use_train = False Total correct: 261 accuracy:261/1000= 0.261 char_accuracy:531/1516= 0.3502638522427441
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 68 | Actual Text: 09 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 8 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 6 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 24 | Actual Text: 24 | Correct: 2
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 5 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 63 | Actual Text: 90 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 91 | Actual Text: 07 | Correct: 0
# use_train = False Total correct: 5 accuracy:5/10= 0.5 char_accuracy:6/14= 0.42857142857142855
# loss at epoch 51 is 68321223802524.39
# loss at epoch 52 is 68364427758454.125
# loss at epoch 53 is 65752969571539.12
# loss at epoch 54 is 67209205522360.27
# loss at epoch 55 is 67123190536568.516
# use_train = True Total correct: 1331 accuracy:1331/5000= 0.2662 char_accuracy:2678/7529= 0.35569132686943816
# use_train = False Total correct: 265 accuracy:265/1000= 0.265 char_accuracy:526/1485= 0.3542087542087542
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 5 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 6 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 16 | Actual Text: 16 | Correct: 2
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 64 | Actual Text: 81 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 68 | Actual Text: 82 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 3 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 3 | Actual Text: 0 | Correct: 0
# use_train = False Total correct: 4 accuracy:4/10= 0.4 char_accuracy:5/13= 0.38461538461538464
# loss at epoch 56 is 67961159342447.25
# loss at epoch 57 is 66572013952104.48
# loss at epoch 58 is 68367643817612.516
# loss at epoch 59 is 66706811443772.484
# loss at epoch 60 is 67104164111152.664
# use_train = True Total correct: 1309 accuracy:1309/5000= 0.2618 char_accuracy:2714/7529= 0.3604728383583477
# use_train = False Total correct: 250 accuracy:250/1000= 0.25 char_accuracy:522/1495= 0.3491638795986622
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 89 | Actual Text: 39 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 60 | Actual Text: 80 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 9 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 8 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 9 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 7 | Actual Text: 7 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 3 | Actual Text: 2 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 81 | Actual Text: 84 | Correct: 1
# use_train = False Total correct: 4 accuracy:4/10= 0.4 char_accuracy:7/13= 0.5384615384615384
# loss at epoch 61 is 66385623889281.445
# loss at epoch 62 is 64555101911464.54
# loss at epoch 63 is 65556023182929.63
# loss at epoch 64 is 65920197244980.83
# loss at epoch 65 is 65052422055244.0
# use_train = True Total correct: 1353 accuracy:1353/5000= 0.2706 char_accuracy:2750/7529= 0.3652543498472573
# use_train = False Total correct: 286 accuracy:286/1000= 0.286 char_accuracy:531/1488= 0.35685483870967744
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 60 | Actual Text: 58 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 29 | Actual Text: 26 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 11 | Actual Text: 11 | Correct: 2
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 41 | Actual Text: 44 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 6 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 5 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 0 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 63 | Actual Text: 55 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 5 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# use_train = False Total correct: 2 accuracy:2/10= 0.2 char_accuracy:5/15= 0.3333333333333333
# loss at epoch 66 is 64751988362888.65
# loss at epoch 67 is 64602720896454.48
# loss at epoch 68 is 63819814535919.055
# loss at epoch 69 is 64186023933918.555
# loss at epoch 70 is 63002616772847.33
# use_train = True Total correct: 1343 accuracy:1343/5000= 0.2686 char_accuracy:2754/7529= 0.36578562890158056
# use_train = False Total correct: 295 accuracy:295/1000= 0.295 char_accuracy:539/1462= 0.3686730506155951
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 49 | Actual Text: 44 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 0 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 63 | Actual Text: 83 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 40 | Actual Text: 42 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 61 | Actual Text: 91 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 88 | Actual Text: 62 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 3 | Actual Text: 3 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 8 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 63 | Actual Text: 30 | Correct: 0
# use_train = False Total correct: 2 accuracy:2/10= 0.2 char_accuracy:6/16= 0.375
# loss at epoch 71 is 63726109659713.28
# loss at epoch 72 is 64048646391167.766
# loss at epoch 73 is 63172163203166.92
# loss at epoch 74 is 63691475290977.82
# loss at epoch 75 is 62466413165594.62
# use_train = True Total correct: 1339 accuracy:1339/5000= 0.2678 char_accuracy:2770/7529= 0.36791074511887367
# use_train = False Total correct: 282 accuracy:282/1000= 0.282 char_accuracy:565/1506= 0.3751660026560425
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 11 | Actual Text: 17 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 6 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 81 | Actual Text: 34 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 38 | Actual Text: 89 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 7 | Actual Text: 7 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 3 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 03 | Actual Text: 80 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 3 | Correct: 0
# use_train = False Total correct: 4 accuracy:4/10= 0.4 char_accuracy:5/14= 0.35714285714285715
# loss at epoch 76 is 62500123395547.83
# loss at epoch 77 is 63839765158711.695
# loss at epoch 78 is 62433461477084.33
# loss at epoch 79 is 63087613311743.48
# loss at epoch 80 is 62473234921725.164
# use_train = True Total correct: 1365 accuracy:1365/5000= 0.273 char_accuracy:2786/7529= 0.37003586133616684
# use_train = False Total correct: 280 accuracy:280/1000= 0.28 char_accuracy:564/1503= 0.37524950099800397
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 26 | Actual Text: 38 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 53 | Actual Text: 66 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 8 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 3 | Actual Text: 5 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 0 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 86 | Actual Text: 92 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 0 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 94 | Actual Text: 04 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# use_train = False Total correct: 2 accuracy:2/10= 0.2 char_accuracy:3/14= 0.21428571428571427
# loss at epoch 81 is 62228973134135.42
# loss at epoch 82 is 62007314013585.87
# loss at epoch 83 is 64383544523900.234
# loss at epoch 84 is 63620578992500.73
# loss at epoch 85 is 62837330361395.72
# use_train = True Total correct: 1405 accuracy:1405/5000= 0.281 char_accuracy:2871/7529= 0.3813255412405366
# use_train = False Total correct: 270 accuracy:270/1000= 0.27 char_accuracy:562/1504= 0.37367021276595747
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 81 | Actual Text: 04 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 56 | Actual Text: 76 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 3 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 13 | Actual Text: 10 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 6 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 5 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 6 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 28 | Actual Text: 29 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# use_train = False Total correct: 3 accuracy:3/10= 0.3 char_accuracy:6/14= 0.42857142857142855
# loss at epoch 86 is 60780426924957.39
# loss at epoch 87 is 62817696027826.484
# loss at epoch 88 is 62278072243477.445
# loss at epoch 89 is 61285732603561.01
# loss at epoch 90 is 61278379854012.7
# use_train = True Total correct: 1399 accuracy:1399/5000= 0.2798 char_accuracy:2835/7529= 0.37654402975162704
# use_train = False Total correct: 274 accuracy:274/1000= 0.274 char_accuracy:540/1494= 0.3614457831325301
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 86 | Actual Text: 50 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 68 | Actual Text: 08 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 3 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 94 | Actual Text: 57 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 66 | Actual Text: 62 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 6 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 3 | Actual Text: 6 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 83 | Actual Text: 59 | Correct: 0
# use_train = False Total correct: 3 accuracy:3/10= 0.3 char_accuracy:5/15= 0.3333333333333333
# loss at epoch 91 is 60762494405182.55
# loss at epoch 92 is 60545160480810.06
# loss at epoch 93 is 62656256745504.805
# loss at epoch 94 is 60046508620087.99
# loss at epoch 95 is 62671773444268.98
# use_train = True Total correct: 1442 accuracy:1442/5000= 0.2884 char_accuracy:2891/7529= 0.383981936512153
# use_train = False Total correct: 279 accuracy:279/1000= 0.279 char_accuracy:574/1503= 0.3819028609447771
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 68 | Actual Text: 09 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 3 | Actual Text: 3 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 28 | Actual Text: 29 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 3 | Actual Text: 2 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 66 | Actual Text: 80 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 6 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 41 | Actual Text: 44 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 75 | Actual Text: 79 | Correct: 1
# use_train = False Total correct: 4 accuracy:4/10= 0.4 char_accuracy:7/15= 0.4666666666666667
# loss at epoch 96 is 59805814888716.38
# loss at epoch 97 is 61585758768984.08
# loss at epoch 98 is 60770885846353.92
# loss at epoch 99 is 60391588218271.555
# loss at epoch 100 is 60556988114180.61
# use_train = True Total correct: 1422 accuracy:1422/5000= 0.2844 char_accuracy:2866/7529= 0.3806614424226325
# use_train = False Total correct: 294 accuracy:294/1000= 0.294 char_accuracy:582/1491= 0.3903420523138833
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 46 | Actual Text: 46 | Correct: 2
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 8 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 8 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 48 | Actual Text: 40 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 8 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 31 | Actual Text: 64 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 3 | Correct: 0
# use_train = False Total correct: 4 accuracy:4/10= 0.4 char_accuracy:6/13= 0.46153846153846156
# loss at epoch 101 is 60855088090457.51
# loss at epoch 102 is 60883094426841.14
# loss at epoch 103 is 58506877943237.42
# loss at epoch 104 is 59002946153996.53
# loss at epoch 105 is 59847133007657.734
# use_train = True Total correct: 1412 accuracy:1412/5000= 0.2824 char_accuracy:2831/7529= 0.3760127506973038
# use_train = False Total correct: 303 accuracy:303/1000= 0.303 char_accuracy:592/1492= 0.3967828418230563
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 81 | Actual Text: 61 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 86 | Actual Text: 68 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 6 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 64 | Actual Text: 94 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 73 | Actual Text: 78 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 88 | Actual Text: 82 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 87 | Actual Text: 87 | Correct: 2
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 31 | Actual Text: 57 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 61 | Actual Text: 54 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 5 | Correct: 0
# use_train = False Total correct: 2 accuracy:2/10= 0.2 char_accuracy:7/18= 0.3888888888888889
# loss at epoch 106 is 59146960524039.85
# loss at epoch 107 is 59088674755176.11
# loss at epoch 108 is 58766329304162.09
# loss at epoch 109 is 59246717169754.22
# loss at epoch 110 is 60012368896272.04
# use_train = True Total correct: 1440 accuracy:1440/5000= 0.288 char_accuracy:2873/7529= 0.3815911807676982
# use_train = False Total correct: 257 accuracy:257/1000= 0.257 char_accuracy:539/1493= 0.3610180843938379
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 3 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 66 | Actual Text: 80 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 6 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 3 | Actual Text: 9 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 84 | Actual Text: 64 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 68 | Actual Text: 85 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 48 | Actual Text: 43 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 88 | Actual Text: 90 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 29 | Actual Text: 20 | Correct: 1
# use_train = False Total correct: 2 accuracy:2/10= 0.2 char_accuracy:5/16= 0.3125
# loss at epoch 111 is 58830091885386.65
# loss at epoch 112 is 59701187132602.83
# loss at epoch 113 is 59948379167837.64
# loss at epoch 114 is 58770324658601.984
# loss at epoch 115 is 59212084312500.305
# use_train = True Total correct: 1460 accuracy:1460/5000= 0.292 char_accuracy:2951/7529= 0.39195112232700224
# use_train = False Total correct: 308 accuracy:308/1000= 0.308 char_accuracy:576/1480= 0.3891891891891892
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 78 | Actual Text: 49 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 8 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 00 | Actual Text: 51 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 63 | Actual Text: 38 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 28 | Actual Text: 28 | Correct: 2
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 86 | Actual Text: 96 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 88 | Actual Text: 30 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 3 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 3 | Actual Text: 3 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 68 | Actual Text: 80 | Correct: 0
# use_train = False Total correct: 2 accuracy:2/10= 0.2 char_accuracy:4/17= 0.23529411764705882
# loss at epoch 116 is 58548894102725.13
# loss at epoch 117 is 57873098308665.914
# loss at epoch 118 is 58565416794792.44
# loss at epoch 119 is 57748168687570.945
# loss at epoch 120 is 58393310873760.62
# use_train = True Total correct: 1477 accuracy:1477/5000= 0.2954 char_accuracy:2958/7529= 0.392880860672068
# use_train = False Total correct: 308 accuracy:308/1000= 0.308 char_accuracy:590/1475= 0.4
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 13 | Actual Text: 18 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 9 | Actual Text: 9 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 5 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 83 | Actual Text: 89 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 84 | Actual Text: 82 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 10 | Actual Text: 13 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 5 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 61 | Actual Text: 81 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 9 | Actual Text: 9 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 88 | Actual Text: 67 | Correct: 0
# use_train = False Total correct: 2 accuracy:2/10= 0.2 char_accuracy:7/16= 0.4375
# loss at epoch 121 is 58033882665084.14
# loss at epoch 122 is 57960058623357.555
# loss at epoch 123 is 57846497044859.055
# loss at epoch 124 is 58615510959114.03
# loss at epoch 125 is 58485905611694.98
# use_train = True Total correct: 1473 accuracy:1473/5000= 0.2946 char_accuracy:2927/7529= 0.38876344800106255
# use_train = False Total correct: 283 accuracy:283/1000= 0.283 char_accuracy:597/1525= 0.39147540983606555
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 5 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 0 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 48 | Actual Text: 42 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 13 | Actual Text: 10 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 7 | Actual Text: 7 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 6 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 60 | Actual Text: 85 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 9 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 61 | Actual Text: 34 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 23 | Actual Text: 97 | Correct: 0
# use_train = False Total correct: 2 accuracy:2/10= 0.2 char_accuracy:4/15= 0.26666666666666666
# loss at epoch 126 is 57586311633559.62
# loss at epoch 127 is 57359248198587.95
# loss at epoch 128 is 57195115636803.836
# loss at epoch 129 is 57336153054007.625
# loss at epoch 130 is 57471592148104.914
# use_train = True Total correct: 1490 accuracy:1490/5000= 0.298 char_accuracy:2972/7529= 0.3947403373621995
# use_train = False Total correct: 328 accuracy:328/1000= 0.328 char_accuracy:645/1507= 0.42800265428002654
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 3 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 3 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 9 | Actual Text: 9 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 7 | Actual Text: 7 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 28 | Actual Text: 24 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 43 | Actual Text: 48 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 9 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# use_train = False Total correct: 5 accuracy:5/10= 0.5 char_accuracy:7/12= 0.5833333333333334
# loss at epoch 131 is 57835321007189.67
# loss at epoch 132 is 57008749750080.2
# loss at epoch 133 is 56793334516686.836
# loss at epoch 134 is 56504268229131.31
# loss at epoch 135 is 56140638695288.445
# use_train = True Total correct: 1560 accuracy:1560/5000= 0.312 char_accuracy:3046/7529= 0.40456899986718026
# use_train = False Total correct: 307 accuracy:307/1000= 0.307 char_accuracy:590/1490= 0.3959731543624161
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 61 | Actual Text: 01 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 28 | Actual Text: 29 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 33 | Actual Text: 05 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 7 | Actual Text: 7 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 9 | Actual Text: 9 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 8 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 28 | Actual Text: 23 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 67 | Actual Text: 51 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 66 | Actual Text: 83 | Correct: 0
# use_train = False Total correct: 4 accuracy:4/10= 0.4 char_accuracy:7/16= 0.4375
# loss at epoch 136 is 57398957757527.47
# loss at epoch 137 is 55823307137691.055
# loss at epoch 138 is 55964915885409.87
# loss at epoch 139 is 56366988569868.37
# loss at epoch 140 is 55517516950066.83
# use_train = True Total correct: 1560 accuracy:1560/5000= 0.312 char_accuracy:3059/7529= 0.4062956567937309
# use_train = False Total correct: 332 accuracy:332/1000= 0.332 char_accuracy:638/1496= 0.4264705882352941
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 7 | Actual Text: 7 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 03 | Actual Text: 08 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 73 | Actual Text: 76 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 2 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 63 | Actual Text: 5 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 0 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 60 | Actual Text: 69 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 6 | Correct: 0
# ...
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 88 | Actual Text: 69 | Correct: 0
# use_train = False Total correct: 4 accuracy:4/10= 0.4 char_accuracy:6/14= 0.42857142857142855
# loss at epoch 411 is 35156190780112.633
# loss at epoch 412 is 35850703914508.1
# loss at epoch 413 is 34412475270436.484
# loss at epoch 414 is 35010892503896.69
# loss at epoch 415 is 35143794019904.03
# use_train = True Total correct: 2165 accuracy:2165/5000= 0.433 char_accuracy:4129/7529= 0.5484128038252092
# use_train = False Total correct: 443 accuracy:443/1000= 0.443 char_accuracy:824/1491= 0.5526492287055668
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 85 | Actual Text: 62 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 8 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 28 | Actual Text: 20 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 9 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 41 | Actual Text: 41 | Correct: 2
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 86 | Actual Text: 88 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 02 | Actual Text: 02 | Correct: 2
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 87 | Actual Text: 87 | Correct: 2
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 9 | Actual Text: 9 | Correct: 1
# use_train = False Total correct: 6 accuracy:6/10= 0.6 char_accuracy:11/16= 0.6875
# loss at epoch 416 is 35501052804995.39
# loss at epoch 417 is 35581547147914.06
# loss at epoch 418 is 34902883954633.39
# loss at epoch 419 is 34855378662262.492
# loss at epoch 420 is 35444880424034.266
# use_train = True Total correct: 2212 accuracy:2212/5000= 0.4424 char_accuracy:4177/7529= 0.5547881524770886
# use_train = False Total correct: 434 accuracy:434/1000= 0.434 char_accuracy:826/1501= 0.5502998001332445
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 44 | Actual Text: 44 | Correct: 2
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 26 | Actual Text: 29 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 28 | Actual Text: 25 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 84 | Actual Text: 64 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 68 | Actual Text: 86 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 0 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 01 | Actual Text: 91 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 7 | Actual Text: 7 | Correct: 1
# use_train = False Total correct: 5 accuracy:5/10= 0.5 char_accuracy:10/16= 0.625
# loss at epoch 421 is 34667406902795.777
# loss at epoch 422 is 34741140113918.63
# loss at epoch 423 is 35122492333261.867
# loss at epoch 424 is 34982733693694.934
# loss at epoch 425 is 34668310141280.645
# use_train = True Total correct: 2261 accuracy:2261/5000= 0.4522 char_accuracy:4238/7529= 0.5628901580555187
# use_train = False Total correct: 455 accuracy:455/1000= 0.455 char_accuracy:828/1488= 0.5564516129032258
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 5 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 34 | Actual Text: 04 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 81 | Actual Text: 81 | Correct: 2
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 02 | Actual Text: 97 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 91 | Actual Text: 01 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 14 | Actual Text: 74 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 6 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 6 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 28 | Actual Text: 29 | Correct: 1
# use_train = False Total correct: 4 accuracy:4/10= 0.4 char_accuracy:9/16= 0.5625
# loss at epoch 426 is 34531828401946.18
# loss at epoch 427 is 34177040786857.754
# loss at epoch 428 is 34617129268716.91
# loss at epoch 429 is 34886481529057.06
# loss at epoch 430 is 34592348475897.754
# use_train = True Total correct: 2233 accuracy:2233/5000= 0.4466 char_accuracy:4222/7529= 0.5607650418382255
# use_train = False Total correct: 459 accuracy:459/1000= 0.459 char_accuracy:838/1488= 0.5631720430107527
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 7 | Actual Text: 7 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 91 | Actual Text: 91 | Correct: 2
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 78 | Actual Text: 79 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 88 | Actual Text: 55 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 88 | Actual Text: 89 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 9 | Actual Text: 0 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 5 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 5 | Actual Text: 5 | Correct: 1
# use_train = False Total correct: 5 accuracy:5/10= 0.5 char_accuracy:8/14= 0.5714285714285714
# loss at epoch 431 is 34604739435655.31
# loss at epoch 432 is 34960325857310.36
# loss at epoch 433 is 35217159491044.15
# loss at epoch 434 is 33190974234858.887
# loss at epoch 435 is 34289103850632.363
# use_train = True Total correct: 2271 accuracy:2271/5000= 0.4542 char_accuracy:4252/7529= 0.5647496347456501
# use_train = False Total correct: 463 accuracy:463/1000= 0.463 char_accuracy:839/1491= 0.562709590878605
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 88 | Actual Text: 30 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 87 | Actual Text: 84 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 8 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 0 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 9 | Actual Text: 6 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 68 | Actual Text: 39 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 01 | Actual Text: 01 | Correct: 2
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 6 | Correct: 0
# use_train = False Total correct: 5 accuracy:5/10= 0.5 char_accuracy:7/14= 0.5
# loss at epoch 436 is 33659744591736.594
# loss at epoch 437 is 33968244112866.875
# loss at epoch 438 is 33773654232484.766
# loss at epoch 439 is 34286716748661.098
# loss at epoch 440 is 34222978217386.133
# use_train = True Total correct: 2249 accuracy:2249/5000= 0.4498 char_accuracy:4237/7529= 0.5627573382919379
# use_train = False Total correct: 472 accuracy:472/1000= 0.472 char_accuracy:854/1491= 0.5727699530516432
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 8 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 0 | Actual Text: 0 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 3 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 9 | Actual Text: 9 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 8 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 8 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 81 | Actual Text: 31 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 5 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 01 | Actual Text: 01 | Correct: 2
# use_train = False Total correct: 7 accuracy:7/10= 0.7 char_accuracy:9/12= 0.75
# loss at epoch 441 is 33076706341104.92
# loss at epoch 442 is 33711492998295.414
# loss at epoch 443 is 33322216835238.645
# loss at epoch 444 is 33562979224266.42
# loss at epoch 445 is 33970852919280.277
# use_train = True Total correct: 2283 accuracy:2283/5000= 0.4566 char_accuracy:4253/7529= 0.564882454509231
# use_train = False Total correct: 481 accuracy:481/1000= 0.481 char_accuracy:875/1504= 0.581781914893617
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 16 | Actual Text: 15 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 35 | Actual Text: 36 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 5 | Actual Text: 5 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 06 | Actual Text: 96 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 27 | Actual Text: 27 | Correct: 2
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 8 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 2 | Actual Text: 2 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 47 | Actual Text: 87 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 14 | Actual Text: 14 | Correct: 2
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 7 | Actual Text: 7 | Correct: 1
# use_train = False Total correct: 6 accuracy:6/10= 0.6 char_accuracy:12/16= 0.75
# loss at epoch 446 is 34316006688207.71
# loss at epoch 447 is 34468937363789.33
# loss at epoch 448 is 33596927911765.934
# loss at epoch 449 is 34283779788113.76
# loss at epoch 450 is 33365480937372.223
# use_train = True Total correct: 2301 accuracy:2301/5000= 0.4602 char_accuracy:4316/7529= 0.5732500996148227
# use_train = False Total correct: 464 accuracy:464/1000= 0.464 char_accuracy:858/1514= 0.5667107001321003
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 18 | Actual Text: 10 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 12 | Actual Text: 12 | Correct: 2
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 67 | Actual Text: 57 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 5 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 11 | Actual Text: 11 | Correct: 2
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 85 | Actual Text: 56 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 6 | Actual Text: 6 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 77 | Actual Text: 77 | Correct: 2
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 12 | Actual Text: 12 | Correct: 2
# use_train = False Total correct: 6 accuracy:6/10= 0.6 char_accuracy:12/17= 0.7058823529411765
# loss at epoch 451 is 34046485513347.836
# loss at epoch 452 is 33197929678858.28
# loss at epoch 453 is 33616328806685.53
# loss at epoch 454 is 33772598518991.633
# loss at epoch 455 is 32727495369245.336
# use_train = True Total correct: 2331 accuracy:2331/5000= 0.4662 char_accuracy:4333/7529= 0.5755080355956966
# use_train = False Total correct: 490 accuracy:490/1000= 0.49 char_accuracy:867/1485= 0.5838383838383838
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 9 | Actual Text: 0 | Correct: 0
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 92 | Actual Text: 92 | Correct: 2
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 8 | Actual Text: 8 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 7 | Actual Text: 7 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 1 | Actual Text: 1 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 08 | Actual Text: 05 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 7 | Actual Text: 7 | Correct: 1
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 4 | Actual Text: 4 | Correct: 1
# N_predicted: 2 | Actual N: 2 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 61 | Actual Text: 33 | Correct: 0
# N_predicted: 1 | Actual N: 1 | Predicted Noise: 0.0 | Actual Noise: 0.0 | Predicted Text: 5 | Actual Text: 5 | Correct: 1
# use_train = False Total correct: 7 accuracy:7/10= 0.7 char_accuracy:9/13= 0.6923076923076923
# loss at epoch 456 is 33546418531863.69
# loss at epoch 457 is 33317869392790.24
# loss at epoch 458 is 32959763703433.035
