# %% [markdown]
# uncomment if executing in google colab

# %%
# ! pip uninstall pyro-ppl
# ! pip install pyro-ppl==1.5.1
# ! unzip fonts.zip 
# ! unzip claptchagen.zip
# ! unzip csis
# ! cp csis.py /usr/local/lib/python3.7/dist-packages/pyro/infer

# %%
import random
import string
import os
import torch.nn as nn
import torch
import torch.nn.functional as F
import pyro
import numpy as np
import pyro.optim as optim
import pyro.distributions as dist
import pyro.infer
import pyro.optim

from torch.autograd import Variable
from pyro.infer import SVI, Trace_ELBO, TraceGraph_ELBO
from PIL import Image
from claptchagen.claptcha import Claptcha
from torch.distributions import constraints
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import matplotlib.pyplot as plt
print(pyro.__version__)

captcha_folder = 'generated_captchas'
captchaHeight = 32
captchaWidth = 100
captchaMarginX = 4
captchaMarginY = 4
batch_size = 10

#char_dict = string.ascii_lowercase
char_dict = string.digits
#char_dict = "abc"
USE_CUDA = True
MAX_N = 5 # maximum number of letters in a captcha 
MIN_N = 3 # minimum number of letters in a captcha
MIN_NOISE = 0.01 # minimum noise
MAX_NOISE = 0.99 # maximum noise
smoke_test = False
num_steps = 200 if not smoke_test else 10
TrainingSample = 10000 if not smoke_test else 100 # number of captchas generated for training


def randomString():
    """
    return a string with <num_char> random letters
    """
    k = random.randint(MIN_N, MAX_N) # sample number of characters
    
    rndLetters = (random.choice(char_dict) for _ in range(k))
    
    pad_spaces = MAX_N - k # pad the string so the captcha is close to center
    space = " " * (pad_spaces // 2)
    
    return space + "".join(rndLetters) + space

def ramdomNoise():
    """
    return a float between MIN_NOISE, MAX_NOISE
    """
    return random.uniform(MIN_NOISE, MAX_NOISE)

def generate_random_captcha(n, save=False):
    """
    generate n random captchas,
    return a list of texts on the captchas
    """
    # Initialize Claptcha object with random text, FreeMono as font, of size
    # 100x30px, using bicubic resampling filter and adding a bit of white noise
    c = Claptcha(randomString, "fonts/FreeSans.ttf", (captchaWidth, captchaHeight), (captchaMarginX, captchaMarginY),
             resample=Image.BILINEAR, noise=0)
    captcha_generated = [ [] for i in range(MAX_N)]
    for i in range(n):
        c.noise = ramdomNoise()
        if save:
            text, _ = c.write(os.path.join(captcha_folder, 'captcha{}.png'.format(i)))
            os.rename(os.path.join(captcha_folder, 'captcha{}.png'.format(i)),os.path.join(captcha_folder, '{}.png'.format(text + "_" + str(i))))
        text, image = c.image
        text = text.strip()
        image = np.array(image)[:, :, 0] # the generator is gray scale, only keep one channel is enough
        captcha_generated[len(text) - 1].append((text, image, c.noise))
    return captcha_generated
    
captcha_generated = generate_random_captcha(TrainingSample, save=False)
for lst in captcha_generated:
    print("number of samples in group", len(lst))
    # print some sample captcha information generated
    for i, t in enumerate(lst):
        print("text", t[0], "captcha shape", t[1].shape, "noise", t[2])
        if i >= 10:
            break
# Out:
# 1.5.1
# number of samples in group 0
# number of samples in group 0
# number of samples in group 3294
# text 152 captcha shape (32, 100) noise 0.21314769954748078
# text 220 captcha shape (32, 100) noise 0.20374159194693375
# text 285 captcha shape (32, 100) noise 0.7740882369444321
# text 294 captcha shape (32, 100) noise 0.11401642396172738
# text 616 captcha shape (32, 100) noise 0.598788504894407
# text 397 captcha shape (32, 100) noise 0.5773762226399135
# text 619 captcha shape (32, 100) noise 0.18542629139347874
# text 644 captcha shape (32, 100) noise 0.9503004820861314
# text 345 captcha shape (32, 100) noise 0.8009596531616269
# text 219 captcha shape (32, 100) noise 0.8149610440123828
# text 499 captcha shape (32, 100) noise 0.2958894281376809
# number of samples in group 3335
# text 5993 captcha shape (32, 100) noise 0.920184646088082
# text 7205 captcha shape (32, 100) noise 0.6412995258975018
# text 1274 captcha shape (32, 100) noise 0.2705097961802969
# text 1822 captcha shape (32, 100) noise 0.5210892503839386
# text 3657 captcha shape (32, 100) noise 0.3457200307983819
# text 6689 captcha shape (32, 100) noise 0.24319143312009586
# text 7766 captcha shape (32, 100) noise 0.369778555939974
# text 2774 captcha shape (32, 100) noise 0.3906149810328714
# text 2613 captcha shape (32, 100) noise 0.27108627974468313
# text 0970 captcha shape (32, 100) noise 0.440008145828898
# text 8052 captcha shape (32, 100) noise 0.10207572269802716
# number of samples in group 3371
# text 76416 captcha shape (32, 100) noise 0.776867943536243
# text 35996 captcha shape (32, 100) noise 0.6349024177384641
# text 78578 captcha shape (32, 100) noise 0.38223896163396137
# text 01844 captcha shape (32, 100) noise 0.39520922513092527
# text 66176 captcha shape (32, 100) noise 0.16190497127503778
# text 04934 captcha shape (32, 100) noise 0.750718289812776
# text 96915 captcha shape (32, 100) noise 0.6026785946173214
# text 01144 captcha shape (32, 100) noise 0.033228758101705815
# text 87585 captcha shape (32, 100) noise 0.2298511225102165
# text 91789 captcha shape (32, 100) noise 0.23582413420464632
# text 42810 captcha shape (32, 100) noise 0.7863169288256433

# %%
def render_image(chars, fonts="fonts/FreeSans.ttf", size=(captchaWidth, captchaHeight), 
                 margin=(captchaMarginX, captchaMarginY), resample=Image.BILINEAR, noise=0.3, use_cuda=False):
    #noise = noise.data.item()
    #print(chars, noise)
    pad_spaces = MAX_N - len(chars)
    space = " " * (pad_spaces // 2)
    chars = space + chars + space
    render = Claptcha(chars, fonts, size, margin, resample=resample, noise=noise)

    
    _ , rendered_image = render.image
    rendered_image = np.array(rendered_image)[:,:,0] # the generator is gray scale, only keep one channel is enough
    rendered_image = np.subtract(np.divide(rendered_image, 255), 0.5)
    rendered_image = torch.from_numpy(rendered_image)
    if use_cuda:
        rendered_image = rendered_image.cuda()
    return rendered_image

# %%
class CaptchaDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, raw_captchas, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.raw_captchas = raw_captchas
        self.transform = transform

    def __len__(self):
        return len(self.raw_captchas)

    def __getitem__(self, idx):
        label = self.raw_captchas[idx][0]
        image = self.raw_captchas[idx][1]
        noise = self.raw_captchas[idx][2]
        
        image = np.subtract(np.divide(image, 255), 0.5)
        image = torch.from_numpy(image).float()

        if self.transform:
            image = self.transform(image)

        return label, image, noise

# %%
def make_loarders(BATCH_SIZE, raw_samples):
    dataloaders = [] # dataloaders for different num of char
    for lst in raw_samples:
        if lst:
            ds = CaptchaDataset(lst)
            dataloader = DataLoader(ds, batch_size=BATCH_SIZE,
                                    shuffle=True, num_workers=0, drop_last=True)
            dataloaders.append(dataloader)
    return dataloaders

def make_batches(dataloaders):
    all_batches = []
    for dl in dataloaders:
        for i_batch, sample in enumerate(dl):
            all_batches.append(sample)
    random.shuffle(all_batches)
    random.shuffle(all_batches)
    return all_batches

TrainLoaders = make_loarders(BATCH_SIZE=batch_size, raw_samples=captcha_generated)

# %%
class NoiseNet(nn.Module):

    def __init__(self, img_size, out_size = 1):
        """
        Network for learning noise in a captcha
        """
        super(NoiseNet, self).__init__()
        
        self.img_size = img_size
        self.fc0 = nn.Linear(img_size[0] * img_size[1], img_size[0] * img_size[1])
        self.fc1 = nn.Linear(img_size[0] * img_size[1], 1024)

        self.fc21 = nn.Linear(1024, out_size)
        self.fc22 = nn.Linear(1024, out_size)
        self.softplus = nn.Softplus()
    
    def forward(self, img):
        img = img.reshape(-1, self.img_size[0] * self.img_size[1])
        hidden = F.relu(self.fc0(img))
        hidden = self.fc1(hidden)
        # mean of noise, used in normal distribution
        mean =  torch.tanh(self.fc21(F.relu(hidden)))
        # std used in normal distribution
        sigma = self.softplus(self.fc22(F.relu(hidden)))
        return mean, sigma

# %%
class NumNet(nn.Module):
    def __init__(self, img_size, out_size = 3):
        """
        Network for learning N, number of letters in a captcha
        """
        super(NumNet, self).__init__()
        self.neural_net = nn.Sequential(
            nn.Linear(img_size[0] * img_size[1], img_size[0] * img_size[1] * 2),
            nn.ReLU(),
            nn.Linear(img_size[0] * img_size[1] * 2, 256),
            nn.ReLU(),
            nn.Linear(256, out_size),
            nn.LogSoftmax(dim=1))
  
    def forward(self, img):
        img = torch.reshape(img, (img.shape[0], img.shape[1] * img.shape[2]))
        prob = self.neural_net(img)
        return prob

# %%
class CharNetSingle(nn.Module):
    def __init__(self, img_size, output_size):
        """
        Network for letters in a captcha, given the noise and number of letters
        """
        super(CharNetSingle, self).__init__()
        self.img_size = img_size
        #self.N_num_class = N_num_class
        #self.input_size = input_size
        
        # output proposal layers

        #self.dropout = nn.Dropout()
        
        # observe layers
        self.conv1 = nn.Conv2d(1, 32, 3)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.pfc1 = nn.Linear(8832, 2048)
        self.pfc2 = nn.Linear(2048, 1024)
        self.pfc3 = nn.Linear(1024, 1024)
        self.pfc4 = nn.Linear(1024, output_size)
        self.convBN1 = nn.BatchNorm2d(32)
        self.convBN2 = nn.BatchNorm2d(64)

    def forward(self, img):
        BATCH_SIZE = img.shape[0]
#         i = torch.arange(0, int(N))
#         if USE_CUDA:
#             i = i.cuda()
#         i_onehot = F.one_hot(i, num_classes=self.N_num_class).float() # one hot format of N and index of letter
#         i_onehot = torch.reshape(i_onehot, (N, 1, self.N_num_class)).repeat(1, BATCH_SIZE, 1)
#         N_onehot = F.one_hot(N-1, num_classes=self.N_num_class).repeat(N, BATCH_SIZE, 1).float()
        
        # observe layers
        img = torch.reshape(img, (BATCH_SIZE, 1, self.img_size[0], self.img_size[1]))

        img = self.pool(F.relu(self.convBN1(self.conv1(img))))
        img = self.pool(F.relu(self.convBN2(self.conv2(img))))
        
        img = torch.reshape(img, (BATCH_SIZE, 8832))

        img = F.relu(self.pfc1(img))
        
        img = F.relu(self.pfc2(img))
        img = F.relu(self.pfc3(img))
        img = self.pfc4(img)
        
        #img = torch.reshape(img, (BATCH_SIZE, 1024))
        
        #img = img.repeat(N, 1, 1)
        
        # cat observed images, N, i and noise 
#         noise_batched = noise_batched.repeat(N, 1, 1)

#         x = torch.cat((img, N_onehot, i_onehot, noise_batched), dim=2)
#         x = torch.reshape(x, (N, BATCH_SIZE, self.input_size))

#         h_0_contig = self.h_0.expand(self.num_layers, BATCH_SIZE, self.hidden_size).contiguous()
#         #c_0_contig = self.c_0.expand(self.num_layers, BATCH_SIZE, self.hidden_size).contiguous()

#         outputs, hn = self.rnn(x, h_0_contig)
        
#         # probosal layer, map to output shape
#         outputs = torch.stack([self.linear_layers[i](outputs[i]) for i in range(outputs.shape[0])])

        outputs = F.log_softmax(img, dim=1)
        
        # transpose to <Batch, Length of Sequence, Character Space>
        #outputs = torch.transpose(outputs, 0, 1)
        
        return outputs

# %%
def inference(t, use_cuda=False):
    """
    one epoch of inference (iterate the training set once)
    """
    loss = 0
    length = TrainingSample
    loss_group = []
    all_batches = make_batches(TrainLoaders)
    for i_batch, sample_batched in enumerate(all_batches):
        
        img = sample_batched[1]
        if use_cuda:
            img = img.cuda()
        IMG = {"captcha" : img}
        imme_loss = csis.step(observations=IMG)
        loss += imme_loss / length

    print("loss at epoch {} is {}".format(t, loss))
    return loss

# %%
def test(n = 0, use_train=False, verbose=False, use_cuda=False):
    """
    benchmarking performance on customized or training set
    """
    if use_train:
        TestLoaders = make_loarders(BATCH_SIZE=1, raw_samples=captcha_generated)
    else:
        test_captcha_generated = generate_random_captcha(n, save=False)
        TestLoaders = make_loarders(BATCH_SIZE=1, raw_samples=test_captcha_generated)
    
    total_correct = 0
    char_correct = 0
    total_char = 0
    all_batches = make_batches(TestLoaders)
    for i_batch, t in enumerate(all_batches):

        label = t[0][0]
        gt_noise = t[2][0]
        img = t[1]

        if use_cuda:
            img = img.cuda()
        
        IMG = {"captcha" : img}
        
        posterior = csis.run(observations=IMG)
        marginal_num = pyro.infer.EmpiricalMarginal(posterior, "num_char")
        marginal_noise = pyro.infer.EmpiricalMarginal(posterior, "noise")
        with torch.no_grad():

            N_index = marginal_num()
            N = N_index + captchaModel.num_char_domain[0]
            noise = captchaModel._map_to_noise_range(marginal_noise()[0])
            sampled_chars = []
            
            # sample characters one by one
            for i in range(N):
                marginal_char = pyro.infer.EmpiricalMarginal(posterior, "char_{}".format(i))()[0]
                if use_cuda:
                    marginal_char.cpu()
                sampled_chars.append(marginal_char)
        
        chars = ""
        for i in range(len(sampled_chars)):
            c = sampled_chars[i]
            chars +=  captchaModel.char_dict[c]
        correct = 0
        
        for p_char, t_char in zip(chars, label):
            if p_char == t_char:
                correct += 1
        if not verbose:
            print("N_predicted:", int(N), "| Actual N:", len(label), "| Predicted Noise:", round(float(noise), 3), "| Actual Noise:", round(float(gt_noise), 3), "| Predicted Text:", chars, "| Actual Text:", label, "| Correct:", correct)
        if correct == len(label) and int(N) == len(label):
            total_correct += 1
        char_correct += correct
        total_char += len(label)
    num_test_samples = i_batch + 1
    accuracy = total_correct / num_test_samples
    char_accuracy = char_correct / total_char
    print("use_train =", use_train, "Total correct:", total_correct, "accuracy:{}/{}=".format(total_correct, num_test_samples), accuracy, "char_accuracy:{}/{}=".format(char_correct, total_char), char_accuracy)

# %%
def test_cycle(use_cuda):
    
    # disable dropout
    #captchaModel.numNet.eval()
    #captchaModel.charNetSingle.eval()
    test(use_train=True, verbose=True, use_cuda=use_cuda)
    test(1000, use_train=False, verbose=True, use_cuda=use_cuda)
    #test(10, use_train=True, verbose=False, use_cuda=use_cuda)
    test(10, use_train=False, verbose=False, use_cuda=use_cuda)
    # enable dropout
    #captchaModel.numNet.train()
    #captchaModel.charNetSingle.train()

def optimize(use_cuda=False):
    """
    Training/Inferencing Stage
    """
    loss_sequence = []
    pause = 5
    print("Optimizing...")
    for t in range(1, num_steps + 1):
        L = inference(t, use_cuda)
        loss_sequence.append(L)
        if (t % pause == 0) and (t > 0):
            test_cycle(use_cuda=use_cuda)
    plt.plot(loss_sequence)
    plt.title("loss")
    plt.show()

# %%
class CaptchaModel(nn.Module):
    """
    network, model and guide wrapper class
    """
    def __init__(self, use_cuda=False):
        super().__init__()
        self.num_char_domain = torch.arange(MIN_N, MAX_N + 1)
        if use_cuda:
            self.num_char_domain = self.num_char_domain.cuda()

        self.numNet = NumNet((captchaHeight, captchaWidth), len(self.num_char_domain))
        self.noiseNet = NoiseNet((captchaHeight, captchaWidth), 1)
        self.char_dict = char_dict # letter dictionary
        self.rnn_hidden_size = 512
        self.rnn_num_layer = 2
        self.charNet = CharNetSingle((captchaHeight, captchaWidth), len(self.char_dict))
        #self.charNetSingle = CharNetSingle((captchaHeight, captchaWidth), len(self.char_dict), N_num_class=max(self.num_char_domain), input_size=1024 + max(self.num_char_domain) * 2 + 1, hidden_size=self.rnn_hidden_size, num_layers=self.rnn_num_layer)
        self.noise_constraint = torch.distributions.constraints.interval(MIN_NOISE, MAX_NOISE)
        if use_cuda:
            self.cuda()
        self.use_cuda = use_cuda
    
    def _map_to_noise_range(self, input):
        """
        map input number to the valid noise range
        """
        input = torch.distributions.transform_to(self.noise_constraint)(input)
        return input

    def guide(self, observations={"captcha": torch.rand(1, captchaHeight, captchaWidth)}):
        pyro.module("guide", self)
        img = observations["captcha"].float()
        
        # posterior to the number of letters
        prob = self.numNet(img)
        prob = torch.mean(prob, dim=0)
        N_index = pyro.sample("num_char", dist.Categorical(prob))
        N_index = torch.add(N_index, self.num_char_domain[0])
        
        with pyro.plate("data", img.shape[0]):
            
            # posterior to the noise
            noise_mean, noise_sig = self.noiseNet(img)
            noise_batch = pyro.sample("noise", dist.Normal(noise_mean, noise_sig).to_event(1))
            noise_batch = self._map_to_noise_range(noise_batch)
            
            # posterior to the characters, given number of letters and noise
            #charP = self.charNetSingle(img, N_index, noise_batch)
            for i in range(N_index):
                charP_i = self.charNet(img)
                pyro.sample("char_{}".format(i), dist.Categorical(charP_i).to_event(0))
    
    def model(self, observations={"captcha": torch.rand(1, captchaHeight, captchaWidth)}):
        
        BS = observations["captcha"].shape[0]
        
        num_p = torch.tensor(1 / len(self.num_char_domain)).repeat(len(self.num_char_domain))
        
        if self.use_cuda:
            num_p = num_p.cuda()
        
        # sample the number of characters
        N_index = pyro.sample("num_char", dist.Categorical(num_p))
        N_index = torch.add(N_index,  self.num_char_domain[0])
        
        with pyro.plate("data", BS):
            
            noise_mean = torch.tensor((MAX_NOISE - MIN_NOISE) / 2).repeat((BS, 1))
            noise_sig = torch.tensor(0.5).repeat((BS, 1))

            if self.use_cuda:
                noise_mean = noise_mean.cuda()
                noise_sig = noise_sig.cuda()

            # sample the noise
            noise_batch = pyro.sample("noise", dist.Normal(noise_mean, noise_sig).to_event(1))
            noise_batch = self._map_to_noise_range(noise_batch)
            
            sampled_c = []
            for i in range(int(N_index)):
                num_c_i = torch.tensor(1 / len(self.char_dict)).repeat((BS, len(self.char_dict)))
                if self.use_cuda:
                    num_c_i = num_c_i.cuda()
                c_i = pyro.sample("char_{}".format(i), dist.Categorical(num_c_i).to_event(0))
                sampled_c.append(c_i)
            
            # sample the character indices
            #c = pyro.sample("chars", dist.Categorical(num_c).to_event(1)) # maybe 2 here
            rendered_images = []
            for i in range(sampled_c[0].shape[0]):
                chars = ""
                for j in range(N_index):
                    #print("sampled_c[%d][%d]" %(j, i), sampled_c[j][i])
                    chars += self.char_dict[sampled_c[j][i]]
        
                rendered_image = render_image(chars, noise=float(noise_batch[i]), use_cuda=self.use_cuda)
                rendered_images.append(rendered_image)
                
        rendered_images = torch.stack(rendered_images)
        sigma = torch.tensor(0.000001)
        if self.use_cuda:
                sigma = sigma.cuda()

        pyro.sample("captcha", dist.Normal(rendered_images, sigma).to_event(2), obs=observations["captcha"])

captchaModel = CaptchaModel(USE_CUDA)

optimiser = pyro.optim.Adam({'lr': 5e-5})
csis = pyro.infer.CSIS(captchaModel.model, captchaModel.guide, optimiser, num_inference_samples=1)


optimize(USE_CUDA)
test_cycle(USE_CUDA)
# Out:
# Optimizing...
# loss at epoch 1 is 8.237445894384392
# loss at epoch 2 is 7.030854938292508
# loss at epoch 3 is 6.445492459487911
# loss at epoch 4 is 6.0621609414100694
# loss at epoch 5 is 5.789668080401405
# use_train = True Total correct: 103 accuracy:103/10000= 0.0103 char_accuracy:10347/40077= 0.2581780073358784
# use_train = False Total correct: 12 accuracy:12/1000= 0.012 char_accuracy:1018/4016= 0.2534860557768924
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.594 | Actual Noise: 0.586 | Predicted Text: 969 | Actual Text: 962 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.315 | Actual Noise: 0.252 | Predicted Text: 04652 | Actual Text: 50096 | Correct: 0
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.42 | Actual Noise: 0.321 | Predicted Text: 495 | Actual Text: 650 | Correct: 0
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.373 | Actual Noise: 0.402 | Predicted Text: 97646 | Actual Text: 79296 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.342 | Actual Noise: 0.231 | Predicted Text: 40121 | Actual Text: 18920 | Correct: 1
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.512 | Actual Noise: 0.623 | Predicted Text: 006 | Actual Text: 002 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.423 | Actual Noise: 0.463 | Predicted Text: 9555 | Actual Text: 3826 | Correct: 0
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.298 | Actual Noise: 0.036 | Predicted Text: 255 | Actual Text: 451 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.679 | Actual Noise: 0.718 | Predicted Text: 5070 | Actual Text: 2250 | Correct: 1
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.666 | Actual Noise: 0.903 | Predicted Text: 536 | Actual Text: 805 | Correct: 0
# use_train = False Total correct: 0 accuracy:0/10= 0.0 char_accuracy:8/38= 0.21052631578947367
# loss at epoch 6 is 5.624247781252861
# loss at epoch 7 is 5.489330007839202
# loss at epoch 8 is 5.331433868122101
# loss at epoch 9 is 5.246922871983054
# loss at epoch 10 is 5.195297689008706
# use_train = True Total correct: 184 accuracy:184/10000= 0.0184 char_accuracy:11600/40077= 0.2894428225665594
# use_train = False Total correct: 22 accuracy:22/1000= 0.022 char_accuracy:1145/3998= 0.28639319659829915
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.312 | Actual Noise: 0.223 | Predicted Text: 184 | Actual Text: 461 | Correct: 0
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.344 | Actual Noise: 0.301 | Predicted Text: 45510 | Actual Text: 15540 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.36 | Actual Noise: 0.301 | Predicted Text: 6662 | Actual Text: 6368 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.697 | Actual Noise: 0.832 | Predicted Text: 22111 | Actual Text: 12197 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.247 | Actual Noise: 0.897 | Predicted Text: 449 | Actual Text: 499 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.38 | Actual Noise: 0.161 | Predicted Text: 5551 | Actual Text: 1359 | Correct: 1
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.856 | Actual Noise: 0.976 | Predicted Text: 303 | Actual Text: 308 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.475 | Actual Noise: 0.479 | Predicted Text: 0033 | Actual Text: 0343 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.904 | Actual Noise: 0.815 | Predicted Text: 89988 | Actual Text: 64829 | Correct: 0
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.301 | Actual Noise: 0.174 | Predicted Text: 61671 | Actual Text: 63171 | Correct: 3
# use_train = False Total correct: 0 accuracy:0/10= 0.0 char_accuracy:17/41= 0.4146341463414634
# loss at epoch 11 is 5.089955025339129
# loss at epoch 12 is 5.0837122569322615
# loss at epoch 13 is 4.986388038218015
# loss at epoch 14 is 4.930285212957857
# loss at epoch 15 is 4.930053981697561
# use_train = True Total correct: 202 accuracy:202/10000= 0.0202 char_accuracy:12046/40077= 0.30057140005489436
# use_train = False Total correct: 18 accuracy:18/1000= 0.018 char_accuracy:1184/4045= 0.2927070457354759
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.424 | Actual Noise: 0.251 | Predicted Text: 6996 | Actual Text: 9667 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.319 | Actual Noise: 0.136 | Predicted Text: 1911 | Actual Text: 1191 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.638 | Actual Noise: 0.919 | Predicted Text: 3333 | Actual Text: 3003 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.322 | Actual Noise: 0.171 | Predicted Text: 828 | Actual Text: 928 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.313 | Actual Noise: 0.02 | Predicted Text: 688 | Actual Text: 688 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.303 | Actual Noise: 0.201 | Predicted Text: 44477 | Actual Text: 74844 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.338 | Actual Noise: 0.155 | Predicted Text: 3932 | Actual Text: 2319 | Correct: 0
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.382 | Actual Noise: 0.257 | Predicted Text: 557 | Actual Text: 755 | Correct: 1
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.554 | Actual Noise: 0.542 | Predicted Text: 222 | Actual Text: 282 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.324 | Actual Noise: 0.969 | Predicted Text: 277 | Actual Text: 667 | Correct: 1
# use_train = False Total correct: 1 accuracy:1/10= 0.1 char_accuracy:14/36= 0.3888888888888889
# loss at epoch 16 is 4.857867473959926
# loss at epoch 17 is 4.866075066685672
# loss at epoch 18 is 4.79628548202514
# loss at epoch 19 is 4.737927451586724
# loss at epoch 20 is 4.775123157346247
# use_train = True Total correct: 232 accuracy:232/10000= 0.0232 char_accuracy:12135/40077= 0.3027921251590688
# use_train = False Total correct: 21 accuracy:21/1000= 0.021 char_accuracy:1221/3999= 0.30532633158289574
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.848 | Actual Noise: 0.942 | Predicted Text: 38384 | Actual Text: 75482 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.397 | Actual Noise: 0.381 | Predicted Text: 04011 | Actual Text: 14901 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.448 | Actual Noise: 0.435 | Predicted Text: 8644 | Actual Text: 3164 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.42 | Actual Noise: 0.417 | Predicted Text: 9999 | Actual Text: 7995 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.394 | Actual Noise: 0.347 | Predicted Text: 6661 | Actual Text: 1586 | Correct: 0
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.392 | Actual Noise: 0.41 | Predicted Text: 19041 | Actual Text: 09419 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.763 | Actual Noise: 0.778 | Predicted Text: 03140 | Actual Text: 00431 | Correct: 1
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.364 | Actual Noise: 0.225 | Predicted Text: 112 | Actual Text: 214 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.424 | Actual Noise: 0.406 | Predicted Text: 33400 | Actual Text: 00341 | Correct: 0
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.558 | Actual Noise: 0.549 | Predicted Text: 632 | Actual Text: 362 | Correct: 1
# use_train = False Total correct: 0 accuracy:0/10= 0.0 char_accuracy:10/43= 0.23255813953488372
# loss at epoch 21 is 4.73103733961582
# loss at epoch 22 is 4.662896105110645
# loss at epoch 23 is 4.6569166539073015
# loss at epoch 24 is 4.656694038701061
# loss at epoch 25 is 4.619507476902007
# use_train = True Total correct: 238 accuracy:238/10000= 0.0238 char_accuracy:12270/40077= 0.30616064076652444
# use_train = False Total correct: 24 accuracy:24/1000= 0.024 char_accuracy:1246/3975= 0.31345911949685534
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.347 | Actual Noise: 0.132 | Predicted Text: 41466 | Actual Text: 44461 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.706 | Actual Noise: 0.84 | Predicted Text: 47143 | Actual Text: 71544 | Correct: 1
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.279 | Actual Noise: 0.189 | Predicted Text: 217 | Actual Text: 217 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.353 | Actual Noise: 0.074 | Predicted Text: 833 | Actual Text: 803 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.762 | Actual Noise: 0.847 | Predicted Text: 25662 | Actual Text: 59562 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.274 | Actual Noise: 0.054 | Predicted Text: 663 | Actual Text: 963 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.475 | Actual Noise: 0.518 | Predicted Text: 15550 | Actual Text: 61500 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.338 | Actual Noise: 0.149 | Predicted Text: 00011 | Actual Text: 10601 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.816 | Actual Noise: 0.872 | Predicted Text: 286 | Actual Text: 926 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.613 | Actual Noise: 0.667 | Predicted Text: 33323 | Actual Text: 33632 | Correct: 2
# use_train = False Total correct: 1 accuracy:1/10= 0.1 char_accuracy:20/42= 0.47619047619047616
# loss at epoch 26 is 4.578509280395504
# loss at epoch 27 is 4.5648962906956685
# loss at epoch 28 is 4.526830335378643
# loss at epoch 29 is 4.500276685345169
# loss at epoch 30 is 4.51634389699697
# use_train = True Total correct: 254 accuracy:254/10000= 0.0254 char_accuracy:12304/40077= 0.307009007660254
# use_train = False Total correct: 25 accuracy:25/1000= 0.025 char_accuracy:1243/4005= 0.3103620474406991
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.273 | Actual Noise: 0.114 | Predicted Text: 63839 | Actual Text: 38958 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.875 | Actual Noise: 0.949 | Predicted Text: 7955 | Actual Text: 9375 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.294 | Actual Noise: 0.126 | Predicted Text: 9499 | Actual Text: 4999 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.525 | Actual Noise: 0.519 | Predicted Text: 6611 | Actual Text: 2161 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.38 | Actual Noise: 0.336 | Predicted Text: 3034 | Actual Text: 4063 | Correct: 1
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.849 | Actual Noise: 0.901 | Predicted Text: 322 | Actual Text: 432 | Correct: 1
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.568 | Actual Noise: 0.514 | Predicted Text: 665 | Actual Text: 561 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.614 | Actual Noise: 0.645 | Predicted Text: 5515 | Actual Text: 5155 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.736 | Actual Noise: 0.748 | Predicted Text: 0373 | Actual Text: 7503 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.676 | Actual Noise: 0.765 | Predicted Text: 5885 | Actual Text: 0538 | Correct: 0
# use_train = False Total correct: 0 accuracy:0/10= 0.0 char_accuracy:10/39= 0.2564102564102564
# loss at epoch 31 is 4.440536417746544
# loss at epoch 32 is 4.463698558664321
# loss at epoch 33 is 4.404732290577893
# loss at epoch 34 is 4.4066847525715795
# loss at epoch 35 is 4.393762440550327
# use_train = True Total correct: 249 accuracy:249/10000= 0.0249 char_accuracy:12403/40077= 0.30947925243905483
# use_train = False Total correct: 20 accuracy:20/1000= 0.02 char_accuracy:1218/4034= 0.30193356470004956
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.493 | Actual Noise: 0.478 | Predicted Text: 5555 | Actual Text: 3785 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.556 | Actual Noise: 0.548 | Predicted Text: 6446 | Actual Text: 6664 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.473 | Actual Noise: 0.459 | Predicted Text: 8544 | Actual Text: 8745 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.574 | Actual Noise: 0.563 | Predicted Text: 35301 | Actual Text: 12935 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.536 | Actual Noise: 0.582 | Predicted Text: 8644 | Actual Text: 6514 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.631 | Actual Noise: 0.626 | Predicted Text: 61606 | Actual Text: 01406 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.297 | Actual Noise: 0.148 | Predicted Text: 9567 | Actual Text: 7965 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.286 | Actual Noise: 0.045 | Predicted Text: 51259 | Actual Text: 15479 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.929 | Actual Noise: 0.964 | Predicted Text: 2771 | Actual Text: 7742 | Correct: 1
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.474 | Actual Noise: 0.512 | Predicted Text: 232 | Actual Text: 232 | Correct: 3
# use_train = False Total correct: 1 accuracy:1/10= 0.1 char_accuracy:14/42= 0.3333333333333333
# loss at epoch 36 is 4.2789866886734975
# loss at epoch 37 is 4.3850081788539965
# loss at epoch 38 is 4.363702240693569
# loss at epoch 39 is 4.343002623605725
# loss at epoch 40 is 4.243643243730068
# use_train = True Total correct: 237 accuracy:237/10000= 0.0237 char_accuracy:12364/40077= 0.30850612570801206
# use_train = False Total correct: 26 accuracy:26/1000= 0.026 char_accuracy:1286/3977= 0.3233593160673875
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.3 | Actual Noise: 0.141 | Predicted Text: 85686 | Actual Text: 59683 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.419 | Actual Noise: 0.39 | Predicted Text: 444 | Actual Text: 442 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.634 | Actual Noise: 0.836 | Predicted Text: 22523 | Actual Text: 52329 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.642 | Actual Noise: 0.632 | Predicted Text: 056 | Actual Text: 905 | Correct: 0
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.274 | Actual Noise: 0.095 | Predicted Text: 67377 | Actual Text: 87376 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.611 | Actual Noise: 0.619 | Predicted Text: 444 | Actual Text: 469 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.323 | Actual Noise: 0.151 | Predicted Text: 44564 | Actual Text: 46045 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.293 | Actual Noise: 0.22 | Predicted Text: 73237 | Actual Text: 94327 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.659 | Actual Noise: 0.66 | Predicted Text: 43693 | Actual Text: 39236 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.739 | Actual Noise: 0.803 | Predicted Text: 0535 | Actual Text: 3150 | Correct: 0
# use_train = False Total correct: 0 accuracy:0/10= 0.0 char_accuracy:12/43= 0.27906976744186046
# loss at epoch 41 is 4.305559628295898
# loss at epoch 42 is 4.276780859029292
# loss at epoch 43 is 4.250502947723866
# loss at epoch 44 is 4.27957054398656
# loss at epoch 45 is 4.214139073044064
# use_train = True Total correct: 287 accuracy:287/10000= 0.0287 char_accuracy:12498/40077= 0.3118496893480051
# use_train = False Total correct: 24 accuracy:24/1000= 0.024 char_accuracy:1266/3981= 0.3180105501130369
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.251 | Actual Noise: 0.054 | Predicted Text: 22644 | Actual Text: 26534 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.523 | Actual Noise: 0.54 | Predicted Text: 9758 | Actual Text: 5879 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.683 | Actual Noise: 0.794 | Predicted Text: 3306 | Actual Text: 3006 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.703 | Actual Noise: 0.715 | Predicted Text: 4944 | Actual Text: 4749 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.319 | Actual Noise: 0.263 | Predicted Text: 117 | Actual Text: 177 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.286 | Actual Noise: 0.106 | Predicted Text: 7557 | Actual Text: 2257 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.395 | Actual Noise: 0.935 | Predicted Text: 22482 | Actual Text: 44228 | Correct: 0
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.415 | Actual Noise: 0.435 | Predicted Text: 222 | Actual Text: 228 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.272 | Actual Noise: 0.089 | Predicted Text: 6111 | Actual Text: 1436 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.275 | Actual Noise: 0.175 | Predicted Text: 6676 | Actual Text: 6761 | Correct: 1
# use_train = False Total correct: 0 accuracy:0/10= 0.0 char_accuracy:14/40= 0.35
# loss at epoch 46 is 4.18924779701233
# loss at epoch 47 is 4.181677304899693
# loss at epoch 48 is 4.194459791314598
# loss at epoch 49 is 4.209879832768446
# loss at epoch 50 is 4.138908143568036
# use_train = True Total correct: 314 accuracy:314/10000= 0.0314 char_accuracy:12457/40077= 0.31082665868203707
# use_train = False Total correct: 28 accuracy:28/1000= 0.028 char_accuracy:1259/4018= 0.31333997013439524
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.729 | Actual Noise: 0.739 | Predicted Text: 661 | Actual Text: 136 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.561 | Actual Noise: 0.861 | Predicted Text: 8119 | Actual Text: 8189 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.748 | Actual Noise: 0.77 | Predicted Text: 00033 | Actual Text: 07302 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.384 | Actual Noise: 0.388 | Predicted Text: 3999 | Actual Text: 3759 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.674 | Actual Noise: 0.689 | Predicted Text: 433 | Actual Text: 430 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.748 | Actual Noise: 0.786 | Predicted Text: 874 | Actual Text: 897 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.643 | Actual Noise: 0.652 | Predicted Text: 59599 | Actual Text: 15599 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.309 | Actual Noise: 0.2 | Predicted Text: 252 | Actual Text: 527 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.58 | Actual Noise: 0.572 | Predicted Text: 8458 | Actual Text: 5842 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.584 | Actual Noise: 0.593 | Predicted Text: 9191 | Actual Text: 1190 | Correct: 2
# use_train = False Total correct: 0 accuracy:0/10= 0.0 char_accuracy:14/38= 0.3684210526315789
# loss at epoch 51 is 4.10186350979805
# loss at epoch 52 is 4.112077154773471
# loss at epoch 53 is 4.135989243459701
# loss at epoch 54 is 4.104023541396856
# loss at epoch 55 is 4.092468302106856
# use_train = True Total correct: 280 accuracy:280/10000= 0.028 char_accuracy:12590/40077= 0.31414527035456746
# use_train = False Total correct: 19 accuracy:19/1000= 0.019 char_accuracy:1226/3997= 0.30673004753565175
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.703 | Actual Noise: 0.673 | Predicted Text: 88677 | Actual Text: 81878 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.985 | Actual Noise: 0.953 | Predicted Text: 33030 | Actual Text: 63039 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.301 | Actual Noise: 0.186 | Predicted Text: 2858 | Actual Text: 8524 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.216 | Actual Noise: 0.966 | Predicted Text: 7199 | Actual Text: 1978 | Correct: 0
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.706 | Actual Noise: 0.751 | Predicted Text: 667 | Actual Text: 769 | Correct: 1
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.707 | Actual Noise: 0.709 | Predicted Text: 564 | Actual Text: 654 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.954 | Actual Noise: 0.988 | Predicted Text: 6909 | Actual Text: 9680 | Correct: 0
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.93 | Actual Noise: 0.922 | Predicted Text: 37315 | Actual Text: 35657 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.607 | Actual Noise: 0.578 | Predicted Text: 6969 | Actual Text: 1639 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.308 | Actual Noise: 0.18 | Predicted Text: 9939 | Actual Text: 4399 | Correct: 1
# use_train = False Total correct: 0 accuracy:0/10= 0.0 char_accuracy:10/41= 0.24390243902439024
# loss at epoch 56 is 4.040339863467218
# loss at epoch 57 is 4.060001862585547
# loss at epoch 58 is 4.049533860707285
# loss at epoch 59 is 4.0254263110399195
# loss at epoch 60 is 4.007171660500766
# use_train = True Total correct: 321 accuracy:321/10000= 0.0321 char_accuracy:12749/40077= 0.3181126331811263
# use_train = False Total correct: 18 accuracy:18/1000= 0.018 char_accuracy:1223/3946= 0.3099341104916371
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.288 | Actual Noise: 0.225 | Predicted Text: 666 | Actual Text: 266 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.601 | Actual Noise: 0.606 | Predicted Text: 44922 | Actual Text: 92264 | Correct: 0
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.78 | Actual Noise: 0.863 | Predicted Text: 477 | Actual Text: 764 | Correct: 0
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.55 | Actual Noise: 0.968 | Predicted Text: 996 | Actual Text: 649 | Correct: 0
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.446 | Actual Noise: 0.967 | Predicted Text: 444 | Actual Text: 447 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.919 | Actual Noise: 0.976 | Predicted Text: 3664 | Actual Text: 4633 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.282 | Actual Noise: 0.127 | Predicted Text: 94944 | Actual Text: 17489 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.297 | Actual Noise: 0.285 | Predicted Text: 0099 | Actual Text: 2990 | Correct: 1
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.964 | Actual Noise: 0.983 | Predicted Text: 930 | Actual Text: 093 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.749 | Actual Noise: 0.86 | Predicted Text: 6606 | Actual Text: 1106 | Correct: 2
# use_train = False Total correct: 0 accuracy:0/10= 0.0 char_accuracy:8/37= 0.21621621621621623
# loss at epoch 61 is 4.030210934156176
# loss at epoch 62 is 4.000180868929626
# loss at epoch 63 is 3.987291901177166
# loss at epoch 64 is 4.0017276182830335
# loss at epoch 65 is 3.9641662091493632
# use_train = True Total correct: 290 accuracy:290/10000= 0.029 char_accuracy:12677/40077= 0.3163160915238167
# use_train = False Total correct: 25 accuracy:25/1000= 0.025 char_accuracy:1251/3963= 0.315669947009841
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.512 | Actual Noise: 0.523 | Predicted Text: 6326 | Actual Text: 2436 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.274 | Actual Noise: 0.206 | Predicted Text: 75717 | Actual Text: 37715 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.418 | Actual Noise: 0.391 | Predicted Text: 955 | Actual Text: 592 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.412 | Actual Noise: 0.452 | Predicted Text: 0070 | Actual Text: 0047 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.63 | Actual Noise: 0.635 | Predicted Text: 00011 | Actual Text: 10240 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.582 | Actual Noise: 0.62 | Predicted Text: 7719 | Actual Text: 9127 | Correct: 0
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.288 | Actual Noise: 0.166 | Predicted Text: 99994 | Actual Text: 85934 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.589 | Actual Noise: 0.579 | Predicted Text: 1011 | Actual Text: 0611 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.741 | Actual Noise: 0.811 | Predicted Text: 88089 | Actual Text: 95088 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.302 | Actual Noise: 0.236 | Predicted Text: 66505 | Actual Text: 25076 | Correct: 0
# use_train = False Total correct: 0 accuracy:0/10= 0.0 char_accuracy:12/44= 0.2727272727272727
# loss at epoch 66 is 3.926264518791437
# loss at epoch 67 is 3.9822944756448275
# loss at epoch 68 is 3.9339246146619278
# loss at epoch 69 is 3.922802874034639
# loss at epoch 70 is 3.923215390771629
# use_train = True Total correct: 293 accuracy:293/10000= 0.0293 char_accuracy:12589/40077= 0.3141203183871048
# use_train = False Total correct: 21 accuracy:21/1000= 0.021 char_accuracy:1226/4008= 0.3058882235528942
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.915 | Actual Noise: 0.853 | Predicted Text: 53385 | Actual Text: 31538 | Correct: 0
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.309 | Actual Noise: 0.017 | Predicted Text: 917 | Actual Text: 179 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.468 | Actual Noise: 0.464 | Predicted Text: 1791 | Actual Text: 7619 | Correct: 0
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.764 | Actual Noise: 0.737 | Predicted Text: 67565 | Actual Text: 76555 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.711 | Actual Noise: 0.737 | Predicted Text: 70730 | Actual Text: 83507 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.42 | Actual Noise: 0.414 | Predicted Text: 5775 | Actual Text: 0357 | Correct: 0
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.328 | Actual Noise: 0.116 | Predicted Text: 52227 | Actual Text: 11275 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.371 | Actual Noise: 0.361 | Predicted Text: 4514 | Actual Text: 1045 | Correct: 0
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.314 | Actual Noise: 0.851 | Predicted Text: 008 | Actual Text: 600 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.355 | Actual Noise: 0.317 | Predicted Text: 2858 | Actual Text: 5892 | Correct: 1
# use_train = False Total correct: 0 accuracy:0/10= 0.0 char_accuracy:5/42= 0.11904761904761904
# loss at epoch 71 is 3.9412209032475936
# loss at epoch 72 is 3.9550269366741175
# loss at epoch 73 is 3.8752543729662903
# loss at epoch 74 is 3.872140687602759
# loss at epoch 75 is 3.8580407318890093
# use_train = True Total correct: 313 accuracy:313/10000= 0.0313 char_accuracy:12653/40077= 0.31571724430471343
# use_train = False Total correct: 33 accuracy:33/1000= 0.033 char_accuracy:1266/4017= 0.31516056758775207
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.714 | Actual Noise: 0.762 | Predicted Text: 45344 | Actual Text: 93345 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.619 | Actual Noise: 0.637 | Predicted Text: 333 | Actual Text: 723 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.713 | Actual Noise: 0.728 | Predicted Text: 0080 | Actual Text: 8770 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.323 | Actual Noise: 0.236 | Predicted Text: 77788 | Actual Text: 78974 | Correct: 1
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.858 | Actual Noise: 0.903 | Predicted Text: 534 | Actual Text: 543 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.322 | Actual Noise: 0.221 | Predicted Text: 8522 | Actual Text: 8825 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.278 | Actual Noise: 0.168 | Predicted Text: 77488 | Actual Text: 84745 | Correct: 0
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.726 | Actual Noise: 0.922 | Predicted Text: 35222 | Actual Text: 82557 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.653 | Actual Noise: 0.659 | Predicted Text: 3631 | Actual Text: 6315 | Correct: 0
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.345 | Actual Noise: 0.344 | Predicted Text: 13610 | Actual Text: 16031 | Correct: 1
# use_train = False Total correct: 0 accuracy:0/10= 0.0 char_accuracy:9/43= 0.20930232558139536
# loss at epoch 76 is 3.8639828100562106
# loss at epoch 77 is 3.8687301821351103
# loss at epoch 78 is 3.9095299765646483
# loss at epoch 79 is 3.8482096994876853
# loss at epoch 80 is 3.8704891784012267
# use_train = True Total correct: 280 accuracy:280/10000= 0.028 char_accuracy:12623/40077= 0.3149686852808344
# use_train = False Total correct: 27 accuracy:27/1000= 0.027 char_accuracy:1251/4004= 0.31243756243756243
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.682 | Actual Noise: 0.681 | Predicted Text: 1272 | Actual Text: 1237 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.588 | Actual Noise: 0.624 | Predicted Text: 52499 | Actual Text: 25494 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.362 | Actual Noise: 0.344 | Predicted Text: 023 | Actual Text: 320 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.217 | Actual Noise: 0.879 | Predicted Text: 71887 | Actual Text: 76316 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.597 | Actual Noise: 0.602 | Predicted Text: 7477 | Actual Text: 6674 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.335 | Actual Noise: 0.121 | Predicted Text: 92696 | Actual Text: 26969 | Correct: 0
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.44 | Actual Noise: 0.879 | Predicted Text: 42222 | Actual Text: 62844 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.43 | Actual Noise: 0.453 | Predicted Text: 5754 | Actual Text: 8445 | Correct: 0
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.691 | Actual Noise: 0.677 | Predicted Text: 8667 | Actual Text: 8776 | Correct: 1
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.36 | Actual Noise: 0.326 | Predicted Text: 828 | Actual Text: 278 | Correct: 1
# use_train = False Total correct: 0 accuracy:0/10= 0.0 char_accuracy:10/42= 0.23809523809523808
# loss at epoch 81 is 3.8340296009063692
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-0f6c7ac39958> in <module>
#     110
#     111
# --> 112 optimize(USE_CUDA)
#     113 test_cycle(USE_CUDA)
#
# <ipython-input-11-13f4e1d1fa17> in optimize(use_cuda)
#      20     print("Optimizing...")
#      21     for t in range(1, num_steps + 1):
# ---> 22         L = inference(t, use_cuda)
#      23         loss_sequence.append(L)
#      24         if (t % pause == 0) and (t > 0):
#
# <ipython-input-9-6b4856846cff> in inference(t, use_cuda)
#      13             img = img.cuda()
#      14         IMG = {"captcha" : img}
# ---> 15         imme_loss = csis.step(observations=IMG)
#      16         loss += imme_loss / length
#      17
#
# ~\anaconda3\lib\site-packages\pyro\infer\csis.py in step(self, *args, **kwargs)
#      70         """
#      71         with poutine.trace(param_only=True) as param_capture:
# ---> 72             loss = self.loss_and_grads(True, None, *args, **kwargs)
#      73
#      74         params = set(site["value"].unconstrained()
#
# ~\anaconda3\lib\site-packages\pyro\infer\csis.py in loss_and_grads(self, grads, batch, *args, **kwargs)
#     103
#     104         loss = 0
# --> 105         for model_trace in batch:
#     106             with poutine.trace(param_only=True) as particle_param_capture:
#     107                 guide_trace = self._get_matched_trace(model_trace, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\pyro\infer\csis.py in <genexpr>(.0)
#      96         """
#      97         if batch is None:
# ---> 98             batch = (self._sample_from_joint(*args, **kwargs)
#      99                      for _ in range(self.training_batch_size))
#     100             batch_size = self.training_batch_size
#
# ~\anaconda3\lib\site-packages\pyro\infer\csis.py in _sample_from_joint(self, *args, **kwargs)
#     196         """
#     197         unconditioned_model = pyro.poutine.uncondition(self.model)
# --> 198         return poutine.trace(unconditioned_model).get_trace(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\pyro\poutine\trace_messenger.py in get_trace(self, *args, **kwargs)
#     185         Calls this poutine and returns its trace instead of the function's return value.
#     186         """
# --> 187         self(*args, **kwargs)
#     188         return self.msngr.get_trace()
#
# ~\anaconda3\lib\site-packages\pyro\poutine\trace_messenger.py in __call__(self, *args, **kwargs)
#     163                                       args=args, kwargs=kwargs)
#     164             try:
# --> 165                 ret = self.fn(*args, **kwargs)
#     166             except (ValueError, RuntimeError) as e:
#     167                 exc_type, exc_value, traceback = sys.exc_info()
#
# ~\anaconda3\lib\site-packages\pyro\poutine\messenger.py in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#      13
#      14
#
# <ipython-input-12-0f6c7ac39958> in model(self, observations)
#      94                     chars += self.char_dict[sampled_c[j][i]]
#      95
# ---> 96                 rendered_image = render_image(chars, noise=float(noise_batch[i]), use_cuda=self.use_cuda)
#      97                 rendered_images.append(rendered_image)
#      98
#
# <ipython-input-3-f1445ba574c5> in render_image(chars, fonts, size, margin, resample, noise, use_cuda)
#       9
#      10
# ---> 11     _ , rendered_image = render.image
#      12     rendered_image = np.array(rendered_image)[:,:,0] # the generator is gray scale, only keep one channel is enough
#      13     rendered_image = np.subtract(np.divide(rendered_image, 255), 0.5)
#
# ~\OneDrive\Documents\URA\claptchagen\claptcha\claptcha.py in image(self)
#     120
#     121         # Resize
# --> 122         image = image.resize(self.size, resample=self.resample)
#     123
#     124         return (text, image)
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in resize(self, size, resample, box, reducing_gap)
#    1933                 )
#    1934
# -> 1935         return self._new(self.im.resize(size, resample, box))
#    1936
#    1937     def reduce(self, factor, box=None):
#
# KeyboardInterrupt:
