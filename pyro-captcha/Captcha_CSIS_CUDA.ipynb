# %% [markdown]
# uncomment if executing in google colab

# %%
# ! pip uninstall pyro-ppl
# ! pip install pyro-ppl==1.5.1
# ! unzip fonts.zip 
# ! unzip claptchagen.zip
# ! unzip csis
# ! cp csis.py /usr/local/lib/python3.7/dist-packages/pyro/infer

# %%
import random
import string
import os
import torch.nn as nn
import torch
import torch.nn.functional as F
import pyro
import numpy as np
import pyro.optim as optim
import pyro.distributions as dist
import pyro.infer
import pyro.optim

from torch.autograd import Variable
from pyro.infer import SVI, Trace_ELBO, TraceGraph_ELBO
from PIL import Image
from claptchagen.claptcha import Claptcha
from torch.distributions import constraints
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import matplotlib.pyplot as plt
print(pyro.__version__)

captcha_folder = 'generated_captchas'
captchaHeight = 32
captchaWidth = 100
captchaMarginX = 4
captchaMarginY = 4
batch_size = 10

#char_dict = string.ascii_lowercase
char_dict = string.digits
USE_CUDA = True
MAX_N = 5 # maximum number of letters in a captcha 
MIN_N = 3 # minimum number of letters in a captcha
MIN_NOISE = 0.01 # minimum noise
MAX_NOISE = 0.99 # maximum noise
smoke_test = False
num_steps = 200 if not smoke_test else 10
TrainingSample = 10000 if not smoke_test else 100 # number of captchas generated for training

def randomString():
    """
    return a string with <num_char> random letters
    """
    k = random.randint(MIN_N, MAX_N) # sample number of characters
    
    rndLetters = (random.choice(char_dict) for _ in range(k))
    
    pad_spaces = MAX_N - k # pad the string so the captcha is close to center
    space = " " * (pad_spaces // 2)
    
    return space + "".join(rndLetters) + space

def ramdomNoise():
    """
    return a float between MIN_NOISE, MAX_NOISE
    """
    return random.uniform(MIN_NOISE, MAX_NOISE)

def generate_random_captcha(n, save=False):
    """
    generate n random captchas,
    return a list of texts on the captchas
    """
    # Initialize Claptcha object with random text, FreeMono as font, of size
    # 100x30px, using bicubic resampling filter and adding a bit of white noise
    c = Claptcha(randomString, "fonts/FreeSans.ttf", (captchaWidth, captchaHeight), (captchaMarginX, captchaMarginY),
             resample=Image.BILINEAR, noise=0)
    captcha_generated = [ [] for i in range(MAX_N)]
    for i in range(n):
        c.noise = ramdomNoise()
        if save:
            text, _ = c.write(os.path.join(captcha_folder, 'captcha{}.png'.format(i)))
            os.rename(os.path.join(captcha_folder, 'captcha{}.png'.format(i)),os.path.join(captcha_folder, '{}.png'.format(text + "_" + str(i))))
        text, image = c.image
        text = text.strip()
        image = np.array(image)[:, :, 0] # the generator is gray scale, only keep one channel is enough
        captcha_generated[len(text) - 1].append((text, image, c.noise))
    return captcha_generated
    
captcha_generated = generate_random_captcha(TrainingSample, save=False)
for lst in captcha_generated:
    print("number of samples in group", len(lst))
    # print some sample captcha information generated
    for i, t in enumerate(lst):
        print("text", t[0], "captcha shape", t[1].shape, "noise", t[2])
        if i >= 10:
            break
# Out:
# 1.5.1
# number of samples in group 0
# number of samples in group 0
# number of samples in group 3326
# text 764 captcha shape (32, 100) noise 0.9061222365042445
# text 335 captcha shape (32, 100) noise 0.8468159625050281
# text 569 captcha shape (32, 100) noise 0.8501482754931509
# text 945 captcha shape (32, 100) noise 0.3664891127477425
# text 246 captcha shape (32, 100) noise 0.05826500760128896
# text 587 captcha shape (32, 100) noise 0.461464183072394
# text 641 captcha shape (32, 100) noise 0.9784302571508726
# text 955 captcha shape (32, 100) noise 0.6070987099926456
# text 546 captcha shape (32, 100) noise 0.47303466105414604
# text 301 captcha shape (32, 100) noise 0.6192618282961018
# text 982 captcha shape (32, 100) noise 0.656073659967958
# number of samples in group 3315
# text 7763 captcha shape (32, 100) noise 0.27843241792724255
# text 3314 captcha shape (32, 100) noise 0.1046967400805218
# text 1373 captcha shape (32, 100) noise 0.29996151824346107
# text 1851 captcha shape (32, 100) noise 0.9505919228115529
# text 7983 captcha shape (32, 100) noise 0.5990197161124037
# text 0578 captcha shape (32, 100) noise 0.4972870970147612
# text 2795 captcha shape (32, 100) noise 0.05376724891246896
# text 4464 captcha shape (32, 100) noise 0.03519250147989363
# text 4926 captcha shape (32, 100) noise 0.713662698380729
# text 9986 captcha shape (32, 100) noise 0.7885108319502654
# text 3606 captcha shape (32, 100) noise 0.7967804565818734
# number of samples in group 3359
# text 66199 captcha shape (32, 100) noise 0.967810917932034
# text 05960 captcha shape (32, 100) noise 0.7410861985489052
# text 93027 captcha shape (32, 100) noise 0.4153668976639986
# text 38150 captcha shape (32, 100) noise 0.38912763097441894
# text 38952 captcha shape (32, 100) noise 0.9447760931737209
# text 80761 captcha shape (32, 100) noise 0.6751680943028008
# text 28150 captcha shape (32, 100) noise 0.34784719660692676
# text 45220 captcha shape (32, 100) noise 0.04645283502120679
# text 85187 captcha shape (32, 100) noise 0.11936257777284512
# text 12594 captcha shape (32, 100) noise 0.551903005587717
# text 11675 captcha shape (32, 100) noise 0.900599905777224

# %%
def render_image(chars, fonts="fonts/FreeSans.ttf", size=(captchaWidth, captchaHeight), 
                 margin=(captchaMarginX, captchaMarginY), resample=Image.BILINEAR, noise=0.3, use_cuda=False):
    #noise = noise.data.item()
    #print(chars, noise)
    pad_spaces = MAX_N - len(chars)
    space = " " * (pad_spaces // 2)
    chars = space + chars + space
    render = Claptcha(chars, fonts, size, margin, resample=resample, noise=noise)

    
    _ , rendered_image = render.image
    rendered_image = np.array(rendered_image)[:,:,0] # the generator is gray scale, only keep one channel is enough
    rendered_image = np.subtract(np.divide(rendered_image, 255), 0.5)
    rendered_image = torch.from_numpy(rendered_image)
    if use_cuda:
        rendered_image = rendered_image.cuda()
    return rendered_image

# %%
class CaptchaDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, raw_captchas, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.raw_captchas = raw_captchas
        self.transform = transform

    def __len__(self):
        return len(self.raw_captchas)

    def __getitem__(self, idx):
        label = self.raw_captchas[idx][0]
        image = self.raw_captchas[idx][1]
        noise = self.raw_captchas[idx][2]
        
        image = np.subtract(np.divide(image, 255), 0.5)
        image = torch.from_numpy(image).float()

        if self.transform:
            image = self.transform(image)

        return label, image, noise

# %%
def make_loarders(BATCH_SIZE, raw_samples):
    dataloaders = [] # dataloaders for different num of char
    for lst in raw_samples:
        if lst:
            ds = CaptchaDataset(lst)
            dataloader = DataLoader(ds, batch_size=BATCH_SIZE,
                                    shuffle=True, num_workers=0, drop_last=True)
            dataloaders.append(dataloader)
    return dataloaders

def make_batches(dataloaders):
    all_batches = []
    for dl in dataloaders:
        for i_batch, sample in enumerate(dl):
            all_batches.append(sample)
    random.shuffle(all_batches)
    random.shuffle(all_batches)
    return all_batches

TrainLoaders = make_loarders(BATCH_SIZE=batch_size, raw_samples=captcha_generated)

# %%
class NoiseNet(nn.Module):

    def __init__(self, img_size, out_size = 1):
        """
        Network for learning noise in a captcha
        """
        super(NoiseNet, self).__init__()
        
        self.img_size = img_size
        self.fc0 = nn.Linear(img_size[0] * img_size[1], img_size[0] * img_size[1])
        self.fc1 = nn.Linear(img_size[0] * img_size[1], 1024)

        self.fc21 = nn.Linear(1024, out_size)
        self.fc22 = nn.Linear(1024, out_size)
        self.softplus = nn.Softplus()
    
    def forward(self, img):
        img = img.reshape(-1, self.img_size[0] * self.img_size[1])
        hidden = F.relu(self.fc0(img))
        hidden = self.fc1(hidden)
        # mean of noise, used in normal distribution
        mean =  torch.tanh(self.fc21(F.relu(hidden)))
        # std used in normal distribution
        sigma = self.softplus(self.fc22(F.relu(hidden)))
        return mean, sigma

# %%
class NumNet(nn.Module):
    def __init__(self, img_size, out_size = 3):
        """
        Network for learning N, number of letters in a captcha
        """
        super(NumNet, self).__init__()
        self.neural_net = nn.Sequential(
            nn.Linear(img_size[0] * img_size[1], img_size[0] * img_size[1] * 2),
            nn.ReLU(),
            nn.Linear(img_size[0] * img_size[1] * 2, 256),
            nn.ReLU(),
            nn.Linear(256, out_size),
            nn.LogSoftmax(dim=1))
  
    def forward(self, img):
        img = torch.reshape(img, (img.shape[0], img.shape[1] * img.shape[2]))
        prob = self.neural_net(img)
        return prob

# %%
class CharNetSingle(nn.Module):
    def __init__(self, img_size, output_size, hidden_size=512, N_num_class=10, input_size=1024, num_layers=1):
        """
        Network for letters in a captcha, given the noise and number of letters
        """
        super(CharNetSingle, self).__init__()
        self.img_size = img_size
        self.N_num_class = N_num_class
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.input_size = input_size
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, nonlinearity='relu', dropout=0.2)
        
        # output proposal layers
        self.linear_layers = nn.ModuleList([nn.Linear(hidden_size, output_size) for i in range(N_num_class)])

        #self.dropout = nn.Dropout()
        
        # observe layers
        self.conv1 = nn.Conv2d(1, 32, 3)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.pfc1 = nn.Linear(8832, 2048)
        self.pfc2 = nn.Linear(2048, 1024)
        self.convBN1 = nn.BatchNorm2d(32)
        self.convBN2 = nn.BatchNorm2d(64)
        self.h_0 = nn.Parameter(torch.zeros(self.num_layers, 1, self.hidden_size))
        #self.c_0 = nn.Parameter(torch.zeros(self.num_layers, 1, self.hidden_size)) # define if use LSTM

    def forward(self, img, N, noise_batched):
        BATCH_SIZE = img.shape[0]
        i = torch.arange(0, int(N))
        if USE_CUDA:
            i = i.cuda()
        i_onehot = F.one_hot(i, num_classes=self.N_num_class).float() # one hot format of N and index of letter
        i_onehot = torch.reshape(i_onehot, (N, 1, self.N_num_class)).repeat(1, BATCH_SIZE, 1)
        N_onehot = F.one_hot(N-1, num_classes=self.N_num_class).repeat(N, BATCH_SIZE, 1).float()
        
        # observe layers
        img = torch.reshape(img, (BATCH_SIZE, 1, self.img_size[0], self.img_size[1]))

        img = self.pool(F.relu(self.convBN1(self.conv1(img))))
        img = self.pool(F.relu(self.convBN2(self.conv2(img))))
        
        img = torch.reshape(img, (BATCH_SIZE, 8832))

        img = F.relu(self.pfc1(img))
        
        img = F.relu(self.pfc2(img))
        
        img = torch.reshape(img, (1, BATCH_SIZE, 1024))
        
        img = img.repeat(N, 1, 1)
        
        # cat observed images, N, i and noise 
        noise_batched = noise_batched.repeat(N, 1, 1)

        x = torch.cat((img, N_onehot, i_onehot, noise_batched), dim=2)
        x = torch.reshape(x, (N, BATCH_SIZE, self.input_size))

        h_0_contig = self.h_0.expand(self.num_layers, BATCH_SIZE, self.hidden_size).contiguous()

        outputs, hn = self.rnn(x, h_0_contig)
        
        # probosal layer, map to output shape
        outputs = torch.stack([self.linear_layers[i](outputs[i]) for i in range(outputs.shape[0])])

        outputs = F.log_softmax(outputs, dim=2)
        
        # transpose to <Batch, Length of Sequence, Character Space>
        outputs = torch.transpose(outputs, 0, 1)
        
        return outputs

# %%
def inference(t, use_cuda=False):
    """
    one epoch of inference (iterate the training set once)
    """
    loss = 0
    length = TrainingSample
    loss_group = []
    all_batches = make_batches(TrainLoaders)
    for i_batch, sample_batched in enumerate(all_batches):
        
        img = sample_batched[1]
        if use_cuda:
            img = img.cuda()
        IMG = {"captcha" : img}
        imme_loss = csis.step(observations=IMG)
        loss += imme_loss / length

    print("loss at epoch {} is {}".format(t, loss))
    return loss

# %%
def test(n = 0, use_train=False, verbose=False, use_cuda=False):
    """
    benchmarking performance on customized or training set
    """
    if use_train:
        TestLoaders = make_loarders(BATCH_SIZE=1, raw_samples=captcha_generated)
    else:
        test_captcha_generated = generate_random_captcha(n, save=False)
        TestLoaders = make_loarders(BATCH_SIZE=1, raw_samples=test_captcha_generated)
    
    total_correct = 0
    char_correct = 0
    total_char = 0
    all_batches = make_batches(TestLoaders)
    for i_batch, t in enumerate(all_batches):

        label = t[0][0]
        gt_noise = t[2][0]
        img = t[1]

        if use_cuda:
            img = img.cuda()
        
        IMG = {"captcha" : img}
        
        posterior = csis.run(observations=IMG)
        marginal_num = pyro.infer.EmpiricalMarginal(posterior, "num_char")
        marginal_noise = pyro.infer.EmpiricalMarginal(posterior, "noise")
        marginal_char = pyro.infer.EmpiricalMarginal(posterior, "chars")
        with torch.no_grad():

            N_index = marginal_num()
            noise = captchaModel._map_to_noise_range(marginal_noise()[0])
            char_indices = marginal_char()[0]
        
        N = N_index + captchaModel.num_char_domain[0]

        if use_cuda:
            char_indices.cpu()
        chars = ""
        for i in range(len(char_indices)):
            c = char_indices[i]
            chars +=  captchaModel.char_dict[c]
        correct = 0
        
        for p_char, t_char in zip(chars, label):
            if p_char == t_char:
                correct += 1
        if not verbose:
            print("N_predicted:", int(N), "| Actual N:", len(label), "| Predicted Noise:", round(float(noise), 3), "| Actual Noise:", round(float(gt_noise), 3), "| Predicted Text:", chars, "| Actual Text:", label, "| Correct:", correct)
        if correct == len(label) and int(N) == len(label):
            total_correct += 1
        char_correct += correct
        total_char += len(label)
    num_test_samples = i_batch + 1
    accuracy = total_correct / num_test_samples
    char_accuracy = char_correct / total_char
    print("use_train =", use_train, "Total correct:", total_correct, "accuracy:{}/{}=".format(total_correct, num_test_samples), accuracy, "char_accuracy:{}/{}=".format(char_correct, total_char), char_accuracy)

# %%
def test_cycle(use_cuda):
    
    # disable dropout
    #captchaModel.numNet.eval()
    #captchaModel.charNetSingle.eval()
    test(use_train=True, verbose=True, use_cuda=use_cuda)
    test(1000, use_train=False, verbose=True, use_cuda=use_cuda)
    #test(10, use_train=True, verbose=False, use_cuda=use_cuda)
    test(10, use_train=False, verbose=False, use_cuda=use_cuda)
    # enable dropout
    #captchaModel.numNet.train()
    #captchaModel.charNetSingle.train()

def optimize(use_cuda=False):
    """
    Training/Inferencing Stage
    """
    loss_sequence = []
    pause = 5
    print("Optimizing...")
    for t in range(1, num_steps + 1):
        L = inference(t, use_cuda)
        loss_sequence.append(L)
        if (t % pause == 0) and (t > 0):
            test_cycle(use_cuda=use_cuda)
    plt.plot(loss_sequence)
    plt.title("loss")
    plt.show()

# %%
class CaptchaModel(nn.Module):
    """
    network, model and guide wrapper class
    """
    def __init__(self, use_cuda=False):
        super().__init__()
        self.num_char_domain = torch.arange(MIN_N, MAX_N + 1)
        if use_cuda:
            self.num_char_domain = self.num_char_domain.cuda()

        self.numNet = NumNet((captchaHeight, captchaWidth), len(self.num_char_domain))
        self.noiseNet = NoiseNet((captchaHeight, captchaWidth), 1)
        self.char_dict = char_dict # letter dictionary
        self.rnn_hidden_size = 512
        self.rnn_num_layer = 2
        self.charNetSingle = CharNetSingle((captchaHeight, captchaWidth), len(self.char_dict), N_num_class=max(self.num_char_domain), input_size=1024 + max(self.num_char_domain) * 2 + 1, hidden_size=self.rnn_hidden_size, num_layers=self.rnn_num_layer)
        self.noise_constraint = torch.distributions.constraints.interval(MIN_NOISE, MAX_NOISE)
        if use_cuda:
            self.cuda()
        self.use_cuda = use_cuda
    
    def _map_to_noise_range(self, input):
        """
        map input number to the valid noise range
        """
        input = torch.distributions.transform_to(self.noise_constraint)(input)
        return input

    def guide(self, observations={"captcha": torch.rand(1, captchaHeight, captchaWidth)}):
        pyro.module("guide", self)
        img = observations["captcha"].float()
        
        # posterior to the number of letters
        prob = self.numNet(img)
        prob = torch.mean(prob, dim=0)
        N_index = pyro.sample("num_char", dist.Categorical(prob))
        N_index = torch.add(N_index, self.num_char_domain[0])
        
        with pyro.plate("data", img.shape[0]):
            
            # posterior to the noise
            noise_mean, noise_sig = self.noiseNet(img)
            noise_batch = pyro.sample("noise", dist.Normal(noise_mean, noise_sig).to_event(1))
            noise_batch = self._map_to_noise_range(noise_batch)
            
            # posterior to the characters, given number of letters and noise
            charP = self.charNetSingle(img, N_index, noise_batch)
            pyro.sample("chars", dist.Categorical(charP).to_event(1))
    
    def model(self, observations={"captcha": torch.rand(1, captchaHeight, captchaWidth)}):
        
        BS = observations["captcha"].shape[0]
        
        num_p = torch.tensor(1 / len(self.num_char_domain)).repeat(len(self.num_char_domain))
        
        if self.use_cuda:
            num_p = num_p.cuda()
        
        # sample the number of characters
        N_index = pyro.sample("num_char", dist.Categorical(num_p))
        N_index = torch.add(N_index,  self.num_char_domain[0])
        
        with pyro.plate("data", BS):
            
            noise_mean = torch.tensor((MAX_NOISE - MIN_NOISE) / 2).repeat((BS, 1))
            noise_sig = torch.tensor(0.5).repeat((BS, 1))

            if self.use_cuda:
                noise_mean = noise_mean.cuda()
                noise_sig = noise_sig.cuda()

            # sample the noise
            noise_batch = pyro.sample("noise", dist.Normal(noise_mean, noise_sig).to_event(1))
            noise_batch = self._map_to_noise_range(noise_batch)

            num_c = torch.tensor(1 / len(self.char_dict)).repeat((BS, N_index, len(self.char_dict)))
            if self.use_cuda:
                    num_c = num_c.cuda()
                    
            # sample the character indices
            c = pyro.sample("chars", dist.Categorical(num_c).to_event(1)) # maybe 2 here
            rendered_images = []
            for i in range(c.shape[0]):
                chars = ""
                for j in range(N_index):
                    chars += self.char_dict[c[i][j]]
        
                rendered_image = render_image(chars, noise=float(noise_batch[i]), use_cuda=self.use_cuda)
                rendered_images.append(rendered_image)
                
        rendered_images = torch.stack(rendered_images)
        sigma = torch.tensor(0.000001)
        if self.use_cuda:
                sigma = sigma.cuda()

        pyro.sample("captcha", dist.Normal(rendered_images, sigma).to_event(2), obs=observations["captcha"])

captchaModel = CaptchaModel(USE_CUDA)

optimiser = pyro.optim.Adam({'lr': 5e-5})
csis = pyro.infer.CSIS(captchaModel.model, captchaModel.guide, optimiser, num_inference_samples=1)


optimize(USE_CUDA)
test_cycle(USE_CUDA)
# Out:
# Optimizing...
# loss at epoch 1 is 7.652324084782588
# loss at epoch 2 is 5.662652781152718
# loss at epoch 3 is 4.3649084091544195
# loss at epoch 4 is 3.41767450749874
# loss at epoch 5 is 2.7851276388287554
# use_train = True Total correct: 936 accuracy:936/10000= 0.0936 char_accuracy:21164/40033= 0.5286638523218344
# use_train = False Total correct: 114 accuracy:114/1000= 0.114 char_accuracy:2142/4011= 0.5340314136125655
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.701 | Actual Noise: 0.597 | Predicted Text: 416 | Actual Text: 416 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.564 | Actual Noise: 0.436 | Predicted Text: 48662 | Actual Text: 43667 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.809 | Actual Noise: 0.799 | Predicted Text: 713 | Actual Text: 113 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.688 | Actual Noise: 0.883 | Predicted Text: 977 | Actual Text: 077 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.372 | Actual Noise: 0.199 | Predicted Text: 7021 | Actual Text: 2031 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.622 | Actual Noise: 0.61 | Predicted Text: 2635 | Actual Text: 2646 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.478 | Actual Noise: 0.492 | Predicted Text: 83357 | Actual Text: 73267 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.685 | Actual Noise: 0.645 | Predicted Text: 6179 | Actual Text: 8670 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.409 | Actual Noise: 0.402 | Predicted Text: 32087 | Actual Text: 32987 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.301 | Actual Noise: 0.035 | Predicted Text: 03912 | Actual Text: 10912 | Correct: 3
# use_train = False Total correct: 1 accuracy:1/10= 0.1 char_accuracy:24/41= 0.5853658536585366
# loss at epoch 6 is 2.3336954973071764
# loss at epoch 7 is 1.9941802085652967
# loss at epoch 8 is 1.7636978479173018
# loss at epoch 9 is 1.5686757263895115
# loss at epoch 10 is 1.3570718186623167
# use_train = True Total correct: 2424 accuracy:2424/10000= 0.2424 char_accuracy:27568/40033= 0.6886318787000725
# use_train = False Total correct: 232 accuracy:232/1000= 0.232 char_accuracy:2761/4017= 0.687328852377396
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.695 | Actual Noise: 0.626 | Predicted Text: 165 | Actual Text: 165 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.708 | Actual Noise: 0.661 | Predicted Text: 285 | Actual Text: 286 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.572 | Actual Noise: 0.581 | Predicted Text: 2715 | Actual Text: 2718 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.656 | Actual Noise: 0.793 | Predicted Text: 3871 | Actual Text: 3836 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.686 | Actual Noise: 0.702 | Predicted Text: 6701 | Actual Text: 6701 | Correct: 4
# N_predicted: 4 | Actual N: 3 | Predicted Noise: 0.372 | Actual Noise: 0.198 | Predicted Text: 9638 | Actual Text: 963 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.604 | Actual Noise: 0.638 | Predicted Text: 8546 | Actual Text: 8645 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.526 | Actual Noise: 0.523 | Predicted Text: 497 | Actual Text: 497 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.326 | Actual Noise: 0.05 | Predicted Text: 9616 | Actual Text: 0615 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.329 | Actual Noise: 0.977 | Predicted Text: 3427 | Actual Text: 2451 | Correct: 1
# use_train = False Total correct: 3 accuracy:3/10= 0.3 char_accuracy:25/36= 0.6944444444444444
# loss at epoch 11 is 1.1734613412912138
# loss at epoch 12 is 1.0313930406961818
# loss at epoch 13 is 0.8756011671437308
# loss at epoch 14 is 0.7352622197499282
# loss at epoch 15 is 0.6472798390275878
# use_train = True Total correct: 4111 accuracy:4111/10000= 0.4111 char_accuracy:31692/40033= 0.7916468913146654
# use_train = False Total correct: 439 accuracy:439/1000= 0.439 char_accuracy:3245/4007= 0.8098327926129274
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.498 | Actual Noise: 0.459 | Predicted Text: 802 | Actual Text: 302 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.319 | Actual Noise: 0.164 | Predicted Text: 448 | Actual Text: 446 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.3 | Actual Noise: 0.184 | Predicted Text: 4543 | Actual Text: 4642 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.428 | Actual Noise: 0.248 | Predicted Text: 60774 | Actual Text: 60771 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.679 | Actual Noise: 0.63 | Predicted Text: 0123 | Actual Text: 0123 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.564 | Actual Noise: 0.506 | Predicted Text: 4381 | Actual Text: 4381 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.419 | Actual Noise: 0.422 | Predicted Text: 303 | Actual Text: 303 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.489 | Actual Noise: 0.869 | Predicted Text: 1861 | Actual Text: 1861 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.305 | Actual Noise: 0.237 | Predicted Text: 844 | Actual Text: 844 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.445 | Actual Noise: 0.408 | Predicted Text: 79038 | Actual Text: 79038 | Correct: 5
# use_train = False Total correct: 6 accuracy:6/10= 0.6 char_accuracy:33/38= 0.868421052631579
# loss at epoch 16 is 0.588056195907081
# loss at epoch 17 is 0.4851780921642752
# loss at epoch 18 is 0.4090766534720897
# loss at epoch 19 is 0.33455576943672627
# loss at epoch 20 is 0.248361401419182
# use_train = True Total correct: 5319 accuracy:5319/10000= 0.5319 char_accuracy:33996/40033= 0.8491994104863487
# use_train = False Total correct: 532 accuracy:532/1000= 0.532 char_accuracy:3387/3978= 0.8514328808446455
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.554 | Actual Noise: 0.537 | Predicted Text: 9169 | Actual Text: 9150 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.757 | Actual Noise: 0.866 | Predicted Text: 5048 | Actual Text: 5048 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.839 | Actual Noise: 0.944 | Predicted Text: 360 | Actual Text: 360 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.485 | Actual Noise: 0.5 | Predicted Text: 4468 | Actual Text: 4068 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.379 | Actual Noise: 0.077 | Predicted Text: 9572 | Actual Text: 9672 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.458 | Actual Noise: 0.492 | Predicted Text: 002 | Actual Text: 002 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.359 | Actual Noise: 0.363 | Predicted Text: 29295 | Actual Text: 29295 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.372 | Actual Noise: 0.206 | Predicted Text: 1841 | Actual Text: 1841 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.905 | Actual Noise: 0.904 | Predicted Text: 0673 | Actual Text: 0653 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.657 | Actual Noise: 0.66 | Predicted Text: 545 | Actual Text: 545 | Correct: 3
# use_train = False Total correct: 6 accuracy:6/10= 0.6 char_accuracy:33/38= 0.868421052631579
# loss at epoch 21 is 0.17850161735000916
# loss at epoch 22 is 0.13761194693809253
# loss at epoch 23 is 0.06845330356125529
# loss at epoch 24 is -0.006475406878569999
# loss at epoch 25 is -0.08763151218464735
# use_train = True Total correct: 6551 accuracy:6551/10000= 0.6551 char_accuracy:35837/40033= 0.8951864711612919
# use_train = False Total correct: 671 accuracy:671/1000= 0.671 char_accuracy:3619/3999= 0.9049762440610153
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.338 | Actual Noise: 0.042 | Predicted Text: 679 | Actual Text: 629 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.978 | Actual Noise: 0.976 | Predicted Text: 50136 | Actual Text: 50186 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.321 | Actual Noise: 0.258 | Predicted Text: 1130 | Actual Text: 1139 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.75 | Actual Noise: 0.778 | Predicted Text: 463 | Actual Text: 463 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.682 | Actual Noise: 0.719 | Predicted Text: 90467 | Actual Text: 90467 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.318 | Actual Noise: 0.148 | Predicted Text: 6843 | Actual Text: 6840 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.758 | Actual Noise: 0.919 | Predicted Text: 986 | Actual Text: 936 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.346 | Actual Noise: 0.277 | Predicted Text: 9466 | Actual Text: 9466 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.737 | Actual Noise: 0.948 | Predicted Text: 84045 | Actual Text: 84035 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.454 | Actual Noise: 0.512 | Predicted Text: 8392 | Actual Text: 8392 | Correct: 4
# use_train = False Total correct: 4 accuracy:4/10= 0.4 char_accuracy:34/40= 0.85
# loss at epoch 26 is -0.1206952248741443
# loss at epoch 27 is -0.20807283231602125
# loss at epoch 28 is -0.1895003356775433
# loss at epoch 29 is -0.2390349505650367
# loss at epoch 30 is -0.26977122948991406
# use_train = True Total correct: 7008 accuracy:7008/10000= 0.7008 char_accuracy:36560/40033= 0.9132465715784478
# use_train = False Total correct: 707 accuracy:707/1000= 0.707 char_accuracy:3673/4012= 0.9155034895314058
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.414 | Actual Noise: 0.409 | Predicted Text: 9668 | Actual Text: 9668 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.614 | Actual Noise: 0.942 | Predicted Text: 51573 | Actual Text: 57573 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.297 | Actual Noise: 0.258 | Predicted Text: 2292 | Actual Text: 2292 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.597 | Actual Noise: 0.99 | Predicted Text: 947 | Actual Text: 947 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.494 | Actual Noise: 0.496 | Predicted Text: 65797 | Actual Text: 83797 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.982 | Actual Noise: 0.952 | Predicted Text: 744 | Actual Text: 744 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.546 | Actual Noise: 0.524 | Predicted Text: 5657 | Actual Text: 5656 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.337 | Actual Noise: 0.126 | Predicted Text: 520 | Actual Text: 520 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.751 | Actual Noise: 0.865 | Predicted Text: 335 | Actual Text: 336 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.258 | Actual Noise: 0.077 | Predicted Text: 7767 | Actual Text: 7757 | Correct: 3
# use_train = False Total correct: 5 accuracy:5/10= 0.5 char_accuracy:32/38= 0.8421052631578947
# loss at epoch 31 is -0.27408642027814845
# loss at epoch 32 is -0.30145580775860237
# loss at epoch 33 is -0.3278051666968422
# loss at epoch 34 is -0.3487543803757595
# loss at epoch 35 is -0.3840135273773932
# use_train = True Total correct: 7678 accuracy:7678/10000= 0.7678 char_accuracy:37416/40033= 0.9346289311318162
# use_train = False Total correct: 754 accuracy:754/1000= 0.754 char_accuracy:3728/4004= 0.9310689310689311
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.56 | Actual Noise: 0.895 | Predicted Text: 29910 | Actual Text: 29910 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.207 | Actual Noise: 0.926 | Predicted Text: 901 | Actual Text: 991 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.276 | Actual Noise: 0.163 | Predicted Text: 90940 | Actual Text: 90940 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.26 | Actual Noise: 0.207 | Predicted Text: 97182 | Actual Text: 97182 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.619 | Actual Noise: 0.574 | Predicted Text: 37843 | Actual Text: 37843 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.679 | Actual Noise: 0.618 | Predicted Text: 947 | Actual Text: 947 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.599 | Actual Noise: 0.907 | Predicted Text: 67445 | Actual Text: 67445 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.658 | Actual Noise: 0.661 | Predicted Text: 388 | Actual Text: 388 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.822 | Actual Noise: 0.854 | Predicted Text: 09907 | Actual Text: 09907 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.711 | Actual Noise: 0.708 | Predicted Text: 141 | Actual Text: 141 | Correct: 3
# use_train = False Total correct: 9 accuracy:9/10= 0.9 char_accuracy:41/42= 0.9761904761904762
# loss at epoch 36 is -0.4090251889249475
# loss at epoch 37 is -0.4207468991932282
# loss at epoch 38 is -0.4293398647991877
# loss at epoch 39 is -0.46596393298528793
# loss at epoch 40 is -0.47050037748436463
# use_train = True Total correct: 8036 accuracy:8036/10000= 0.8036 char_accuracy:37859/40033= 0.9456948017885245
# use_train = False Total correct: 809 accuracy:809/1000= 0.809 char_accuracy:3820/4025= 0.9490683229813665
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.356 | Actual Noise: 0.279 | Predicted Text: 04463 | Actual Text: 04463 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.728 | Actual Noise: 0.753 | Predicted Text: 11157 | Actual Text: 11057 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.652 | Actual Noise: 0.707 | Predicted Text: 798 | Actual Text: 798 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.288 | Actual Noise: 0.027 | Predicted Text: 3292 | Actual Text: 3292 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.74 | Actual Noise: 0.78 | Predicted Text: 513 | Actual Text: 513 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.307 | Actual Noise: 0.234 | Predicted Text: 94583 | Actual Text: 94533 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.45 | Actual Noise: 0.444 | Predicted Text: 4777 | Actual Text: 4777 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.377 | Actual Noise: 0.397 | Predicted Text: 6889 | Actual Text: 6889 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.309 | Actual Noise: 0.147 | Predicted Text: 4492 | Actual Text: 4492 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.45 | Actual Noise: 0.438 | Predicted Text: 92187 | Actual Text: 92187 | Correct: 5
# use_train = False Total correct: 8 accuracy:8/10= 0.8 char_accuracy:40/42= 0.9523809523809523
# loss at epoch 41 is -0.5033426823821369
# loss at epoch 42 is -0.5021769991942672
# loss at epoch 43 is -0.5365812366516642
# loss at epoch 44 is -0.551583374861208
# loss at epoch 45 is -0.5670446379572587
# use_train = True Total correct: 8110 accuracy:8110/10000= 0.811 char_accuracy:37928/40033= 0.9474183798366348
# use_train = False Total correct: 809 accuracy:809/1000= 0.809 char_accuracy:3819/4028= 0.9481132075471698
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.299 | Actual Noise: 0.258 | Predicted Text: 183 | Actual Text: 183 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.582 | Actual Noise: 0.967 | Predicted Text: 48426 | Actual Text: 48426 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.674 | Actual Noise: 0.639 | Predicted Text: 70235 | Actual Text: 70236 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.675 | Actual Noise: 0.708 | Predicted Text: 6095 | Actual Text: 6095 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.673 | Actual Noise: 0.684 | Predicted Text: 837 | Actual Text: 837 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.7 | Actual Noise: 0.769 | Predicted Text: 79632 | Actual Text: 79632 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.367 | Actual Noise: 0.324 | Predicted Text: 1253 | Actual Text: 1253 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.77 | Actual Noise: 0.756 | Predicted Text: 8424 | Actual Text: 8424 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.517 | Actual Noise: 0.476 | Predicted Text: 4779 | Actual Text: 4779 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.321 | Actual Noise: 0.181 | Predicted Text: 79694 | Actual Text: 79694 | Correct: 5
# use_train = False Total correct: 9 accuracy:9/10= 0.9 char_accuracy:41/42= 0.9761904761904762
# loss at epoch 46 is -0.5731181492650053
# loss at epoch 47 is -0.582596863116749
# loss at epoch 48 is -0.5777828022628384
# loss at epoch 49 is -0.6325888457322507
# loss at epoch 50 is -0.6459845491161502
# use_train = True Total correct: 8407 accuracy:8407/10000= 0.8407 char_accuracy:38310/40033= 0.9569605075812455
# use_train = False Total correct: 843 accuracy:843/1000= 0.843 char_accuracy:3863/4028= 0.9590367428003972
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.381 | Actual Noise: 0.353 | Predicted Text: 15407 | Actual Text: 15407 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.404 | Actual Noise: 0.381 | Predicted Text: 0103 | Actual Text: 0103 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.373 | Actual Noise: 0.348 | Predicted Text: 5440 | Actual Text: 5440 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.65 | Actual Noise: 0.653 | Predicted Text: 3396 | Actual Text: 3396 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.691 | Actual Noise: 0.629 | Predicted Text: 2044 | Actual Text: 2044 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.339 | Actual Noise: 0.264 | Predicted Text: 74628 | Actual Text: 74628 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.608 | Actual Noise: 0.586 | Predicted Text: 372 | Actual Text: 372 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.862 | Actual Noise: 0.815 | Predicted Text: 73351 | Actual Text: 13351 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.547 | Actual Noise: 0.549 | Predicted Text: 187 | Actual Text: 187 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.476 | Actual Noise: 0.485 | Predicted Text: 06259 | Actual Text: 06259 | Correct: 5
# use_train = False Total correct: 9 accuracy:9/10= 0.9 char_accuracy:41/42= 0.9761904761904762
# loss at epoch 51 is -0.651570275445384
# loss at epoch 52 is -0.6644189641519735
# loss at epoch 53 is -0.6956329365122592
# loss at epoch 54 is -0.6806983727250812
# loss at epoch 55 is -0.7444534548819761
# use_train = True Total correct: 8717 accuracy:8717/10000= 0.8717 char_accuracy:38649/40033= 0.9654285214697874
# use_train = False Total correct: 873 accuracy:873/1000= 0.873 char_accuracy:3891/4029= 0.9657483246463142
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.375 | Actual Noise: 0.362 | Predicted Text: 464 | Actual Text: 464 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.309 | Actual Noise: 0.085 | Predicted Text: 082 | Actual Text: 082 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.63 | Actual Noise: 0.631 | Predicted Text: 014 | Actual Text: 014 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.287 | Actual Noise: 0.125 | Predicted Text: 7553 | Actual Text: 7553 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.831 | Actual Noise: 0.853 | Predicted Text: 038 | Actual Text: 038 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.321 | Actual Noise: 0.172 | Predicted Text: 8945 | Actual Text: 2945 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.726 | Actual Noise: 0.737 | Predicted Text: 04091 | Actual Text: 04091 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.654 | Actual Noise: 0.795 | Predicted Text: 042 | Actual Text: 042 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.713 | Actual Noise: 0.814 | Predicted Text: 53017 | Actual Text: 53017 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.539 | Actual Noise: 0.556 | Predicted Text: 836 | Actual Text: 836 | Correct: 3
# use_train = False Total correct: 9 accuracy:9/10= 0.9 char_accuracy:35/36= 0.9722222222222222
# loss at epoch 56 is -0.7315650362521878
# loss at epoch 57 is -0.7531501643381768
# loss at epoch 58 is -0.7750814138135731
# loss at epoch 59 is -0.7668480726725511
# loss at epoch 60 is -0.7850447083807899
# use_train = True Total correct: 8726 accuracy:8726/10000= 0.8726 char_accuracy:38662/40033= 0.9657532535658082
# use_train = False Total correct: 854 accuracy:854/1000= 0.854 char_accuracy:3840/3993= 0.9616829451540195
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.415 | Actual Noise: 0.377 | Predicted Text: 49958 | Actual Text: 49958 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.337 | Actual Noise: 0.244 | Predicted Text: 86729 | Actual Text: 36729 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.765 | Actual Noise: 0.785 | Predicted Text: 89994 | Actual Text: 89924 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.905 | Actual Noise: 0.901 | Predicted Text: 704 | Actual Text: 704 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.297 | Actual Noise: 0.097 | Predicted Text: 0157 | Actual Text: 0157 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.436 | Actual Noise: 0.445 | Predicted Text: 58660 | Actual Text: 58660 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.23 | Actual Noise: 0.148 | Predicted Text: 503 | Actual Text: 503 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.607 | Actual Noise: 0.838 | Predicted Text: 453 | Actual Text: 453 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.646 | Actual Noise: 0.648 | Predicted Text: 953 | Actual Text: 953 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.263 | Actual Noise: 0.097 | Predicted Text: 461 | Actual Text: 461 | Correct: 3
# use_train = False Total correct: 8 accuracy:8/10= 0.8 char_accuracy:37/39= 0.9487179487179487
# loss at epoch 61 is -0.8026262728043091
# loss at epoch 62 is -0.7935716498915985
# loss at epoch 63 is -0.8228839893117388
# loss at epoch 64 is -0.8382440835431096
# loss at epoch 65 is -0.8378979617604937
# use_train = True Total correct: 8900 accuracy:8900/10000= 0.89 char_accuracy:38885/40033= 0.9713236579821647
# use_train = False Total correct: 903 accuracy:903/1000= 0.903 char_accuracy:3932/4037= 0.9739905870696062
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.289 | Actual Noise: 0.073 | Predicted Text: 57011 | Actual Text: 57011 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.296 | Actual Noise: 0.204 | Predicted Text: 065 | Actual Text: 065 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.314 | Actual Noise: 0.236 | Predicted Text: 8765 | Actual Text: 8765 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.46 | Actual Noise: 0.459 | Predicted Text: 3724 | Actual Text: 3724 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.293 | Actual Noise: 0.154 | Predicted Text: 22585 | Actual Text: 22585 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.733 | Actual Noise: 0.755 | Predicted Text: 2427 | Actual Text: 2427 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.62 | Actual Noise: 0.652 | Predicted Text: 9583 | Actual Text: 9583 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.561 | Actual Noise: 0.557 | Predicted Text: 5235 | Actual Text: 5235 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.332 | Actual Noise: 0.3 | Predicted Text: 2201 | Actual Text: 2201 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.341 | Actual Noise: 0.327 | Predicted Text: 17512 | Actual Text: 17512 | Correct: 5
# use_train = False Total correct: 10 accuracy:10/10= 1.0 char_accuracy:42/42= 1.0
# loss at epoch 66 is -0.8462019343102646
# loss at epoch 67 is -0.8534160058911424
# loss at epoch 68 is -0.8695735523777488
# loss at epoch 69 is -0.8430231186062849
# loss at epoch 70 is -0.8966239681645535
# use_train = True Total correct: 8959 accuracy:8959/10000= 0.8959 char_accuracy:38930/40033= 0.9724477306222367
# use_train = False Total correct: 890 accuracy:890/1000= 0.89 char_accuracy:3880/3997= 0.9707280460345259
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.263 | Actual Noise: 0.041 | Predicted Text: 87356 | Actual Text: 87356 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.284 | Actual Noise: 0.149 | Predicted Text: 793 | Actual Text: 793 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.808 | Actual Noise: 0.859 | Predicted Text: 59870 | Actual Text: 59870 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.448 | Actual Noise: 0.424 | Predicted Text: 23569 | Actual Text: 23569 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.437 | Actual Noise: 0.43 | Predicted Text: 461 | Actual Text: 461 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.334 | Actual Noise: 0.248 | Predicted Text: 8074 | Actual Text: 8074 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.639 | Actual Noise: 0.589 | Predicted Text: 4745 | Actual Text: 4745 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.597 | Actual Noise: 0.982 | Predicted Text: 27696 | Actual Text: 27696 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.683 | Actual Noise: 0.686 | Predicted Text: 436 | Actual Text: 436 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.878 | Actual Noise: 0.928 | Predicted Text: 06656 | Actual Text: 06656 | Correct: 5
# use_train = False Total correct: 10 accuracy:10/10= 1.0 char_accuracy:42/42= 1.0
# loss at epoch 71 is -0.8995414482354211
# loss at epoch 72 is -0.8946671105145821
# loss at epoch 73 is -0.9044934985081423
# loss at epoch 74 is -0.9199472002902012
# loss at epoch 75 is -0.9112544440109284
# use_train = True Total correct: 9048 accuracy:9048/10000= 0.9048 char_accuracy:39027/40033= 0.9748707316463917
# use_train = False Total correct: 907 accuracy:907/1000= 0.907 char_accuracy:3919/4016= 0.9758466135458167
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.406 | Actual Noise: 0.427 | Predicted Text: 6347 | Actual Text: 6647 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.482 | Actual Noise: 0.472 | Predicted Text: 993 | Actual Text: 993 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.348 | Actual Noise: 0.305 | Predicted Text: 8385 | Actual Text: 8385 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.722 | Actual Noise: 0.767 | Predicted Text: 6538 | Actual Text: 6538 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.989 | Actual Noise: 0.977 | Predicted Text: 938 | Actual Text: 938 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.3 | Actual Noise: 0.062 | Predicted Text: 38582 | Actual Text: 38582 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.362 | Actual Noise: 0.262 | Predicted Text: 7996 | Actual Text: 7996 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.49 | Actual Noise: 0.498 | Predicted Text: 5520 | Actual Text: 5520 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.645 | Actual Noise: 0.684 | Predicted Text: 7906 | Actual Text: 7906 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.762 | Actual Noise: 0.816 | Predicted Text: 0841 | Actual Text: 0841 | Correct: 4
# use_train = False Total correct: 9 accuracy:9/10= 0.9 char_accuracy:38/39= 0.9743589743589743
# loss at epoch 76 is -0.923463925924206
# loss at epoch 77 is -0.9373343699061603
# loss at epoch 78 is -0.9401342553493974
# loss at epoch 79 is -0.9472320473990928
# loss at epoch 80 is -0.9493764291874536
# use_train = True Total correct: 9052 accuracy:9052/10000= 0.9052 char_accuracy:39040/40033= 0.9751954637424125
# use_train = False Total correct: 903 accuracy:903/1000= 0.903 char_accuracy:3878/3982= 0.9738824711200402
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.32 | Actual Noise: 0.334 | Predicted Text: 90336 | Actual Text: 90336 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.322 | Actual Noise: 0.272 | Predicted Text: 8828 | Actual Text: 8828 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.622 | Actual Noise: 0.599 | Predicted Text: 997 | Actual Text: 997 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.361 | Actual Noise: 0.316 | Predicted Text: 6665 | Actual Text: 6665 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.712 | Actual Noise: 0.703 | Predicted Text: 31633 | Actual Text: 31633 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.214 | Actual Noise: 0.898 | Predicted Text: 7527 | Actual Text: 7527 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.439 | Actual Noise: 0.388 | Predicted Text: 4195 | Actual Text: 4195 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.821 | Actual Noise: 0.787 | Predicted Text: 44651 | Actual Text: 44651 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.745 | Actual Noise: 0.839 | Predicted Text: 59704 | Actual Text: 59704 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.272 | Actual Noise: 0.077 | Predicted Text: 82911 | Actual Text: 82911 | Correct: 5
# use_train = False Total correct: 10 accuracy:10/10= 1.0 char_accuracy:44/44= 1.0
# loss at epoch 81 is -0.9431340391517906
# loss at epoch 82 is -0.967838671654749
# loss at epoch 83 is -0.9489752643716276
# loss at epoch 84 is -0.9647503447696623
# loss at epoch 85 is -0.9718805715495255
# use_train = True Total correct: 9189 accuracy:9189/10000= 0.9189 char_accuracy:39180/40033= 0.9786925786226364
# use_train = False Total correct: 918 accuracy:918/1000= 0.918 char_accuracy:3929/4012= 0.9793120638085743
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.762 | Actual Noise: 0.788 | Predicted Text: 7852 | Actual Text: 7852 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.296 | Actual Noise: 0.207 | Predicted Text: 29580 | Actual Text: 29580 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.582 | Actual Noise: 0.578 | Predicted Text: 712 | Actual Text: 712 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.503 | Actual Noise: 0.514 | Predicted Text: 84242 | Actual Text: 84242 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.338 | Actual Noise: 0.267 | Predicted Text: 2878 | Actual Text: 2878 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.305 | Actual Noise: 0.235 | Predicted Text: 56269 | Actual Text: 56269 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.672 | Actual Noise: 0.664 | Predicted Text: 03815 | Actual Text: 03815 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.412 | Actual Noise: 0.392 | Predicted Text: 55329 | Actual Text: 55329 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.257 | Actual Noise: 0.209 | Predicted Text: 946 | Actual Text: 946 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.688 | Actual Noise: 0.676 | Predicted Text: 4864 | Actual Text: 4864 | Correct: 4
# use_train = False Total correct: 10 accuracy:10/10= 1.0 char_accuracy:43/43= 1.0
# loss at epoch 86 is -0.9731768232667344
# loss at epoch 87 is -0.9578569077253911
# loss at epoch 88 is -0.9759891374677662
# loss at epoch 89 is -0.9957763776023771
# loss at epoch 90 is -0.9934546713720156
# use_train = True Total correct: 9270 accuracy:9270/10000= 0.927 char_accuracy:39276/40033= 0.9810906002547898
# use_train = False Total correct: 926 accuracy:926/1000= 0.926 char_accuracy:3936/4014= 0.9805680119581465
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.674 | Actual Noise: 0.715 | Predicted Text: 8369 | Actual Text: 8369 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.051 | Actual Noise: 0.985 | Predicted Text: 3296 | Actual Text: 3296 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.613 | Actual Noise: 0.941 | Predicted Text: 88822 | Actual Text: 88822 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.259 | Actual Noise: 0.021 | Predicted Text: 7579 | Actual Text: 7579 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.509 | Actual Noise: 0.505 | Predicted Text: 53301 | Actual Text: 53351 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.533 | Actual Noise: 0.534 | Predicted Text: 479 | Actual Text: 479 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.362 | Actual Noise: 0.358 | Predicted Text: 38760 | Actual Text: 38760 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.638 | Actual Noise: 0.658 | Predicted Text: 0041 | Actual Text: 0041 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.197 | Actual Noise: 0.035 | Predicted Text: 160 | Actual Text: 160 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.281 | Actual Noise: 0.09 | Predicted Text: 20643 | Actual Text: 20643 | Correct: 5
# use_train = False Total correct: 9 accuracy:9/10= 0.9 char_accuracy:41/42= 0.9761904761904762
# loss at epoch 91 is -0.9912271994905277
# loss at epoch 92 is -0.9972249811497986
# loss at epoch 93 is -0.9914157086842573
# loss at epoch 94 is -0.9937132663133189
# loss at epoch 95 is -1.0060136960199715
# use_train = True Total correct: 9183 accuracy:9183/10000= 0.9183 char_accuracy:39169/40033= 0.9784178053106187
# use_train = False Total correct: 921 accuracy:921/1000= 0.921 char_accuracy:3911/3994= 0.9792188282423635
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.579 | Actual Noise: 0.56 | Predicted Text: 938 | Actual Text: 988 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.683 | Actual Noise: 0.684 | Predicted Text: 0857 | Actual Text: 0857 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.707 | Actual Noise: 0.791 | Predicted Text: 16916 | Actual Text: 16916 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.758 | Actual Noise: 0.748 | Predicted Text: 526 | Actual Text: 526 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.378 | Actual Noise: 0.35 | Predicted Text: 768 | Actual Text: 768 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.539 | Actual Noise: 0.539 | Predicted Text: 781 | Actual Text: 781 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.757 | Actual Noise: 0.783 | Predicted Text: 693 | Actual Text: 692 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.282 | Actual Noise: 0.184 | Predicted Text: 5179 | Actual Text: 5179 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.741 | Actual Noise: 0.887 | Predicted Text: 691 | Actual Text: 691 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.372 | Actual Noise: 0.379 | Predicted Text: 3533 | Actual Text: 3533 | Correct: 4
# use_train = False Total correct: 8 accuracy:8/10= 0.8 char_accuracy:33/35= 0.9428571428571428
# loss at epoch 96 is -1.001922168432403
# loss at epoch 97 is -0.999287355259357
# loss at epoch 98 is -1.0000033610159882
# loss at epoch 99 is -0.9939099993902719
# loss at epoch 100 is -1.0285617880414588
# use_train = True Total correct: 9290 accuracy:9290/10000= 0.929 char_accuracy:39298/40033= 0.981640146878825
# use_train = False Total correct: 905 accuracy:905/1000= 0.905 char_accuracy:3939/4036= 0.9759663032705649
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.515 | Actual Noise: 0.529 | Predicted Text: 17070 | Actual Text: 17070 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.591 | Actual Noise: 0.609 | Predicted Text: 376 | Actual Text: 676 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.33 | Actual Noise: 0.284 | Predicted Text: 059 | Actual Text: 059 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.54 | Actual Noise: 0.83 | Predicted Text: 13442 | Actual Text: 13442 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.678 | Actual Noise: 0.696 | Predicted Text: 6312 | Actual Text: 6312 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.437 | Actual Noise: 0.463 | Predicted Text: 27181 | Actual Text: 27181 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.298 | Actual Noise: 0.25 | Predicted Text: 186 | Actual Text: 186 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.425 | Actual Noise: 0.43 | Predicted Text: 07328 | Actual Text: 07328 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.254 | Actual Noise: 0.135 | Predicted Text: 551 | Actual Text: 551 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.304 | Actual Noise: 0.239 | Predicted Text: 7627 | Actual Text: 7627 | Correct: 4
# use_train = False Total correct: 9 accuracy:9/10= 0.9 char_accuracy:39/40= 0.975
# loss at epoch 101 is -1.0123697578863236
# loss at epoch 102 is -1.0272069317103127
# loss at epoch 103 is -1.018515942744433
# loss at epoch 104 is -1.0242519994458048
# loss at epoch 105 is -1.0402320460061563
# use_train = True Total correct: 9349 accuracy:9349/10000= 0.9349 char_accuracy:39366/40033= 0.9833387455349337
# use_train = False Total correct: 953 accuracy:953/1000= 0.953 char_accuracy:3947/3995= 0.9879849812265332
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.368 | Actual Noise: 0.375 | Predicted Text: 541 | Actual Text: 541 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.588 | Actual Noise: 0.605 | Predicted Text: 825 | Actual Text: 825 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.808 | Actual Noise: 0.794 | Predicted Text: 3370 | Actual Text: 3370 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.774 | Actual Noise: 0.904 | Predicted Text: 042 | Actual Text: 042 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.448 | Actual Noise: 0.472 | Predicted Text: 88352 | Actual Text: 88352 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.288 | Actual Noise: 0.055 | Predicted Text: 1923 | Actual Text: 1323 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.662 | Actual Noise: 0.77 | Predicted Text: 400 | Actual Text: 400 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.474 | Actual Noise: 0.47 | Predicted Text: 18937 | Actual Text: 18937 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.427 | Actual Noise: 0.432 | Predicted Text: 67279 | Actual Text: 67279 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.368 | Actual Noise: 0.391 | Predicted Text: 54283 | Actual Text: 54283 | Correct: 5
# use_train = False Total correct: 9 accuracy:9/10= 0.9 char_accuracy:39/40= 0.975
# loss at epoch 106 is -1.0220256583769332
# loss at epoch 107 is -1.0317413135854765
# loss at epoch 108 is -1.0414763257002462
# loss at epoch 109 is -1.029885166504184
# loss at epoch 110 is -1.031960799298058
# use_train = True Total correct: 9268 accuracy:9268/10000= 0.9268 char_accuracy:39262/40033= 0.9807408887667675
# use_train = False Total correct: 927 accuracy:927/1000= 0.927 char_accuracy:3916/3994= 0.9804707060590886
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.295 | Actual Noise: 0.188 | Predicted Text: 3041 | Actual Text: 3041 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.314 | Actual Noise: 0.954 | Predicted Text: 94987 | Actual Text: 94989 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.697 | Actual Noise: 0.648 | Predicted Text: 0363 | Actual Text: 0363 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.667 | Actual Noise: 0.652 | Predicted Text: 3050 | Actual Text: 3050 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.537 | Actual Noise: 0.563 | Predicted Text: 832 | Actual Text: 832 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.271 | Actual Noise: 0.134 | Predicted Text: 85582 | Actual Text: 85582 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.313 | Actual Noise: 0.18 | Predicted Text: 39252 | Actual Text: 39252 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.796 | Actual Noise: 0.848 | Predicted Text: 411 | Actual Text: 411 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.332 | Actual Noise: 0.279 | Predicted Text: 13322 | Actual Text: 13322 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.424 | Actual Noise: 0.428 | Predicted Text: 8884 | Actual Text: 8884 | Correct: 4
# use_train = False Total correct: 9 accuracy:9/10= 0.9 char_accuracy:41/42= 0.9761904761904762
