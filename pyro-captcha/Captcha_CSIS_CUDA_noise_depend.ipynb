# %% [markdown]
# uncomment if executing in google colab

# %%
# ! pip uninstall pyro-ppl
# ! pip install pyro-ppl==1.5.1
# ! unzip fonts.zip 
# ! unzip claptchagen.zip
# ! unzip csis
# ! cp csis.py /usr/local/lib/python3.7/dist-packages/pyro/infer

# %%
import random
import string
import os
import torch.nn as nn
import torch
import torch.nn.functional as F
import pyro
import numpy as np
import pyro.optim as optim
import pyro.distributions as dist
import pyro.infer
import pyro.optim

from torch.autograd import Variable
from pyro.infer import SVI, Trace_ELBO, TraceGraph_ELBO
from PIL import Image
from claptchagen.claptcha import Claptcha
from torch.distributions import constraints
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import matplotlib.pyplot as plt
print(pyro.__version__)

captcha_folder = 'generated_captchas'
captchaHeight = 32
captchaWidth = 100
captchaMarginX = 4
captchaMarginY = 4
batch_size = 10

char_dict = string.digits
USE_CUDA = True
MAX_N = 5 # maximum number of letters in a captcha 
MIN_N = 3 # minimum number of letters in a captcha
MIN_NOISE = 0.01 # minimum noise
MAX_NOISE = 0.99 # maximum noise
smoke_test = False
num_steps = 200 if not smoke_test else 10
TrainingSample = 10000 if not smoke_test else 100 # number of captchas generated for training

def randomString():
    """
    return a string with <num_char> random letters
    """
    k = random.randint(MIN_N, MAX_N) # sample number of characters
    
    rndLetters = (random.choice(char_dict) for _ in range(k))
    
    pad_spaces = MAX_N - k # pad the string so the captcha is close to center
    space = " " * (pad_spaces // 2)
    
    return space + "".join(rndLetters) + space

def ramdomNoise():
    """
    return a float between MIN_NOISE, MAX_NOISE
    """
    return random.uniform(MIN_NOISE, MAX_NOISE)

def generate_random_captcha(n, save=False):
    """
    generate n random captchas,
    return a list of texts on the captchas
    """
    # Initialize Claptcha object with random text, FreeMono as font, of size
    # 100x30px, using bicubic resampling filter and adding a bit of white noise
    c = Claptcha(randomString, "fonts/FreeSans.ttf", (captchaWidth, captchaHeight), (captchaMarginX, captchaMarginY),
             resample=Image.BILINEAR, noise=0)
    captcha_generated = [ [] for i in range(MAX_N)]
    for i in range(n):
        c.noise = ramdomNoise()
        if save:
            text, _ = c.write(os.path.join(captcha_folder, 'captcha{}.png'.format(i)))
            os.rename(os.path.join(captcha_folder, 'captcha{}.png'.format(i)),os.path.join(captcha_folder, '{}.png'.format(text + "_" + str(i))))
        text, image = c.image
        text = text.strip()
        image = np.array(image)[:, :, 0] # the generator is gray scale, only keep one channel is enough
        captcha_generated[len(text) - 1].append((text, image, c.noise))
    return captcha_generated
    
captcha_generated = generate_random_captcha(TrainingSample, save=False)
for lst in captcha_generated:
    print("number of samples in group", len(lst))
    # print some sample captcha information generated
    for i, t in enumerate(lst):
        print("text", t[0], "captcha shape", t[1].shape, "noise", t[2])
        if i >= 10:
            break
# Out:
# 1.5.1
# number of samples in group 0
# number of samples in group 0
# number of samples in group 3273
# text 712 captcha shape (32, 100) noise 0.07700688312384003
# text 165 captcha shape (32, 100) noise 0.6417097229132835
# text 304 captcha shape (32, 100) noise 0.653944117614349
# text 450 captcha shape (32, 100) noise 0.6163655384342778
# text 618 captcha shape (32, 100) noise 0.5091439031458551
# text 140 captcha shape (32, 100) noise 0.7956781197637947
# text 673 captcha shape (32, 100) noise 0.7676395100780321
# text 507 captcha shape (32, 100) noise 0.5371319442523937
# text 109 captcha shape (32, 100) noise 0.8178013947826746
# text 205 captcha shape (32, 100) noise 0.8869671167845189
# text 145 captcha shape (32, 100) noise 0.4376002818901202
# number of samples in group 3301
# text 4098 captcha shape (32, 100) noise 0.6498733748989223
# text 7432 captcha shape (32, 100) noise 0.46272872063204656
# text 7525 captcha shape (32, 100) noise 0.8370499838880107
# text 8989 captcha shape (32, 100) noise 0.09074370774943236
# text 2527 captcha shape (32, 100) noise 0.4312622720454755
# text 4954 captcha shape (32, 100) noise 0.4904971269090123
# text 4293 captcha shape (32, 100) noise 0.5941443939190904
# text 8819 captcha shape (32, 100) noise 0.2758819083505586
# text 1272 captcha shape (32, 100) noise 0.45010533474726216
# text 2746 captcha shape (32, 100) noise 0.7076219671827296
# text 9538 captcha shape (32, 100) noise 0.5197787106330286
# number of samples in group 3426
# text 51644 captcha shape (32, 100) noise 0.4067818704534577
# text 12282 captcha shape (32, 100) noise 0.9889852169482205
# text 27359 captcha shape (32, 100) noise 0.9392799761225187
# text 50334 captcha shape (32, 100) noise 0.5721061340350582
# text 80865 captcha shape (32, 100) noise 0.7543088246939761
# text 06106 captcha shape (32, 100) noise 0.3189770185921101
# text 22556 captcha shape (32, 100) noise 0.6661730712005293
# text 54129 captcha shape (32, 100) noise 0.06767604641869106
# text 01272 captcha shape (32, 100) noise 0.8851149075273927
# text 16667 captcha shape (32, 100) noise 0.06482890942962782
# text 58163 captcha shape (32, 100) noise 0.858563191457763

# %%
def render_image(chars, fonts="fonts/FreeSans.ttf", size=(captchaWidth, captchaHeight), 
                 margin=(captchaMarginX, captchaMarginY), resample=Image.BILINEAR, noise=0.3, use_cuda=False):
    #noise = noise.data.item()
    #print(chars, noise)
    pad_spaces = MAX_N - len(chars)
    space = " " * (pad_spaces // 2)
    chars = space + chars + space
    render = Claptcha(chars, fonts, size, margin, resample=resample, noise=noise)

    
    _ , rendered_image = render.image
    rendered_image = np.array(rendered_image)[:,:,0] # the generator is gray scale, only keep one channel is enough
    rendered_image = np.subtract(np.divide(rendered_image, 255), 0.5)
    rendered_image = torch.from_numpy(rendered_image)
    if use_cuda:
        rendered_image = rendered_image.cuda()
    return rendered_image

# %%
class CaptchaDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, raw_captchas, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.raw_captchas = raw_captchas
        self.transform = transform

    def __len__(self):
        return len(self.raw_captchas)

    def __getitem__(self, idx):
        label = self.raw_captchas[idx][0]
        image = self.raw_captchas[idx][1]
        noise = self.raw_captchas[idx][2]
        
        image = np.subtract(np.divide(image, 255), 0.5)
        image = torch.from_numpy(image).float()

        if self.transform:
            image = self.transform(image)

        return label, image, noise

# %%
def make_loarders(BATCH_SIZE, raw_samples):
    dataloaders = [] # dataloaders for different num of char
    for lst in raw_samples:
        if lst:
            ds = CaptchaDataset(lst)
            dataloader = DataLoader(ds, batch_size=BATCH_SIZE,
                                    shuffle=True, num_workers=0, drop_last=True)
            dataloaders.append(dataloader)
    return dataloaders

def make_batches(dataloaders):
    all_batches = []
    for dl in dataloaders:
        for i_batch, sample in enumerate(dl):
            all_batches.append(sample)
    random.shuffle(all_batches)
    random.shuffle(all_batches)
    return all_batches

TrainLoaders = make_loarders(BATCH_SIZE=batch_size, raw_samples=captcha_generated)

# %%
class NoiseNet(nn.Module):

    def __init__(self, img_size, out_size = 1):
        """
        Network for learning noise in a captcha
        """
        super(NoiseNet, self).__init__()
        
        self.img_size = img_size
        self.fc0 = nn.Linear(img_size[0] * img_size[1], img_size[0] * img_size[1])
        self.fc1 = nn.Linear(img_size[0] * img_size[1], 1024)
        
        self.fc2 = nn.Linear(1024, 1024)
        self.fc20 = nn.Linear(1024, img_size[0] * img_size[1])
        self.fc21 = nn.Linear(img_size[0] * img_size[1], out_size)
        self.softplus = nn.Softplus()
    
    def forward(self, img):
        BS = img.shape[0]
        img = img.reshape(-1, self.img_size[0] * self.img_size[1])
        hidden = F.relu(self.fc0(img))
        hidden = self.fc1(hidden)
        # mean of noise, used in normal distribution
        noise_map = self.fc20(F.relu(self.fc2(F.relu(hidden))))
        mean =  self.fc21(F.relu(noise_map))
        # std used in normal distribution
        sigma = torch.tensor([[1e-8] for _ in range(BS)]).float()
        if USE_CUDA:
            sigma = sigma.cuda()
        return mean, sigma, noise_map

# %%
class NumNet(nn.Module):
    def __init__(self, img_size, out_size = 3):
        """
        Network for learning N, number of letters in a captcha
        """
        super(NumNet, self).__init__()
        self.neural_net = nn.Sequential(
            nn.Linear(img_size[0] * img_size[1], img_size[0] * img_size[1] * 2),
            nn.ReLU(),
            nn.Linear(img_size[0] * img_size[1] * 2, 256),
            nn.ReLU(),
            nn.Linear(256, out_size),
            nn.LogSoftmax(dim=1))
  
    def forward(self, img):
        img = torch.reshape(img, (img.shape[0], img.shape[1] * img.shape[2]))
        prob = self.neural_net(img)
        return prob

# %%
class CharNetSingle(nn.Module):
    def __init__(self, img_size, output_size, MAX_N):
        """
        Network for letters in a captcha, given the noise and number of letters
        """
        super(CharNetSingle, self).__init__()
        self.img_size = img_size
        
        # observe layers
        self.nnfc = nn.Linear(img_size[0] * img_size[1], img_size[0] * img_size[1])
        self.conv1 = nn.Conv2d(1, 64, 3)
        self.conv2 = nn.Conv2d(64, 64, 3)
        self.conv3 = nn.Conv2d(64, 64, 3)
        self.pool = nn.MaxPool2d(2, 2)
        
        # branches
        self.pfc1s = nn.ModuleList([nn.Linear(1280, 2048) for i in range(MAX_N)])
        self.pfc2s = nn.ModuleList([nn.Linear(2048, 1024) for i in range(MAX_N)])
        self.pfc3s = nn.ModuleList([nn.Linear(1024, 1024) for i in range(MAX_N)])
        self.pfc4s = nn.ModuleList([nn.Linear(1024, output_size) for i in range(MAX_N)])
        
        self.convBN1 = nn.BatchNorm2d(64)
        self.convBN2 = nn.BatchNorm2d(64)
        self.convBN3 = nn.BatchNorm2d(64)

    def forward(self, img, i, noise_map):
        
        BATCH_SIZE = img.shape[0]
        # feed the noise_map to a linear layer to tune the values
        noise_map = F.relu(self.nnfc(noise_map))
        noise_map = torch.reshape(noise_map, (BATCH_SIZE, 1, self.img_size[0], self.img_size[1]))
    
        img = torch.reshape(img, (BATCH_SIZE, 1, self.img_size[0], self.img_size[1]))
        # compute the difference between original image and noise map
        # i.e. extract the unnoisy image
        img = torch.sub(img, noise_map)

        img = self.pool(F.relu(self.convBN1(self.conv1(img))))
        img = self.pool(F.relu(self.convBN2(self.conv2(img))))
        img = self.pool(F.relu(self.convBN3(self.conv3(img))))
        
        img = torch.reshape(img, (BATCH_SIZE, 1280))
        
        # i is the index of character, use different layers for different indicies
        out = F.relu(self.pfc1s[i](img))
        out = F.relu(self.pfc2s[i](out))
        out = F.relu(self.pfc3s[i](out))
        out = self.pfc4s[i](out)
        out = F.log_softmax(out, dim=1)
        
        return out

# %%
def inference(t, use_cuda=False):
    """
    one epoch of inference (iterate the training set once)
    """
    loss = 0
    length = TrainingSample
    loss_group = []
    all_batches = make_batches(TrainLoaders)
    for i_batch, sample_batched in enumerate(all_batches):
        
        img = sample_batched[1]
        if use_cuda:
            img = img.cuda()
        IMG = {"captcha" : img}
        imme_loss = csis.step(observations=IMG)
        loss += imme_loss / length

    print("loss at epoch {} is {}".format(t, loss))
    return loss

# %%
def test(n = 0, use_train=False, verbose=False, use_cuda=False):
    """
    benchmarking performance on customized or training set
    """
    if use_train:
        TestLoaders = make_loarders(BATCH_SIZE=1, raw_samples=captcha_generated)
    else:
        test_captcha_generated = generate_random_captcha(n, save=False)
        TestLoaders = make_loarders(BATCH_SIZE=1, raw_samples=test_captcha_generated)
    
    total_correct = 0
    char_correct = 0
    total_char = 0
    all_batches = make_batches(TestLoaders)
    noise_difference = 0
    for i_batch, t in enumerate(all_batches):

        label = t[0][0]
        gt_noise = t[2][0]
        img = t[1]

        if use_cuda:
            img = img.cuda()
        
        IMG = {"captcha" : img}
        
        posterior = csis.run(observations=IMG)
        marginal_num = pyro.infer.EmpiricalMarginal(posterior, "num_char")
        marginal_noise = pyro.infer.EmpiricalMarginal(posterior, "noise")
        with torch.no_grad():

            N_index = marginal_num()
            N = N_index + captchaModel.num_char_domain[0]
            noise = captchaModel._map_to_noise_range(marginal_noise()[0])
            sampled_chars = []
            
            # sample characters one by one
            for i in range(N):
                marginal_char = pyro.infer.EmpiricalMarginal(posterior, "char_{}".format(i))()[0]
                if use_cuda:
                    marginal_char.cpu()
                sampled_chars.append(marginal_char)
        
        chars = ""
        for i in range(len(sampled_chars)):
            c = sampled_chars[i]
            chars +=  captchaModel.char_dict[c]
        correct = 0
        
        for p_char, t_char in zip(chars, label):
            if p_char == t_char:
                correct += 1
        noise_difference += abs(float(noise) - float(gt_noise))
        if not verbose:
            print("N_predicted:", int(N), "| Actual N:", len(label), "| Predicted Noise:", round(float(noise), 3), "| Actual Noise:", round(float(gt_noise), 3), "| Predicted Text:", chars, "| Actual Text:", label, "| Correct:", correct)
        if correct == len(label) and int(N) == len(label):
            total_correct += 1
        char_correct += correct
        total_char += len(label)
    num_test_samples = i_batch + 1
    accuracy = total_correct / num_test_samples
    char_accuracy = char_correct / total_char
    noise_difference = noise_difference / num_test_samples
    print("use_train =", use_train, "AVG Noise Difference:", noise_difference, "Total correct:", total_correct, "accuracy:{}/{}=".format(total_correct, num_test_samples), accuracy, "char_accuracy:{}/{}=".format(char_correct, total_char), char_accuracy)

# %%
def test_cycle(use_cuda):
    
    # disable dropout
    #captchaModel.numNet.eval()
    #captchaModel.charNetSingle.eval()
    test(use_train=True, verbose=True, use_cuda=use_cuda)
    test(1000, use_train=False, verbose=True, use_cuda=use_cuda)
    #test(10, use_train=True, verbose=False, use_cuda=use_cuda)
    test(10, use_train=False, verbose=False, use_cuda=use_cuda)
    # enable dropout
    #captchaModel.numNet.train()
    #captchaModel.charNetSingle.train()

def optimize(start_epoch=1, use_cuda=False):
    """
    Training/Inferencing Stage
    """
    loss_sequence = []
    pause = 5
    save_pause = 10
    print("Optimizing...")
    for t in range(start_epoch, num_steps + 1):
        L = inference(t, use_cuda)
        loss_sequence.append(L)
        if (t % pause == 0) and (t > 0):
            test_cycle(use_cuda=use_cuda)
        if (t % save_pause == 0) and (t > 0):
            save_and_download_checkpoints("branches-1-no-var-no-tanh_model.pt", "branches-1-no-var-no-tanh_optim.pt", "branches-1-no-var-no-tanh_param_store.pt")
    plt.plot(loss_sequence)
    plt.title("loss")
    plt.show()

# %%
# saves the model and optimizer states to disk
def save_checkpoint(currentModel, currentOptimzier, save_model, save_opt, save_param_store):
    print("saving model to %s..." % save_model)
    torch.save(currentModel.state_dict(), save_model)
    print("saving optimizer states to %s..." % save_opt)
    currentOptimzier.save(save_opt)
    print("saving pyro pram store states to %s..." % save_param_store)
    pyro.get_param_store().save(save_param_store)
    print("done saving checkpoints to disk.")

# loads the model and optimizer states from disk
def load_checkpoint(myModel, myOptimzer, load_model, load_opt, load_param_store):
    pyro.clear_param_store()
    print("loading model from %s..." % load_model)
    myModel.load_state_dict(torch.load(load_model))
    print("loading optimizer states from %s..." % load_opt)
    myOptimzer.load(load_opt)
    print("loading pyro pram store states from %s..." % load_param_store)
    pyro.get_param_store().load(load_param_store)
    print("done loading states.")
    pyro.module("guide", myModel, update_module_params=True)

def save_and_download_checkpoints(save_model, save_opt, save_param_store):
    save_checkpoint(captchaModel, optimiser, save_model, save_opt, save_param_store)

# %%
class CaptchaModel(nn.Module):
    """
    network, model and guide wrapper class
    """
    def __init__(self, use_cuda=False):
        super().__init__()
        self.num_char_domain = torch.arange(MIN_N, MAX_N + 1)
        if use_cuda:
            self.num_char_domain = self.num_char_domain.cuda()

        self.numNet = NumNet((captchaHeight, captchaWidth), len(self.num_char_domain))
        self.noiseNet = NoiseNet((captchaHeight, captchaWidth), 1)
        self.char_dict = char_dict # letter dictionary
        self.rnn_hidden_size = 512
        self.rnn_num_layer = 2
        self.charNet = CharNetSingle((captchaHeight, captchaWidth), len(self.char_dict), max(self.num_char_domain))
        self.noise_constraint = torch.distributions.constraints.interval(MIN_NOISE, MAX_NOISE)
        if use_cuda:
            self.cuda()
        self.use_cuda = use_cuda
    
    def _map_to_noise_range(self, input):
        """
        map input number to the valid noise range
        """
        input = torch.distributions.transform_to(self.noise_constraint)(input)
        return input

    def guide(self, observations={"captcha": torch.rand(1, captchaHeight, captchaWidth)}):
        pyro.module("guide", self)
        img = observations["captcha"].float()
        
        # posterior to the number of letters
        prob = self.numNet(img)
        prob = torch.mean(prob, dim=0)
        N_index = pyro.sample("num_char", dist.Categorical(prob))
        N_index = torch.add(N_index, self.num_char_domain[0])
        
        with pyro.plate("data", img.shape[0]):
            
            # posterior to the noise
            noise_mean, noise_sig, noise_map = self.noiseNet(img)
            noise_batch = pyro.sample("noise", dist.Normal(noise_mean, noise_sig).to_event(1))
            noise_batch = self._map_to_noise_range(noise_batch)
            
            for i in range(N_index):
                charP_i = self.charNet(img, i, noise_map)
                pyro.sample("char_{}".format(i), dist.Categorical(charP_i).to_event(0))
    
    def model(self, observations={"captcha": torch.rand(1, captchaHeight, captchaWidth)}):
        
        BS = observations["captcha"].shape[0]
        
        num_p = torch.tensor(1 / len(self.num_char_domain)).repeat(len(self.num_char_domain))
        
        if self.use_cuda:
            num_p = num_p.cuda()
        
        # sample the number of characters
        N_index = pyro.sample("num_char", dist.Categorical(num_p))
        N_index = torch.add(N_index,  self.num_char_domain[0])
        
        with pyro.plate("data", BS):
            
            noise_mean = torch.tensor((MAX_NOISE - MIN_NOISE) / 2).repeat((BS, 1))
            noise_sig = torch.tensor(0.5).repeat((BS, 1))

            if self.use_cuda:
                noise_mean = noise_mean.cuda()
                noise_sig = noise_sig.cuda()

            # sample the noise
            noise_batch = pyro.sample("noise", dist.Normal(noise_mean, noise_sig).to_event(1))
            noise_batch = self._map_to_noise_range(noise_batch)
            
            sampled_c = []
            for i in range(int(N_index)):
                num_c_i = torch.tensor(1 / len(self.char_dict)).repeat((BS, len(self.char_dict)))
                if self.use_cuda:
                    num_c_i = num_c_i.cuda()
                c_i = pyro.sample("char_{}".format(i), dist.Categorical(num_c_i).to_event(0))
                sampled_c.append(c_i)
            
            # sample characters
            rendered_images = []
            for i in range(sampled_c[0].shape[0]):
                chars = ""
                for j in range(N_index):
                    chars += self.char_dict[sampled_c[j][i]]
        
                rendered_image = render_image(chars, noise=float(noise_batch[i]), use_cuda=self.use_cuda)
                rendered_images.append(rendered_image)
                
        rendered_images = torch.stack(rendered_images)
        sigma = torch.tensor(0.000001)
        if self.use_cuda:
                sigma = sigma.cuda()

        pyro.sample("captcha", dist.Normal(rendered_images, sigma).to_event(2), obs=observations["captcha"])

captchaModel = CaptchaModel(USE_CUDA)

optimiser = pyro.optim.Adam({'lr': 5e-5})
csis = pyro.infer.CSIS(captchaModel.model, captchaModel.guide, optimiser, num_inference_samples=1)


optimize(1, USE_CUDA)
test_cycle(USE_CUDA)
# Out:
# Optimizing...
# loss at epoch 1 is 384602421597726.2
# loss at epoch 2 is 115936711219661.89
# loss at epoch 3 is 74578008164584.62
# loss at epoch 4 is 52703317903120.83
# loss at epoch 5 is 47238492778555.016
# use_train = True AVG Noise Difference: 0.036190565837183275 Total correct: 6265 accuracy:6265/10000= 0.6265 char_accuracy:35654/40153= 0.8879535775658107
# use_train = False AVG Noise Difference: 0.03659073389729798 Total correct: 640 accuracy:640/1000= 0.64 char_accuracy:3554/3971= 0.8949886678418535
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.898 | Actual Noise: 0.964 | Predicted Text: 6635 | Actual Text: 6655 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.876 | Actual Noise: 0.976 | Predicted Text: 420 | Actual Text: 420 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.866 | Actual Noise: 0.889 | Predicted Text: 94632 | Actual Text: 94632 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.859 | Actual Noise: 0.888 | Predicted Text: 9377 | Actual Text: 9377 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.236 | Actual Noise: 0.21 | Predicted Text: 329 | Actual Text: 399 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.4 | Actual Noise: 0.394 | Predicted Text: 265 | Actual Text: 265 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.439 | Actual Noise: 0.452 | Predicted Text: 151 | Actual Text: 151 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.752 | Actual Noise: 0.799 | Predicted Text: 93301 | Actual Text: 93301 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.844 | Actual Noise: 0.858 | Predicted Text: 6871 | Actual Text: 6871 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.17 | Actual Noise: 0.05 | Predicted Text: 631 | Actual Text: 631 | Correct: 3
# use_train = False AVG Noise Difference: 0.04443655133899787 Total correct: 8 accuracy:8/10= 0.8 char_accuracy:35/37= 0.9459459459459459
# loss at epoch 6 is 42832687216853.016
# loss at epoch 7 is 39566089804840.96
# loss at epoch 8 is 35718540693130.41
# loss at epoch 9 is 35975878214287.4
# loss at epoch 10 is 32694567989647.746
# use_train = True AVG Noise Difference: 0.03207418718947779 Total correct: 7903 accuracy:7903/10000= 0.7903 char_accuracy:37857/40153= 0.942818718402112
# use_train = False AVG Noise Difference: 0.03121082450797686 Total correct: 792 accuracy:792/1000= 0.792 char_accuracy:3750/3981= 0.9419743782969103
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.17 | Actual Noise: 0.06 | Predicted Text: 95373 | Actual Text: 95373 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.165 | Actual Noise: 0.048 | Predicted Text: 0046 | Actual Text: 0046 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.669 | Actual Noise: 0.676 | Predicted Text: 6951 | Actual Text: 6951 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.28 | Actual Noise: 0.268 | Predicted Text: 121 | Actual Text: 171 | Correct: 2
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.192 | Actual Noise: 0.098 | Predicted Text: 58442 | Actual Text: 58442 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.446 | Actual Noise: 0.428 | Predicted Text: 9109 | Actual Text: 9109 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.882 | Actual Noise: 0.957 | Predicted Text: 56743 | Actual Text: 56743 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.351 | Actual Noise: 0.357 | Predicted Text: 602 | Actual Text: 602 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.867 | Actual Noise: 0.898 | Predicted Text: 810 | Actual Text: 810 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.725 | Actual Noise: 0.741 | Predicted Text: 8504 | Actual Text: 8504 | Correct: 4
# use_train = False AVG Noise Difference: 0.04864821083475514 Total correct: 9 accuracy:9/10= 0.9 char_accuracy:39/40= 0.975
# saving model to branches-1-no-var-no-tanh_model.pt...
# saving optimizer states to branches-1-no-var-no-tanh_optim.pt...
# saving pyro pram store states to branches-1-no-var-no-tanh_param_store.pt...
# done saving checkpoints to disk.
# loss at epoch 11 is 32125760382645.03
# loss at epoch 12 is 30100819221610.504
# loss at epoch 13 is 30122988419914.113
# loss at epoch 14 is 28786043519696.914
# loss at epoch 15 is 26667778484417.344
# use_train = True AVG Noise Difference: 0.03041234561439483 Total correct: 8603 accuracy:8603/10000= 0.8603 char_accuracy:38639/40153= 0.9622942245909396
# use_train = False AVG Noise Difference: 0.03134356447644291 Total correct: 864 accuracy:864/1000= 0.864 char_accuracy:3888/4026= 0.9657228017883756
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.327 | Actual Noise: 0.307 | Predicted Text: 12695 | Actual Text: 12695 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.884 | Actual Noise: 0.937 | Predicted Text: 9366 | Actual Text: 9375 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.839 | Actual Noise: 0.862 | Predicted Text: 150 | Actual Text: 150 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.235 | Actual Noise: 0.195 | Predicted Text: 43612 | Actual Text: 43612 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.172 | Actual Noise: 0.055 | Predicted Text: 87666 | Actual Text: 87666 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.568 | Actual Noise: 0.551 | Predicted Text: 282 | Actual Text: 282 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.174 | Actual Noise: 0.066 | Predicted Text: 6504 | Actual Text: 6504 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.722 | Actual Noise: 0.725 | Predicted Text: 8366 | Actual Text: 8366 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.302 | Actual Noise: 0.296 | Predicted Text: 11819 | Actual Text: 11819 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.665 | Actual Noise: 0.682 | Predicted Text: 52132 | Actual Text: 52132 | Correct: 5
# use_train = False AVG Noise Difference: 0.04025537785994156 Total correct: 9 accuracy:9/10= 0.9 char_accuracy:41/43= 0.9534883720930233
# loss at epoch 16 is 25798870121447.395
# loss at epoch 17 is 26371695867605.773
# loss at epoch 18 is 25551517907523.965
# loss at epoch 19 is 25660512299044.023
# loss at epoch 20 is 24151187699361.395
# use_train = True AVG Noise Difference: 0.0299671943146176 Total correct: 8916 accuracy:8916/10000= 0.8916 char_accuracy:39002/40153= 0.9713346449829402
# use_train = False AVG Noise Difference: 0.02816582814995543 Total correct: 907 accuracy:907/1000= 0.907 char_accuracy:3905/4009= 0.9740583686704914
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.533 | Actual Noise: 0.531 | Predicted Text: 84365 | Actual Text: 84365 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.248 | Actual Noise: 0.232 | Predicted Text: 91710 | Actual Text: 91710 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.554 | Actual Noise: 0.537 | Predicted Text: 09273 | Actual Text: 09273 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.367 | Actual Noise: 0.351 | Predicted Text: 7776 | Actual Text: 7776 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.374 | Actual Noise: 0.372 | Predicted Text: 684 | Actual Text: 684 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.239 | Actual Noise: 0.22 | Predicted Text: 355 | Actual Text: 355 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.166 | Actual Noise: 0.035 | Predicted Text: 533 | Actual Text: 533 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.741 | Actual Noise: 0.706 | Predicted Text: 701 | Actual Text: 701 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.692 | Actual Noise: 0.68 | Predicted Text: 4612 | Actual Text: 4612 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.312 | Actual Noise: 0.309 | Predicted Text: 0849 | Actual Text: 0819 | Correct: 3
# use_train = False AVG Noise Difference: 0.02554385660995544 Total correct: 9 accuracy:9/10= 0.9 char_accuracy:38/39= 0.9743589743589743
# saving model to branches-1-no-var-no-tanh_model.pt...
# saving optimizer states to branches-1-no-var-no-tanh_optim.pt...
# saving pyro pram store states to branches-1-no-var-no-tanh_param_store.pt...
# done saving checkpoints to disk.
# loss at epoch 21 is 24054032267031.355
# loss at epoch 22 is 24804937107426.543
# loss at epoch 23 is 22582808824315.867
# loss at epoch 24 is 23653296961382.008
# loss at epoch 25 is 23770622294635.277
# use_train = True AVG Noise Difference: 0.028389160814599638 Total correct: 9124 accuracy:9124/10000= 0.9124 char_accuracy:39240/40153= 0.9772619729534531
# use_train = False AVG Noise Difference: 0.02899067939577088 Total correct: 903 accuracy:903/1000= 0.903 char_accuracy:3916/4016= 0.9750996015936255
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.732 | Actual Noise: 0.735 | Predicted Text: 497 | Actual Text: 497 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.912 | Actual Noise: 0.97 | Predicted Text: 104 | Actual Text: 104 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.387 | Actual Noise: 0.372 | Predicted Text: 451 | Actual Text: 451 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.224 | Actual Noise: 0.206 | Predicted Text: 70359 | Actual Text: 70359 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.592 | Actual Noise: 0.594 | Predicted Text: 317 | Actual Text: 317 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.191 | Actual Noise: 0.119 | Predicted Text: 69889 | Actual Text: 69889 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.514 | Actual Noise: 0.493 | Predicted Text: 422 | Actual Text: 422 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.156 | Actual Noise: 0.02 | Predicted Text: 50717 | Actual Text: 50717 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.672 | Actual Noise: 0.655 | Predicted Text: 1308 | Actual Text: 1308 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.627 | Actual Noise: 0.615 | Predicted Text: 1367 | Actual Text: 1367 | Correct: 4
# use_train = False AVG Noise Difference: 0.035412750366931714 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:38/38= 1.0
# loss at epoch 26 is 21796770315134.562
# loss at epoch 27 is 23991631834959.086
# loss at epoch 28 is 22303155294922.344
# loss at epoch 29 is 21544502692728.035
# loss at epoch 30 is 22061161451303.7
# use_train = True AVG Noise Difference: 0.0298063104204499 Total correct: 9222 accuracy:9222/10000= 0.9222 char_accuracy:39346/40153= 0.9799018753268747
# use_train = False AVG Noise Difference: 0.029101408070641772 Total correct: 920 accuracy:920/1000= 0.92 char_accuracy:3896/3982= 0.9784028126569563
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.804 | Actual Noise: 0.785 | Predicted Text: 75897 | Actual Text: 75897 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.253 | Actual Noise: 0.239 | Predicted Text: 93764 | Actual Text: 93764 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.28 | Actual Noise: 0.258 | Predicted Text: 14086 | Actual Text: 14086 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.82 | Actual Noise: 0.818 | Predicted Text: 5294 | Actual Text: 5222 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.258 | Actual Noise: 0.228 | Predicted Text: 1817 | Actual Text: 1817 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.886 | Actual Noise: 0.887 | Predicted Text: 425 | Actual Text: 425 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.877 | Actual Noise: 0.922 | Predicted Text: 1188 | Actual Text: 1188 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.637 | Actual Noise: 0.632 | Predicted Text: 5358 | Actual Text: 5358 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.466 | Actual Noise: 0.459 | Predicted Text: 8554 | Actual Text: 8554 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.822 | Actual Noise: 0.816 | Predicted Text: 1935 | Actual Text: 1935 | Correct: 4
# use_train = False AVG Noise Difference: 0.015198293190989693 Total correct: 9 accuracy:9/10= 0.9 char_accuracy:40/42= 0.9523809523809523
# saving model to branches-1-no-var-no-tanh_model.pt...
# saving optimizer states to branches-1-no-var-no-tanh_optim.pt...
# saving pyro pram store states to branches-1-no-var-no-tanh_param_store.pt...
# done saving checkpoints to disk.
# loss at epoch 31 is 21242249461524.066
# loss at epoch 32 is 21481446985957.41
# loss at epoch 33 is 21934048216429.355
# loss at epoch 34 is 21660712796369.703
# loss at epoch 35 is 20896045931154.65
# use_train = True AVG Noise Difference: 0.026285235773708938 Total correct: 9395 accuracy:9395/10000= 0.9395 char_accuracy:39526/40153= 0.9843847284138172
# use_train = False AVG Noise Difference: 0.02763166961091364 Total correct: 938 accuracy:938/1000= 0.938 char_accuracy:3933/3998= 0.9837418709354677
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.677 | Actual Noise: 0.66 | Predicted Text: 8248 | Actual Text: 8248 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.619 | Actual Noise: 0.593 | Predicted Text: 136 | Actual Text: 136 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.222 | Actual Noise: 0.198 | Predicted Text: 8749 | Actual Text: 8749 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.179 | Actual Noise: 0.101 | Predicted Text: 67861 | Actual Text: 67861 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.92 | Actual Noise: 0.986 | Predicted Text: 5984 | Actual Text: 5984 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.878 | Actual Noise: 0.896 | Predicted Text: 4354 | Actual Text: 4354 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.199 | Actual Noise: 0.152 | Predicted Text: 4814 | Actual Text: 4814 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.838 | Actual Noise: 0.845 | Predicted Text: 1191 | Actual Text: 1191 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.906 | Actual Noise: 0.939 | Predicted Text: 4547 | Actual Text: 4547 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.247 | Actual Noise: 0.252 | Predicted Text: 58934 | Actual Text: 58934 | Correct: 5
# use_train = False AVG Noise Difference: 0.03210520502227428 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:41/41= 1.0
# loss at epoch 36 is 21426743660052.465
# loss at epoch 37 is 20364533819611.54
# loss at epoch 38 is 20536719211102.207
# loss at epoch 39 is 20364900753263.84
# loss at epoch 40 is 20977930784499.305
# use_train = True AVG Noise Difference: 0.02547513408051563 Total correct: 9407 accuracy:9407/10000= 0.9407 char_accuracy:39537/40153= 0.9846586805469081
# use_train = False AVG Noise Difference: 0.02651664945456843 Total correct: 951 accuracy:951/1000= 0.951 char_accuracy:3975/4025= 0.9875776397515528
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.369 | Actual Noise: 0.361 | Predicted Text: 933 | Actual Text: 933 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.901 | Actual Noise: 0.947 | Predicted Text: 2124 | Actual Text: 2124 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.671 | Actual Noise: 0.675 | Predicted Text: 033 | Actual Text: 033 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.691 | Actual Noise: 0.688 | Predicted Text: 971 | Actual Text: 971 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.199 | Actual Noise: 0.151 | Predicted Text: 312 | Actual Text: 312 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.738 | Actual Noise: 0.726 | Predicted Text: 606 | Actual Text: 606 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.419 | Actual Noise: 0.424 | Predicted Text: 329 | Actual Text: 329 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.847 | Actual Noise: 0.855 | Predicted Text: 096 | Actual Text: 096 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.253 | Actual Noise: 0.24 | Predicted Text: 0624 | Actual Text: 0624 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.894 | Actual Noise: 0.916 | Predicted Text: 88357 | Actual Text: 88357 | Correct: 5
# use_train = False AVG Noise Difference: 0.01697401845783448 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:34/34= 1.0
# saving model to branches-1-no-var-no-tanh_model.pt...
# saving optimizer states to branches-1-no-var-no-tanh_optim.pt...
# saving pyro pram store states to branches-1-no-var-no-tanh_param_store.pt...
# done saving checkpoints to disk.
# loss at epoch 41 is 20617876237398.836
# loss at epoch 42 is 20136269441446.72
# loss at epoch 43 is 19839268932773.473
# loss at epoch 44 is 20640590472386.977
# loss at epoch 45 is 20143620735401.973
# use_train = True AVG Noise Difference: 0.026815302550521794 Total correct: 9406 accuracy:9406/10000= 0.9406 char_accuracy:39540/40153= 0.9847333947650238
# use_train = False AVG Noise Difference: 0.02785933482967463 Total correct: 948 accuracy:948/1000= 0.948 char_accuracy:3938/3993= 0.9862258953168044
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.449 | Actual Noise: 0.445 | Predicted Text: 76241 | Actual Text: 76241 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.869 | Actual Noise: 0.861 | Predicted Text: 88813 | Actual Text: 88813 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.385 | Actual Noise: 0.379 | Predicted Text: 398 | Actual Text: 398 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.639 | Actual Noise: 0.634 | Predicted Text: 9112 | Actual Text: 9112 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.306 | Actual Noise: 0.301 | Predicted Text: 241 | Actual Text: 241 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.342 | Actual Noise: 0.33 | Predicted Text: 932 | Actual Text: 932 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.632 | Actual Noise: 0.629 | Predicted Text: 868 | Actual Text: 868 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.542 | Actual Noise: 0.536 | Predicted Text: 11681 | Actual Text: 11681 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.827 | Actual Noise: 0.806 | Predicted Text: 8805 | Actual Text: 8805 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.705 | Actual Noise: 0.698 | Predicted Text: 52884 | Actual Text: 52884 | Correct: 5
# use_train = False AVG Noise Difference: 0.007569448031996567 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:40/40= 1.0
# loss at epoch 46 is 19891223098595.754
# loss at epoch 47 is 19834058420738.438
# loss at epoch 48 is 19449858442238.375
# loss at epoch 49 is 19505830076298.016
# loss at epoch 50 is 19697329645735.152
# use_train = True AVG Noise Difference: 0.025715820041213085 Total correct: 9481 accuracy:9481/10000= 0.9481 char_accuracy:39610/40153= 0.986476726521057
# use_train = False AVG Noise Difference: 0.025557473765450093 Total correct: 952 accuracy:952/1000= 0.952 char_accuracy:3939/3989= 0.9874655302080722
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.895 | Actual Noise: 0.935 | Predicted Text: 326 | Actual Text: 326 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.441 | Actual Noise: 0.451 | Predicted Text: 6755 | Actual Text: 6755 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.49 | Actual Noise: 0.499 | Predicted Text: 92642 | Actual Text: 92642 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.442 | Actual Noise: 0.461 | Predicted Text: 7060 | Actual Text: 7060 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.774 | Actual Noise: 0.784 | Predicted Text: 06305 | Actual Text: 06305 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.435 | Actual Noise: 0.442 | Predicted Text: 8825 | Actual Text: 8825 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.378 | Actual Noise: 0.386 | Predicted Text: 269 | Actual Text: 269 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.197 | Actual Noise: 0.17 | Predicted Text: 764 | Actual Text: 764 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.195 | Actual Noise: 0.151 | Predicted Text: 721 | Actual Text: 721 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.491 | Actual Noise: 0.486 | Predicted Text: 687 | Actual Text: 667 | Correct: 2
# use_train = False AVG Noise Difference: 0.017906846666669623 Total correct: 9 accuracy:9/10= 0.9 char_accuracy:36/37= 0.972972972972973
# saving model to branches-1-no-var-no-tanh_model.pt...
# saving optimizer states to branches-1-no-var-no-tanh_optim.pt...
# saving pyro pram store states to branches-1-no-var-no-tanh_param_store.pt...
# done saving checkpoints to disk.
# loss at epoch 51 is 19172311437449.65
# loss at epoch 52 is 19184584817082.348
# loss at epoch 53 is 19891538886223.445
# loss at epoch 54 is 19848068298899.453
# loss at epoch 55 is 19214539536675.63
# use_train = True AVG Noise Difference: 0.026328015091443727 Total correct: 9596 accuracy:9596/10000= 0.9596 char_accuracy:39740/40153= 0.9897143426394043
# use_train = False AVG Noise Difference: 0.025779137227883664 Total correct: 959 accuracy:959/1000= 0.959 char_accuracy:3987/4029= 0.9895755770662695
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.882 | Actual Noise: 0.92 | Predicted Text: 37125 | Actual Text: 37125 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.16 | Actual Noise: 0.036 | Predicted Text: 991 | Actual Text: 991 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.719 | Actual Noise: 0.705 | Predicted Text: 779 | Actual Text: 779 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.714 | Actual Noise: 0.71 | Predicted Text: 0976 | Actual Text: 0976 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.844 | Actual Noise: 0.879 | Predicted Text: 8290 | Actual Text: 8290 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.757 | Actual Noise: 0.76 | Predicted Text: 52787 | Actual Text: 52787 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.798 | Actual Noise: 0.79 | Predicted Text: 923 | Actual Text: 923 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.612 | Actual Noise: 0.611 | Predicted Text: 0247 | Actual Text: 0247 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.564 | Actual Noise: 0.542 | Predicted Text: 0979 | Actual Text: 0979 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.819 | Actual Noise: 0.823 | Predicted Text: 259 | Actual Text: 259 | Correct: 3
# use_train = False AVG Noise Difference: 0.025325390784941802 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:38/38= 1.0
# loss at epoch 56 is 19848617011707.887
# loss at epoch 57 is 18705669681020.938
# loss at epoch 58 is 19066981049630.695
# loss at epoch 59 is 19144186839446.31
# loss at epoch 60 is 19145843101165.168
# use_train = True AVG Noise Difference: 0.023716519103377298 Total correct: 9576 accuracy:9576/10000= 0.9576 char_accuracy:39712/40153= 0.989017009936991
# use_train = False AVG Noise Difference: 0.023372501553879675 Total correct: 954 accuracy:954/1000= 0.954 char_accuracy:3928/3978= 0.987430869783811
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.16 | Actual Noise: 0.074 | Predicted Text: 52202 | Actual Text: 52202 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.26 | Actual Noise: 0.261 | Predicted Text: 05733 | Actual Text: 05733 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.69 | Actual Noise: 0.677 | Predicted Text: 361 | Actual Text: 361 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.853 | Actual Noise: 0.87 | Predicted Text: 643 | Actual Text: 643 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.184 | Actual Noise: 0.127 | Predicted Text: 5572 | Actual Text: 5572 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.162 | Actual Noise: 0.059 | Predicted Text: 55086 | Actual Text: 55086 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.654 | Actual Noise: 0.666 | Predicted Text: 60743 | Actual Text: 60743 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.509 | Actual Noise: 0.512 | Predicted Text: 41742 | Actual Text: 41742 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.84 | Actual Noise: 0.849 | Predicted Text: 14853 | Actual Text: 14853 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.668 | Actual Noise: 0.656 | Predicted Text: 90630 | Actual Text: 90630 | Correct: 5
# use_train = False AVG Noise Difference: 0.03125590752808825 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:45/45= 1.0
# saving model to branches-1-no-var-no-tanh_model.pt...
# saving optimizer states to branches-1-no-var-no-tanh_optim.pt...
# saving pyro pram store states to branches-1-no-var-no-tanh_param_store.pt...
# done saving checkpoints to disk.
# loss at epoch 61 is 18731551909701.24
# loss at epoch 62 is 18392134858794.6
# loss at epoch 63 is 18520336186382.74
# loss at epoch 64 is 18869960354706.223
# loss at epoch 65 is 18686857280179.39
# use_train = True AVG Noise Difference: 0.025471220836572744 Total correct: 9521 accuracy:9521/10000= 0.9521 char_accuracy:39660/40153= 0.9877219634896521
# use_train = False AVG Noise Difference: 0.0239190462596666 Total correct: 948 accuracy:948/1000= 0.948 char_accuracy:3975/4030= 0.9863523573200993
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.203 | Actual Noise: 0.165 | Predicted Text: 69685 | Actual Text: 69685 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.686 | Actual Noise: 0.689 | Predicted Text: 50147 | Actual Text: 50147 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.201 | Actual Noise: 0.175 | Predicted Text: 71988 | Actual Text: 71988 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.166 | Actual Noise: 0.097 | Predicted Text: 281 | Actual Text: 281 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.489 | Actual Noise: 0.494 | Predicted Text: 881 | Actual Text: 881 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.783 | Actual Noise: 0.794 | Predicted Text: 575 | Actual Text: 575 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.905 | Actual Noise: 0.959 | Predicted Text: 216 | Actual Text: 216 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.214 | Actual Noise: 0.187 | Predicted Text: 196 | Actual Text: 196 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.911 | Actual Noise: 0.974 | Predicted Text: 7444 | Actual Text: 7444 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.849 | Actual Noise: 0.867 | Predicted Text: 3280 | Actual Text: 3280 | Correct: 4
# use_train = False AVG Noise Difference: 0.03148913427925417 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:38/38= 1.0
# loss at epoch 66 is 18960322096450.766
# loss at epoch 67 is 18693815762196.895
# loss at epoch 68 is 18618023385694.215
# loss at epoch 69 is 18140697833950.406
# loss at epoch 70 is 18577387431120.11
# use_train = True AVG Noise Difference: 0.022874215775074706 Total correct: 9513 accuracy:9513/10000= 0.9513 char_accuracy:39655/40153= 0.9875974397927926
# use_train = False AVG Noise Difference: 0.02161706253221982 Total correct: 958 accuracy:958/1000= 0.958 char_accuracy:3930/3975= 0.9886792452830189
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.833 | Actual Noise: 0.807 | Predicted Text: 0859 | Actual Text: 0859 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.346 | Actual Noise: 0.35 | Predicted Text: 0395 | Actual Text: 0395 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.901 | Actual Noise: 0.927 | Predicted Text: 3996 | Actual Text: 5996 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.189 | Actual Noise: 0.158 | Predicted Text: 769 | Actual Text: 769 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.281 | Actual Noise: 0.267 | Predicted Text: 98565 | Actual Text: 98565 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.709 | Actual Noise: 0.715 | Predicted Text: 821 | Actual Text: 821 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.347 | Actual Noise: 0.347 | Predicted Text: 957 | Actual Text: 957 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.235 | Actual Noise: 0.227 | Predicted Text: 2982 | Actual Text: 2982 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.162 | Actual Noise: 0.075 | Predicted Text: 2662 | Actual Text: 2662 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.179 | Actual Noise: 0.128 | Predicted Text: 23225 | Actual Text: 23225 | Correct: 5
# use_train = False AVG Noise Difference: 0.025332279520346657 Total correct: 9 accuracy:9/10= 0.9 char_accuracy:38/39= 0.9743589743589743
# saving model to branches-1-no-var-no-tanh_model.pt...
# saving optimizer states to branches-1-no-var-no-tanh_optim.pt...
# saving pyro pram store states to branches-1-no-var-no-tanh_param_store.pt...
# done saving checkpoints to disk.
# loss at epoch 71 is 18144825498153.793
# loss at epoch 72 is 18342399678008.543
# loss at epoch 73 is 18256254632093.25
# loss at epoch 74 is 17674830800879.617
# loss at epoch 75 is 19105602040443.69
# use_train = True AVG Noise Difference: 0.02274952108331614 Total correct: 9570 accuracy:9570/10000= 0.957 char_accuracy:39713/40153= 0.9890419146763629
# use_train = False AVG Noise Difference: 0.02394201657193676 Total correct: 970 accuracy:970/1000= 0.97 char_accuracy:3975/4006= 0.992261607588617
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.153 | Actual Noise: 0.052 | Predicted Text: 57640 | Actual Text: 57640 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.217 | Actual Noise: 0.205 | Predicted Text: 8568 | Actual Text: 8568 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.845 | Actual Noise: 0.869 | Predicted Text: 6176 | Actual Text: 6176 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.535 | Actual Noise: 0.523 | Predicted Text: 566 | Actual Text: 566 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.213 | Actual Noise: 0.186 | Predicted Text: 74271 | Actual Text: 74271 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.894 | Actual Noise: 0.903 | Predicted Text: 806 | Actual Text: 806 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.162 | Actual Noise: 0.089 | Predicted Text: 4886 | Actual Text: 4886 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.186 | Actual Noise: 0.165 | Predicted Text: 5483 | Actual Text: 5483 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.892 | Actual Noise: 0.907 | Predicted Text: 4447 | Actual Text: 4447 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.914 | Actual Noise: 0.952 | Predicted Text: 10454 | Actual Text: 10454 | Correct: 5
# use_train = False AVG Noise Difference: 0.03331528780991788 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:41/41= 1.0
# loss at epoch 76 is 18178733833984.402
# loss at epoch 77 is 17991538365733.27
# loss at epoch 78 is 17787378719326.195
# loss at epoch 79 is 17625085256309.15
# loss at epoch 80 is 18123702612341.543
# use_train = True AVG Noise Difference: 0.022505742374184807 Total correct: 9654 accuracy:9654/10000= 0.9654 char_accuracy:39802/40153= 0.9912584364804622
# use_train = False AVG Noise Difference: 0.023972164560634668 Total correct: 969 accuracy:969/1000= 0.969 char_accuracy:3953/3985= 0.991969887076537
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.622 | Actual Noise: 0.634 | Predicted Text: 624 | Actual Text: 624 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.547 | Actual Noise: 0.558 | Predicted Text: 60369 | Actual Text: 60369 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.649 | Actual Noise: 0.663 | Predicted Text: 711 | Actual Text: 711 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.365 | Actual Noise: 0.371 | Predicted Text: 22683 | Actual Text: 22683 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.832 | Actual Noise: 0.849 | Predicted Text: 62390 | Actual Text: 62390 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.365 | Actual Noise: 0.375 | Predicted Text: 00678 | Actual Text: 00678 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.199 | Actual Noise: 0.18 | Predicted Text: 505 | Actual Text: 505 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.841 | Actual Noise: 0.892 | Predicted Text: 00576 | Actual Text: 00576 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.828 | Actual Noise: 0.827 | Predicted Text: 0145 | Actual Text: 0145 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.211 | Actual Noise: 0.197 | Predicted Text: 006 | Actual Text: 006 | Correct: 3
# use_train = False AVG Noise Difference: 0.015373406808764794 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:41/41= 1.0
# saving model to branches-1-no-var-no-tanh_model.pt...
# saving optimizer states to branches-1-no-var-no-tanh_optim.pt...
# saving pyro pram store states to branches-1-no-var-no-tanh_param_store.pt...
# done saving checkpoints to disk.
# loss at epoch 81 is 18023871049865.598
# loss at epoch 82 is 17783121774477.305
# loss at epoch 83 is 17992048470845.04
# loss at epoch 84 is 17867742105278.867
# loss at epoch 85 is 18033811611621.785
# use_train = True AVG Noise Difference: 0.022157616458516327 Total correct: 9661 accuracy:9661/10000= 0.9661 char_accuracy:39800/40153= 0.9912086270017184
# use_train = False AVG Noise Difference: 0.02184383110474845 Total correct: 967 accuracy:967/1000= 0.967 char_accuracy:3925/3960= 0.9911616161616161
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.936 | Actual Noise: 0.986 | Predicted Text: 1982 | Actual Text: 1982 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.835 | Actual Noise: 0.875 | Predicted Text: 3430 | Actual Text: 3430 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.21 | Actual Noise: 0.206 | Predicted Text: 099 | Actual Text: 099 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.735 | Actual Noise: 0.738 | Predicted Text: 80641 | Actual Text: 80641 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.305 | Actual Noise: 0.316 | Predicted Text: 74025 | Actual Text: 74025 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.24 | Actual Noise: 0.23 | Predicted Text: 909 | Actual Text: 909 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.877 | Actual Noise: 0.905 | Predicted Text: 54276 | Actual Text: 54276 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.417 | Actual Noise: 0.422 | Predicted Text: 56315 | Actual Text: 56315 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.62 | Actual Noise: 0.634 | Predicted Text: 72560 | Actual Text: 72560 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.247 | Actual Noise: 0.238 | Predicted Text: 124 | Actual Text: 124 | Correct: 3
# use_train = False AVG Noise Difference: 0.017321781963688276 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:42/42= 1.0
# loss at epoch 86 is 17785086204615.05
# loss at epoch 87 is 17760002376623.71
# loss at epoch 88 is 17610600081758.613
# loss at epoch 89 is 17510113495718.295
# loss at epoch 90 is 18150043054610.836
# use_train = True AVG Noise Difference: 0.0225706236479137 Total correct: 9653 accuracy:9653/10000= 0.9653 char_accuracy:39791/40153= 0.9909844843473713
# use_train = False AVG Noise Difference: 0.021670787380034796 Total correct: 969 accuracy:969/1000= 0.969 char_accuracy:3958/3989= 0.9922286287290047
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.15 | Actual Noise: 0.049 | Predicted Text: 050 | Actual Text: 050 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.149 | Actual Noise: 0.033 | Predicted Text: 107 | Actual Text: 107 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.156 | Actual Noise: 0.067 | Predicted Text: 26062 | Actual Text: 26062 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.456 | Actual Noise: 0.467 | Predicted Text: 3140 | Actual Text: 3140 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.453 | Actual Noise: 0.456 | Predicted Text: 546 | Actual Text: 546 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.565 | Actual Noise: 0.558 | Predicted Text: 9262 | Actual Text: 9262 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.441 | Actual Noise: 0.445 | Predicted Text: 35411 | Actual Text: 35411 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.679 | Actual Noise: 0.697 | Predicted Text: 84618 | Actual Text: 84618 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.657 | Actual Noise: 0.656 | Predicted Text: 77052 | Actual Text: 77052 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.179 | Actual Noise: 0.132 | Predicted Text: 7065 | Actual Text: 7065 | Correct: 4
# use_train = False AVG Noise Difference: 0.039600921721168234 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:41/41= 1.0
# saving model to branches-1-no-var-no-tanh_model.pt...
# saving optimizer states to branches-1-no-var-no-tanh_optim.pt...
# saving pyro pram store states to branches-1-no-var-no-tanh_param_store.pt...
# done saving checkpoints to disk.
# loss at epoch 91 is 17517834541033.057
# loss at epoch 92 is 17724611218132.18
# loss at epoch 93 is 17598083747060.125
# loss at epoch 94 is 17548860272331.98
# loss at epoch 95 is 17448631653852.77
# use_train = True AVG Noise Difference: 0.022604851426144008 Total correct: 9706 accuracy:9706/10000= 0.9706 char_accuracy:39848/40153= 0.9924040544915698
# use_train = False AVG Noise Difference: 0.02295428879290181 Total correct: 965 accuracy:965/1000= 0.965 char_accuracy:3949/3987= 0.9904690243290695
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.648 | Actual Noise: 0.635 | Predicted Text: 6174 | Actual Text: 6174 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.326 | Actual Noise: 0.316 | Predicted Text: 6760 | Actual Text: 6760 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.553 | Actual Noise: 0.56 | Predicted Text: 65822 | Actual Text: 65822 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.173 | Actual Noise: 0.118 | Predicted Text: 01700 | Actual Text: 01700 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.342 | Actual Noise: 0.332 | Predicted Text: 42775 | Actual Text: 42776 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.316 | Actual Noise: 0.312 | Predicted Text: 4343 | Actual Text: 4343 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.897 | Actual Noise: 0.945 | Predicted Text: 316 | Actual Text: 316 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.141 | Actual Noise: 0.016 | Predicted Text: 41939 | Actual Text: 41939 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.633 | Actual Noise: 0.627 | Predicted Text: 08347 | Actual Text: 08347 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.395 | Actual Noise: 0.388 | Predicted Text: 196 | Actual Text: 196 | Correct: 3
# use_train = False AVG Noise Difference: 0.028274961829799432 Total correct: 9 accuracy:9/10= 0.9 char_accuracy:42/43= 0.9767441860465116
# loss at epoch 96 is 17349855185417.004
# loss at epoch 97 is 17164560296365.287
# loss at epoch 98 is 17345629692939.465
# loss at epoch 99 is 17182882710054.512
# loss at epoch 100 is 17442724266927.73
# use_train = True AVG Noise Difference: 0.02230801906484691 Total correct: 9674 accuracy:9674/10000= 0.9674 char_accuracy:39819/40153= 0.9916818170497845
# use_train = False AVG Noise Difference: 0.02455338937711734 Total correct: 966 accuracy:966/1000= 0.966 char_accuracy:3941/3978= 0.9906988436400201
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.366 | Actual Noise: 0.374 | Predicted Text: 37463 | Actual Text: 37463 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.337 | Actual Noise: 0.323 | Predicted Text: 936 | Actual Text: 936 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.19 | Actual Noise: 0.177 | Predicted Text: 7105 | Actual Text: 7105 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.164 | Actual Noise: 0.103 | Predicted Text: 265 | Actual Text: 265 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.628 | Actual Noise: 0.62 | Predicted Text: 19820 | Actual Text: 19820 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.886 | Actual Noise: 0.893 | Predicted Text: 090 | Actual Text: 090 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.608 | Actual Noise: 0.607 | Predicted Text: 52843 | Actual Text: 52843 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.135 | Actual Noise: 0.011 | Predicted Text: 2302 | Actual Text: 2302 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.681 | Actual Noise: 0.682 | Predicted Text: 28758 | Actual Text: 28758 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.272 | Actual Noise: 0.275 | Predicted Text: 504 | Actual Text: 504 | Correct: 3
# use_train = False AVG Noise Difference: 0.02399596974937515 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:40/40= 1.0
# saving model to branches-1-no-var-no-tanh_model.pt...
# saving optimizer states to branches-1-no-var-no-tanh_optim.pt...
# saving pyro pram store states to branches-1-no-var-no-tanh_param_store.pt...
# done saving checkpoints to disk.
# loss at epoch 101 is 17186714111456.049
# loss at epoch 102 is 17271516037926.086
# loss at epoch 103 is 16973456022405.137
# loss at epoch 104 is 17382468856302.814
# loss at epoch 105 is 17359197512518.861
# use_train = True AVG Noise Difference: 0.022345273991156295 Total correct: 9699 accuracy:9699/10000= 0.9699 char_accuracy:39844/40153= 0.9923044355340821
# use_train = False AVG Noise Difference: 0.023511232726109957 Total correct: 965 accuracy:965/1000= 0.965 char_accuracy:3942/3979= 0.9907011812013069
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.162 | Actual Noise: 0.094 | Predicted Text: 934 | Actual Text: 934 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.647 | Actual Noise: 0.654 | Predicted Text: 5120 | Actual Text: 5120 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.298 | Actual Noise: 0.3 | Predicted Text: 66892 | Actual Text: 66892 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.571 | Actual Noise: 0.585 | Predicted Text: 402 | Actual Text: 402 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.849 | Actual Noise: 0.854 | Predicted Text: 9516 | Actual Text: 9516 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.429 | Actual Noise: 0.425 | Predicted Text: 9903 | Actual Text: 9903 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.164 | Actual Noise: 0.088 | Predicted Text: 665 | Actual Text: 665 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.934 | Actual Noise: 0.982 | Predicted Text: 118 | Actual Text: 118 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.916 | Actual Noise: 0.966 | Predicted Text: 797 | Actual Text: 797 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.283 | Actual Noise: 0.286 | Predicted Text: 1686 | Actual Text: 1686 | Correct: 4
# use_train = False AVG Noise Difference: 0.027955654396297963 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:36/36= 1.0
# loss at epoch 106 is 17312723144291.133
# loss at epoch 107 is 17632140882385.297
# loss at epoch 108 is 17207377183755.46
# loss at epoch 109 is 17180257180018.29
# loss at epoch 110 is 17119732250037.45
# use_train = True AVG Noise Difference: 0.02184814312122425 Total correct: 9713 accuracy:9713/10000= 0.9713 char_accuracy:39856/40153= 0.992603292406545
# use_train = False AVG Noise Difference: 0.022459578156170747 Total correct: 977 accuracy:977/1000= 0.977 char_accuracy:3990/4013= 0.9942686269623723
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.326 | Actual Noise: 0.322 | Predicted Text: 33335 | Actual Text: 33335 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.693 | Actual Noise: 0.723 | Predicted Text: 0525 | Actual Text: 0525 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.743 | Actual Noise: 0.723 | Predicted Text: 12656 | Actual Text: 12656 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.793 | Actual Noise: 0.809 | Predicted Text: 398 | Actual Text: 398 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.531 | Actual Noise: 0.538 | Predicted Text: 775 | Actual Text: 775 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.334 | Actual Noise: 0.345 | Predicted Text: 151 | Actual Text: 151 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.141 | Actual Noise: 0.029 | Predicted Text: 891 | Actual Text: 891 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.256 | Actual Noise: 0.269 | Predicted Text: 3647 | Actual Text: 3647 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.203 | Actual Noise: 0.194 | Predicted Text: 6130 | Actual Text: 6130 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.374 | Actual Noise: 0.359 | Predicted Text: 65011 | Actual Text: 65011 | Correct: 5
# use_train = False AVG Noise Difference: 0.023801550251491766 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:39/39= 1.0
# saving model to branches-1-no-var-no-tanh_model.pt...
# saving optimizer states to branches-1-no-var-no-tanh_optim.pt...
# saving pyro pram store states to branches-1-no-var-no-tanh_param_store.pt...
# done saving checkpoints to disk.
# loss at epoch 111 is 17343271114794.594
# loss at epoch 112 is 17320687454086.746
# loss at epoch 113 is 17461189246163.342
# loss at epoch 114 is 17223541655823.986
# loss at epoch 115 is 16864718563285.408
# use_train = True AVG Noise Difference: 0.022068636852864004 Total correct: 9681 accuracy:9681/10000= 0.9681 char_accuracy:39827/40153= 0.9918810549647598
# use_train = False AVG Noise Difference: 0.022127114333261318 Total correct: 973 accuracy:973/1000= 0.973 char_accuracy:3969/3996= 0.9932432432432432
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.498 | Actual Noise: 0.484 | Predicted Text: 650 | Actual Text: 650 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.16 | Actual Noise: 0.078 | Predicted Text: 80716 | Actual Text: 80716 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.81 | Actual Noise: 0.822 | Predicted Text: 386 | Actual Text: 386 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.637 | Actual Noise: 0.643 | Predicted Text: 6497 | Actual Text: 6497 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.872 | Actual Noise: 0.86 | Predicted Text: 7561 | Actual Text: 7561 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.143 | Actual Noise: 0.016 | Predicted Text: 6790 | Actual Text: 6790 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.695 | Actual Noise: 0.695 | Predicted Text: 64630 | Actual Text: 64630 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.896 | Actual Noise: 0.909 | Predicted Text: 8907 | Actual Text: 8907 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.252 | Actual Noise: 0.254 | Predicted Text: 362 | Actual Text: 362 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.877 | Actual Noise: 0.896 | Predicted Text: 0709 | Actual Text: 0709 | Correct: 4
# use_train = False AVG Noise Difference: 0.028619170255816485 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:39/39= 1.0
# loss at epoch 116 is 16866524875502.379
# loss at epoch 117 is 17041388652068.871
# loss at epoch 118 is 16932193725474.396
# loss at epoch 119 is 17363180029411.348
# loss at epoch 120 is 17041792360447.982
# use_train = True AVG Noise Difference: 0.02407960319372086 Total correct: 9702 accuracy:9702/10000= 0.9702 char_accuracy:39849/40153= 0.9924289592309417
# use_train = False AVG Noise Difference: 0.02557380332441836 Total correct: 973 accuracy:973/1000= 0.973 char_accuracy:3918/3945= 0.9931558935361217
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.62 | Actual Noise: 0.63 | Predicted Text: 9599 | Actual Text: 9599 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.706 | Actual Noise: 0.73 | Predicted Text: 34650 | Actual Text: 34650 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.254 | Actual Noise: 0.271 | Predicted Text: 7775 | Actual Text: 7775 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.764 | Actual Noise: 0.775 | Predicted Text: 478 | Actual Text: 478 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.787 | Actual Noise: 0.813 | Predicted Text: 28718 | Actual Text: 28718 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.449 | Actual Noise: 0.447 | Predicted Text: 1410 | Actual Text: 1410 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.902 | Actual Noise: 0.95 | Predicted Text: 9227 | Actual Text: 9227 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.175 | Actual Noise: 0.136 | Predicted Text: 228 | Actual Text: 228 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.498 | Actual Noise: 0.511 | Predicted Text: 32457 | Actual Text: 32457 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.892 | Actual Noise: 0.924 | Predicted Text: 263 | Actual Text: 293 | Correct: 2
# use_train = False AVG Noise Difference: 0.022248205947381736 Total correct: 9 accuracy:9/10= 0.9 char_accuracy:39/40= 0.975
# saving model to branches-1-no-var-no-tanh_model.pt...
# saving optimizer states to branches-1-no-var-no-tanh_optim.pt...
# saving pyro pram store states to branches-1-no-var-no-tanh_param_store.pt...
# done saving checkpoints to disk.
# loss at epoch 121 is 16881204226424.832
# loss at epoch 122 is 16986322454675.479
# loss at epoch 123 is 16936781753443.945
# loss at epoch 124 is 16783471322208.67
# loss at epoch 125 is 16658188060085.418
# use_train = True AVG Noise Difference: 0.02187142770512952 Total correct: 9765 accuracy:9765/10000= 0.9765 char_accuracy:39911/40153= 0.9939730530719996
# use_train = False AVG Noise Difference: 0.020905875949800774 Total correct: 976 accuracy:976/1000= 0.976 char_accuracy:4030/4054= 0.9940799210656142
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.225 | Actual Noise: 0.232 | Predicted Text: 4118 | Actual Text: 4118 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.696 | Actual Noise: 0.691 | Predicted Text: 59454 | Actual Text: 59454 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.386 | Actual Noise: 0.394 | Predicted Text: 72705 | Actual Text: 72705 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.807 | Actual Noise: 0.808 | Predicted Text: 803 | Actual Text: 803 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.711 | Actual Noise: 0.711 | Predicted Text: 835 | Actual Text: 835 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.151 | Actual Noise: 0.059 | Predicted Text: 3052 | Actual Text: 3052 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.611 | Actual Noise: 0.617 | Predicted Text: 9693 | Actual Text: 9693 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.174 | Actual Noise: 0.123 | Predicted Text: 962 | Actual Text: 962 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.6 | Actual Noise: 0.608 | Predicted Text: 87232 | Actual Text: 87232 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.777 | Actual Noise: 0.785 | Predicted Text: 229 | Actual Text: 229 | Correct: 3
# use_train = False AVG Noise Difference: 0.01868049404916337 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:39/39= 1.0
# loss at epoch 126 is 16891169106362.383
# loss at epoch 127 is 16907068873729.635
# loss at epoch 128 is 17046341801836.57
# loss at epoch 129 is 16667577128891.201
# loss at epoch 130 is 16992044861181.123
# use_train = True AVG Noise Difference: 0.022793737032853763 Total correct: 9767 accuracy:9767/10000= 0.9767 char_accuracy:39911/40153= 0.9939730530719996
# use_train = False AVG Noise Difference: 0.024744607967525818 Total correct: 978 accuracy:978/1000= 0.978 char_accuracy:4035/4057= 0.9945772738476707
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.17 | Actual Noise: 0.117 | Predicted Text: 7475 | Actual Text: 7475 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.542 | Actual Noise: 0.547 | Predicted Text: 3947 | Actual Text: 3947 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.644 | Actual Noise: 0.631 | Predicted Text: 52840 | Actual Text: 52840 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.829 | Actual Noise: 0.878 | Predicted Text: 9691 | Actual Text: 9691 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.142 | Actual Noise: 0.025 | Predicted Text: 6330 | Actual Text: 6330 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.914 | Actual Noise: 0.97 | Predicted Text: 52596 | Actual Text: 52596 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.283 | Actual Noise: 0.29 | Predicted Text: 3450 | Actual Text: 3450 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.785 | Actual Noise: 0.793 | Predicted Text: 467 | Actual Text: 467 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.342 | Actual Noise: 0.335 | Predicted Text: 465 | Actual Text: 465 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.815 | Actual Noise: 0.838 | Predicted Text: 00947 | Actual Text: 00947 | Correct: 5
# use_train = False AVG Noise Difference: 0.03398634927901101 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:41/41= 1.0
# saving model to branches-1-no-var-no-tanh_model.pt...
# saving optimizer states to branches-1-no-var-no-tanh_optim.pt...
# saving pyro pram store states to branches-1-no-var-no-tanh_param_store.pt...
# done saving checkpoints to disk.
# loss at epoch 131 is 16773706079666.188
# loss at epoch 132 is 16894518548561.912
# loss at epoch 133 is 17248489712038.713
# loss at epoch 134 is 16673028216868.04
# loss at epoch 135 is 16794175346933.752
# use_train = True AVG Noise Difference: 0.02272615022376509 Total correct: 9688 accuracy:9688/10000= 0.9688 char_accuracy:39832/40153= 0.9920055786616193
# use_train = False AVG Noise Difference: 0.023400068171956896 Total correct: 963 accuracy:963/1000= 0.963 char_accuracy:3950/3987= 0.9907198394783044
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.703 | Actual Noise: 0.711 | Predicted Text: 507 | Actual Text: 507 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.658 | Actual Noise: 0.648 | Predicted Text: 81013 | Actual Text: 81013 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.562 | Actual Noise: 0.565 | Predicted Text: 433 | Actual Text: 433 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.349 | Actual Noise: 0.347 | Predicted Text: 74903 | Actual Text: 74903 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.154 | Actual Noise: 0.052 | Predicted Text: 47254 | Actual Text: 47254 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.556 | Actual Noise: 0.541 | Predicted Text: 23900 | Actual Text: 23900 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.547 | Actual Noise: 0.518 | Predicted Text: 8454 | Actual Text: 8454 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.721 | Actual Noise: 0.719 | Predicted Text: 09503 | Actual Text: 09503 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.745 | Actual Noise: 0.754 | Predicted Text: 52253 | Actual Text: 52253 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.319 | Actual Noise: 0.317 | Predicted Text: 820 | Actual Text: 820 | Correct: 3
# use_train = False AVG Noise Difference: 0.018004049047996074 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:43/43= 1.0
# loss at epoch 136 is 16681238342985.314
# loss at epoch 137 is 16625832072472.16
# loss at epoch 138 is 16664869484127.844
# loss at epoch 139 is 16653766599455.55
# loss at epoch 140 is 16821951006493.912
# use_train = True AVG Noise Difference: 0.023502875891173846 Total correct: 9759 accuracy:9759/10000= 0.9759 char_accuracy:39904/40153= 0.9937987198963962
# use_train = False AVG Noise Difference: 0.022833285463646075 Total correct: 970 accuracy:970/1000= 0.97 char_accuracy:3990/4021= 0.9922904750062174
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.596 | Actual Noise: 0.599 | Predicted Text: 05629 | Actual Text: 05629 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.144 | Actual Noise: 0.045 | Predicted Text: 8612 | Actual Text: 8612 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.344 | Actual Noise: 0.368 | Predicted Text: 750 | Actual Text: 750 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.336 | Actual Noise: 0.347 | Predicted Text: 6525 | Actual Text: 6525 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.157 | Actual Noise: 0.094 | Predicted Text: 3567 | Actual Text: 3567 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.929 | Actual Noise: 0.951 | Predicted Text: 543 | Actual Text: 543 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.663 | Actual Noise: 0.681 | Predicted Text: 953 | Actual Text: 953 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.215 | Actual Noise: 0.231 | Predicted Text: 36937 | Actual Text: 36937 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.212 | Actual Noise: 0.219 | Predicted Text: 42918 | Actual Text: 42918 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.862 | Actual Noise: 0.881 | Predicted Text: 42297 | Actual Text: 42297 | Correct: 5
# use_train = False AVG Noise Difference: 0.028067924045445957 Total correct: 10 accuracy:10/10= 1.0 char_accuracy:41/41= 1.0
# saving model to branches-1-no-var-no-tanh_model.pt...
# saving optimizer states to branches-1-no-var-no-tanh_optim.pt...
# saving pyro pram store states to branches-1-no-var-no-tanh_param_store.pt...
# done saving checkpoints to disk.
# loss at epoch 141 is 16715244015203.13
# loss at epoch 142 is 16442332027558.31
# loss at epoch 143 is 16400843381879.613
# loss at epoch 144 is 16447482383571.348
# loss at epoch 145 is 16552654180699.322
# use_train = True AVG Noise Difference: 0.021393281253690253 Total correct: 9751 accuracy:9751/10000= 0.9751 char_accuracy:39899/40153= 0.9936741961995368
# use_train = False AVG Noise Difference: 0.02205312139291376 Total correct: 981 accuracy:981/1000= 0.981 char_accuracy:3985/4005= 0.9950062421972534
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.678 | Actual Noise: 0.667 | Predicted Text: 719 | Actual Text: 719 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.912 | Actual Noise: 0.939 | Predicted Text: 2075 | Actual Text: 2775 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.862 | Actual Noise: 0.889 | Predicted Text: 015 | Actual Text: 015 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.66 | Actual Noise: 0.649 | Predicted Text: 08554 | Actual Text: 08554 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.743 | Actual Noise: 0.712 | Predicted Text: 624 | Actual Text: 624 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.239 | Actual Noise: 0.23 | Predicted Text: 4715 | Actual Text: 4715 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.875 | Actual Noise: 0.903 | Predicted Text: 63382 | Actual Text: 63382 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.152 | Actual Noise: 0.075 | Predicted Text: 358 | Actual Text: 358 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.572 | Actual Noise: 0.558 | Predicted Text: 8605 | Actual Text: 8605 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.143 | Actual Noise: 0.044 | Predicted Text: 5588 | Actual Text: 5588 | Correct: 4
# use_train = False AVG Noise Difference: 0.033699190749330955 Total correct: 9 accuracy:9/10= 0.9 char_accuracy:37/38= 0.9736842105263158
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-d63488936a16> in <module>
#     112
#     113
# --> 114 optimize(1, USE_CUDA)
#     115 test_cycle(USE_CUDA)
#
# <ipython-input-12-b59d7394cb9e> in optimize(start_epoch, use_cuda)
#      21     print("Optimizing...")
#      22     for t in range(start_epoch, num_steps + 1):
# ---> 23         L = inference(t, use_cuda)
#      24         loss_sequence.append(L)
#      25         if (t % pause == 0) and (t > 0):
#
# <ipython-input-10-6b4856846cff> in inference(t, use_cuda)
#      13             img = img.cuda()
#      14         IMG = {"captcha" : img}
# ---> 15         imme_loss = csis.step(observations=IMG)
#      16         loss += imme_loss / length
#      17
#
# ~\anaconda3\lib\site-packages\pyro\infer\csis.py in step(self, *args, **kwargs)
#      70         """
#      71         with poutine.trace(param_only=True) as param_capture:
# ---> 72             loss = self.loss_and_grads(True, None, *args, **kwargs)
#      73
#      74         params = set(site["value"].unconstrained()
#
# ~\anaconda3\lib\site-packages\pyro\infer\csis.py in loss_and_grads(self, grads, batch, *args, **kwargs)
#     116                 # for guide_param in guide_params:
#     117                 #     logging.error(str(guide_param.shape))
# --> 118                 guide_grads = torch.autograd.grad(particle_loss, guide_params, allow_unused=True)
#     119                 # logging.error(str(type(guide_grads)))
#     120                 # logging.error(str(len(guide_grads)))
#
# ~\anaconda3\lib\site-packages\torch\autograd\__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     200         retain_graph = create_graph
#     201
# --> 202     return Variable._execution_engine.run_backward(
#     203         outputs, grad_outputs_, retain_graph, create_graph,
#     204         inputs, allow_unused)
#
# KeyboardInterrupt:
