# %% [markdown]
# uncomment if executing in google colab

# %%
# ! pip uninstall pyro-ppl
# ! pip install pyro-ppl==1.5.1
# ! unzip fonts.zip 
# ! unzip claptchagen.zip
# ! unzip csis
# ! cp csis.py /usr/local/lib/python3.7/dist-packages/pyro/infer

# %%
import random
import string
import os
import torch.nn as nn
import torch
import torch.nn.functional as F
import pyro
import numpy as np
import pyro.optim as optim
import pyro.distributions as dist
import pyro.infer
import pyro.optim

from torch.autograd import Variable
from pyro.infer import SVI, Trace_ELBO, TraceGraph_ELBO
from PIL import Image
from claptchagen.claptcha import Claptcha
from torch.distributions import constraints
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import matplotlib.pyplot as plt
print(pyro.__version__)

captcha_folder = 'generated_captchas'
captchaHeight = 32
captchaWidth = 100
captchaMarginX = 4
captchaMarginY = 4
batch_size = 10

#char_dict = string.ascii_lowercase
char_dict = string.digits
#char_dict = "abc"
USE_CUDA = True
MAX_N = 5 # maximum number of letters in a captcha 
MIN_N = 3 # minimum number of letters in a captcha
MIN_NOISE = 0.01 # minimum noise
MAX_NOISE = 0.99 # maximum noise
smoke_test = False
num_steps = 200 if not smoke_test else 10
TrainingSample = 10000 if not smoke_test else 100 # number of captchas generated for training

def randomString():
    """
    return a string with <num_char> random letters
    """
    k = random.randint(MIN_N, MAX_N) # sample number of characters
    
    rndLetters = (random.choice(char_dict) for _ in range(k))
    
    pad_spaces = MAX_N - k # pad the string so the captcha is close to center
    space = " " * (pad_spaces // 2)
    
    return space + "".join(rndLetters) + space

def ramdomNoise():
    """
    return a float between MIN_NOISE, MAX_NOISE
    """
    return random.uniform(MIN_NOISE, MAX_NOISE)

def generate_random_captcha(n, save=False):
    """
    generate n random captchas,
    return a list of texts on the captchas
    """
    # Initialize Claptcha object with random text, FreeMono as font, of size
    # 100x30px, using bicubic resampling filter and adding a bit of white noise
    c = Claptcha(randomString, "fonts/FreeSans.ttf", (captchaWidth, captchaHeight), (captchaMarginX, captchaMarginY),
             resample=Image.BILINEAR, noise=0)
    captcha_generated = [ [] for i in range(MAX_N)]
    for i in range(n):
        c.noise = ramdomNoise()
        if save:
            text, _ = c.write(os.path.join(captcha_folder, 'captcha{}.png'.format(i)))
            os.rename(os.path.join(captcha_folder, 'captcha{}.png'.format(i)),os.path.join(captcha_folder, '{}.png'.format(text + "_" + str(i))))
        text, image = c.image
        text = text.strip()
        image = np.array(image)[:, :, 0] # the generator is gray scale, only keep one channel is enough
        captcha_generated[len(text) - 1].append((text, image, c.noise))
    return captcha_generated
    
captcha_generated = generate_random_captcha(TrainingSample, save=False)
for lst in captcha_generated:
    print("number of samples in group", len(lst))
    # print some sample captcha information generated
    for i, t in enumerate(lst):
        print("text", t[0], "captcha shape", t[1].shape, "noise", t[2])
        if i >= 10:
            break
# Out:
# 1.5.1
# number of samples in group 0
# number of samples in group 0
# number of samples in group 3342
# text 913 captcha shape (32, 100) noise 0.6418915706609779
# text 580 captcha shape (32, 100) noise 0.03427519853262102
# text 181 captcha shape (32, 100) noise 0.5991810857972669
# text 135 captcha shape (32, 100) noise 0.22458789803738302
# text 869 captcha shape (32, 100) noise 0.12967867687197704
# text 227 captcha shape (32, 100) noise 0.42541953684879175
# text 865 captcha shape (32, 100) noise 0.3845370790928689
# text 622 captcha shape (32, 100) noise 0.9244151354939266
# text 069 captcha shape (32, 100) noise 0.9436542944772176
# text 576 captcha shape (32, 100) noise 0.19621218539443505
# text 752 captcha shape (32, 100) noise 0.036052930492667466
# number of samples in group 3302
# text 1686 captcha shape (32, 100) noise 0.1294690479318104
# text 8122 captcha shape (32, 100) noise 0.30904564040506466
# text 2837 captcha shape (32, 100) noise 0.9369222637371468
# text 7945 captcha shape (32, 100) noise 0.7771507871584958
# text 6138 captcha shape (32, 100) noise 0.9859718523607185
# text 0073 captcha shape (32, 100) noise 0.19375860496169323
# text 7901 captcha shape (32, 100) noise 0.3629472901892285
# text 2253 captcha shape (32, 100) noise 0.951894942614558
# text 9103 captcha shape (32, 100) noise 0.7159333910853654
# text 9751 captcha shape (32, 100) noise 0.8796492118016555
# text 2792 captcha shape (32, 100) noise 0.02661062982596195
# number of samples in group 3356
# text 77314 captcha shape (32, 100) noise 0.46747621659428146
# text 81516 captcha shape (32, 100) noise 0.38850660432536804
# text 30926 captcha shape (32, 100) noise 0.6654611201840721
# text 00159 captcha shape (32, 100) noise 0.6003615961155798
# text 50923 captcha shape (32, 100) noise 0.10049284911893491
# text 94680 captcha shape (32, 100) noise 0.4004310443202268
# text 52753 captcha shape (32, 100) noise 0.7574012366487993
# text 33469 captcha shape (32, 100) noise 0.7679081797879637
# text 31074 captcha shape (32, 100) noise 0.16644175080422513
# text 56024 captcha shape (32, 100) noise 0.16674948403535586
# text 79264 captcha shape (32, 100) noise 0.9201362718191184

# %%
def render_image(chars, fonts="fonts/FreeSans.ttf", size=(captchaWidth, captchaHeight), 
                 margin=(captchaMarginX, captchaMarginY), resample=Image.BILINEAR, noise=0.3, use_cuda=False):
    #noise = noise.data.item()
    #print(chars, noise)
    pad_spaces = MAX_N - len(chars)
    space = " " * (pad_spaces // 2)
    chars = space + chars + space
    render = Claptcha(chars, fonts, size, margin, resample=resample, noise=noise)

    
    _ , rendered_image = render.image
    rendered_image = np.array(rendered_image)[:,:,0] # the generator is gray scale, only keep one channel is enough
    rendered_image = np.subtract(np.divide(rendered_image, 255), 0.5)
    rendered_image = torch.from_numpy(rendered_image)
    if use_cuda:
        rendered_image = rendered_image.cuda()
    return rendered_image

# %%
class CaptchaDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, raw_captchas, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.raw_captchas = raw_captchas
        self.transform = transform

    def __len__(self):
        return len(self.raw_captchas)

    def __getitem__(self, idx):
        label = self.raw_captchas[idx][0]
        image = self.raw_captchas[idx][1]
        noise = self.raw_captchas[idx][2]
        
        image = np.subtract(np.divide(image, 255), 0.5)
        image = torch.from_numpy(image).float()

        if self.transform:
            image = self.transform(image)

        return label, image, noise

# %%
def make_loarders(BATCH_SIZE, raw_samples):
    dataloaders = [] # dataloaders for different num of char
    for lst in raw_samples:
        if lst:
            ds = CaptchaDataset(lst)
            dataloader = DataLoader(ds, batch_size=BATCH_SIZE,
                                    shuffle=True, num_workers=0, drop_last=True)
            dataloaders.append(dataloader)
    return dataloaders

def make_batches(dataloaders):
    all_batches = []
    for dl in dataloaders:
        for i_batch, sample in enumerate(dl):
            all_batches.append(sample)
    random.shuffle(all_batches)
    random.shuffle(all_batches)
    return all_batches

TrainLoaders = make_loarders(BATCH_SIZE=batch_size, raw_samples=captcha_generated)

# %%
class NoiseNet(nn.Module):

    def __init__(self, img_size, out_size = 1):
        """
        Network for learning noise in a captcha
        """
        super(NoiseNet, self).__init__()
        
        self.img_size = img_size
        self.fc0 = nn.Linear(img_size[0] * img_size[1], img_size[0] * img_size[1])
        self.fc1 = nn.Linear(img_size[0] * img_size[1], 1024)

        self.fc21 = nn.Linear(1024, out_size)
        self.fc22 = nn.Linear(1024, out_size)
        self.softplus = nn.Softplus()
    
    def forward(self, img):
        img = img.reshape(-1, self.img_size[0] * self.img_size[1])
        hidden = F.relu(self.fc0(img))
        hidden = self.fc1(hidden)
        # mean of noise, used in normal distribution
        mean =  torch.tanh(self.fc21(F.relu(hidden)))
        # std used in normal distribution
        sigma = self.softplus(self.fc22(F.relu(hidden)))
        return mean, sigma

# %%
class NumNet(nn.Module):
    def __init__(self, img_size, out_size = 3):
        """
        Network for learning N, number of letters in a captcha
        """
        super(NumNet, self).__init__()
        self.neural_net = nn.Sequential(
            nn.Linear(img_size[0] * img_size[1], img_size[0] * img_size[1] * 2),
            nn.ReLU(),
            nn.Linear(img_size[0] * img_size[1] * 2, 256),
            nn.ReLU(),
            nn.Linear(256, out_size),
            nn.LogSoftmax(dim=1))
  
    def forward(self, img):
        img = torch.reshape(img, (img.shape[0], img.shape[1] * img.shape[2]))
        prob = self.neural_net(img)
        return prob

# %%
class CharNetSingle(nn.Module):
    def __init__(self, img_size, output_size, hidden_size=512, N_num_class=10, input_size=1024, num_layers=1):
        """
        Network for letters in a captcha, given the noise and number of letters
        """
        super(CharNetSingle, self).__init__()
        self.img_size = img_size
        self.N_num_class = N_num_class
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.input_size = input_size
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, nonlinearity='relu', dropout=0.2)
        
        # output proposal layers
        self.linear_layers = nn.ModuleList([nn.Linear(hidden_size, output_size) for i in range(N_num_class)])

        #self.dropout = nn.Dropout()
        
        # observe layers
        self.conv1 = nn.Conv2d(1, 32, 3)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.pfc1 = nn.Linear(8832, 2048)
        self.pfc2 = nn.Linear(2048, 1024)
        self.convBN1 = nn.BatchNorm2d(32)
        self.convBN2 = nn.BatchNorm2d(64)
        self.h_0 = nn.Parameter(torch.zeros(self.num_layers, 1, self.hidden_size))
        #self.c_0 = nn.Parameter(torch.zeros(self.num_layers, 1, self.hidden_size)) # define if use LSTM

    def forward(self, img, N, noise_batched):
        BATCH_SIZE = img.shape[0]
        i = torch.arange(0, int(N))
        if USE_CUDA:
            i = i.cuda()
        i_onehot = F.one_hot(i, num_classes=self.N_num_class).float() # one hot format of N and index of letter
        i_onehot = torch.reshape(i_onehot, (N, 1, self.N_num_class)).repeat(1, BATCH_SIZE, 1)
        N_onehot = F.one_hot(N-1, num_classes=self.N_num_class).repeat(N, BATCH_SIZE, 1).float()
        
        # observe layers
        img = torch.reshape(img, (BATCH_SIZE, 1, self.img_size[0], self.img_size[1]))

        img = self.pool(F.relu(self.convBN1(self.conv1(img))))
        img = self.pool(F.relu(self.convBN2(self.conv2(img))))
        
        img = torch.reshape(img, (BATCH_SIZE, 8832))

        img = F.relu(self.pfc1(img))
        
        img = F.relu(self.pfc2(img))
        
        img = torch.reshape(img, (1, BATCH_SIZE, 1024))
        
        img = img.repeat(N, 1, 1)
        
        # cat observed images, N, i and noise 
        noise_batched = noise_batched.repeat(N, 1, 1)

        x = torch.cat((img, N_onehot, i_onehot, noise_batched), dim=2)
        x = torch.reshape(x, (N, BATCH_SIZE, self.input_size))

        h_0_contig = self.h_0.expand(self.num_layers, BATCH_SIZE, self.hidden_size).contiguous()
        #c_0_contig = self.c_0.expand(self.num_layers, BATCH_SIZE, self.hidden_size).contiguous()

        outputs, hn = self.rnn(x, h_0_contig)
        
        # probosal layer, map to output shape
        outputs = torch.stack([self.linear_layers[i](outputs[i]) for i in range(outputs.shape[0])])

        outputs = F.log_softmax(outputs, dim=2)
        
        # transpose to <Batch, Length of Sequence, Character Space>
        outputs = torch.transpose(outputs, 0, 1)
        
        return outputs

# %%
def inference(t, use_cuda=False):
    """
    one epoch of inference (iterate the training set once)
    """
    loss = 0
    length = TrainingSample
    loss_group = []
    all_batches = make_batches(TrainLoaders)
    for i_batch, sample_batched in enumerate(all_batches):
        
        img = sample_batched[1]
        if use_cuda:
            img = img.cuda()
        IMG = {"captcha" : img}
        imme_loss = csis.step(observations=IMG)
        loss += imme_loss / length

    print("loss at epoch {} is {}".format(t, loss))
    return loss

# %%
def test(n = 0, use_train=False, verbose=False, use_cuda=False):
    """
    benchmarking performance on customized or training set
    """
    if use_train:
        TestLoaders = make_loarders(BATCH_SIZE=1, raw_samples=captcha_generated)
    else:
        test_captcha_generated = generate_random_captcha(n, save=False)
        TestLoaders = make_loarders(BATCH_SIZE=1, raw_samples=test_captcha_generated)
    
    total_correct = 0
    char_correct = 0
    total_char = 0
    all_batches = make_batches(TestLoaders)
    for i_batch, t in enumerate(all_batches):

        label = t[0][0]
        gt_noise = t[2][0]
        img = t[1]

        if use_cuda:
            img = img.cuda()
        
        IMG = {"captcha" : img}
        
        posterior = csis.run(observations=IMG)
        marginal_num = pyro.infer.EmpiricalMarginal(posterior, "num_char")
        marginal_noise = pyro.infer.EmpiricalMarginal(posterior, "noise"))
        with torch.no_grad():

            N_index = marginal_num()
            N = N_index + captchaModel.num_char_domain[0]
            noise = captchaModel._map_to_noise_range(marginal_noise()[0])
            sampled_chars = []
            
            # sample characters one by one
            for i in range(N):
                marginal_char = pyro.infer.EmpiricalMarginal(posterior, "char_{}".format(i))()[0]
                if use_cuda:
                    marginal_char.cpu()
                sampled_chars.append(marginal_char)
        
        chars = ""
        for i in range(len(sampled_chars)):
            c = sampled_chars[i]
            chars +=  captchaModel.char_dict[c]
        correct = 0
        
        for p_char, t_char in zip(chars, label):
            if p_char == t_char:
                correct += 1
        if not verbose:
            print("N_predicted:", int(N), "| Actual N:", len(label), "| Predicted Noise:", round(float(noise), 3), "| Actual Noise:", round(float(gt_noise), 3), "| Predicted Text:", chars, "| Actual Text:", label, "| Correct:", correct)
        if correct == len(label) and int(N) == len(label):
            total_correct += 1
        char_correct += correct
        total_char += len(label)
    num_test_samples = i_batch + 1
    accuracy = total_correct / num_test_samples
    char_accuracy = char_correct / total_char
    print("use_train =", use_train, "Total correct:", total_correct, "accuracy:{}/{}=".format(total_correct, num_test_samples), accuracy, "char_accuracy:{}/{}=".format(char_correct, total_char), char_accuracy)

# %%
def test_cycle(use_cuda):
    
    # disable dropout
    #captchaModel.numNet.eval()
    #captchaModel.charNetSingle.eval()
    test(use_train=True, verbose=True, use_cuda=use_cuda)
    test(1000, use_train=False, verbose=True, use_cuda=use_cuda)
    #test(10, use_train=True, verbose=False, use_cuda=use_cuda)
    test(10, use_train=False, verbose=False, use_cuda=use_cuda)
    # enable dropout
    #captchaModel.numNet.train()
    #captchaModel.charNetSingle.train()

def optimize(use_cuda=False):
    """
    Training/Inferencing Stage
    """
    loss_sequence = []
    pause = 5
    print("Optimizing...")
    for t in range(1, num_steps + 1):
        L = inference(t, use_cuda)
        loss_sequence.append(L)
        if (t % pause == 0) and (t > 0):
            test_cycle(use_cuda=use_cuda)
    plt.plot(loss_sequence)
    plt.title("loss")
    plt.show()

# %%
class CaptchaModel(nn.Module):
    """
    network, model and guide wrapper class
    """
    def __init__(self, use_cuda=False):
        super().__init__()
        self.num_char_domain = torch.arange(MIN_N, MAX_N + 1)
        if use_cuda:
            self.num_char_domain = self.num_char_domain.cuda()

        self.numNet = NumNet((captchaHeight, captchaWidth), len(self.num_char_domain))
        self.noiseNet = NoiseNet((captchaHeight, captchaWidth), 1)
        self.char_dict = char_dict # letter dictionary
        self.rnn_hidden_size = 512
        self.rnn_num_layer = 2
        self.charNetSingle = CharNetSingle((captchaHeight, captchaWidth), len(self.char_dict), N_num_class=max(self.num_char_domain), input_size=1024 + max(self.num_char_domain) * 2 + 1, hidden_size=self.rnn_hidden_size, num_layers=self.rnn_num_layer)
        self.noise_constraint = torch.distributions.constraints.interval(MIN_NOISE, MAX_NOISE)
        if use_cuda:
            self.cuda()
        self.use_cuda = use_cuda
    
    def _map_to_noise_range(self, input):
        """
        map input number to the valid noise range
        """
        input = torch.distributions.transform_to(self.noise_constraint)(input)
        return input

    def guide(self, observations={"captcha": torch.rand(1, captchaHeight, captchaWidth)}):
        pyro.module("guide", self)
        img = observations["captcha"].float()
        
        # posterior to the number of letters
        prob = self.numNet(img)
        prob = torch.mean(prob, dim=0)
        N_index = pyro.sample("num_char", dist.Categorical(prob))
        N_index = torch.add(N_index, self.num_char_domain[0])
        
        with pyro.plate("data", img.shape[0]):
            
            # posterior to the noise
            noise_mean, noise_sig = self.noiseNet(img)
            noise_batch = pyro.sample("noise", dist.Normal(noise_mean, noise_sig).to_event(1))
            noise_batch = self._map_to_noise_range(noise_batch)
            
            # posterior to the characters, given number of letters and noise
            charP = self.charNetSingle(img, N_index, noise_batch)
            for i in range(N_index):
                pyro.sample("char_{}".format(i), dist.Categorical(charP[:, i, :]).to_event(0))
    
    def model(self, observations={"captcha": torch.rand(1, captchaHeight, captchaWidth)}):
        
        BS = observations["captcha"].shape[0]
        
        num_p = torch.tensor(1 / len(self.num_char_domain)).repeat(len(self.num_char_domain))
        
        if self.use_cuda:
            num_p = num_p.cuda()
        
        # sample the number of characters
        N_index = pyro.sample("num_char", dist.Categorical(num_p))
        N_index = torch.add(N_index,  self.num_char_domain[0])
        
        with pyro.plate("data", BS):
            
            noise_mean = torch.tensor((MAX_NOISE - MIN_NOISE) / 2).repeat((BS, 1))
            noise_sig = torch.tensor(0.5).repeat((BS, 1))

            if self.use_cuda:
                noise_mean = noise_mean.cuda()
                noise_sig = noise_sig.cuda()

            # sample the noise
            noise_batch = pyro.sample("noise", dist.Normal(noise_mean, noise_sig).to_event(1))
            noise_batch = self._map_to_noise_range(noise_batch)
            
            sampled_c = []
            for i in range(int(N_index)):
                num_c_i = torch.tensor(1 / len(self.char_dict)).repeat((BS, len(self.char_dict)))
                if self.use_cuda:
                    num_c_i = num_c_i.cuda()
                c_i = pyro.sample("char_{}".format(i), dist.Categorical(num_c_i).to_event(0))
                sampled_c.append(c_i)
            
            # sample the character indices
            #c = pyro.sample("chars", dist.Categorical(num_c).to_event(1)) # maybe 2 here
            rendered_images = []
            for i in range(sampled_c[0].shape[0]):
                chars = ""
                for j in range(N_index):
                    #print("sampled_c[%d][%d]" %(j, i), sampled_c[j][i])
                    chars += self.char_dict[sampled_c[j][i]]
        
                rendered_image = render_image(chars, noise=float(noise_batch[i]), use_cuda=self.use_cuda)
                rendered_images.append(rendered_image)
                
        rendered_images = torch.stack(rendered_images)
        sigma = torch.tensor(0.000001)
        if self.use_cuda:
                sigma = sigma.cuda()

        pyro.sample("captcha", dist.Normal(rendered_images, sigma).to_event(2), obs=observations["captcha"])

captchaModel = CaptchaModel(USE_CUDA)

optimiser = pyro.optim.Adam({'lr': 5e-5})
csis = pyro.infer.CSIS(captchaModel.model, captchaModel.guide, optimiser, num_inference_samples=1)


optimize(USE_CUDA)
test_cycle(USE_CUDA)
# Out:
# Optimizing...
# loss at epoch 1 is 7.610284799647337
# loss at epoch 2 is 5.657850939774513
# loss at epoch 3 is 4.5703999676346765
# loss at epoch 4 is 3.673549264597896
# loss at epoch 5 is 3.061004981368781
# use_train = True Total correct: 801 accuracy:801/10000= 0.0801 char_accuracy:20198/40014= 0.5047733293347328
# use_train = False Total correct: 73 accuracy:73/1000= 0.073 char_accuracy:1974/3996= 0.493993993993994
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.511 | Actual Noise: 0.51 | Predicted Text: 7392 | Actual Text: 7592 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.733 | Actual Noise: 0.986 | Predicted Text: 83546 | Actual Text: 87573 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.747 | Actual Noise: 0.652 | Predicted Text: 774 | Actual Text: 944 | Correct: 1
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.273 | Actual Noise: 0.028 | Predicted Text: 22071 | Actual Text: 23377 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.658 | Actual Noise: 0.954 | Predicted Text: 865 | Actual Text: 634 | Correct: 0
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.532 | Actual Noise: 0.543 | Predicted Text: 474 | Actual Text: 414 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.639 | Actual Noise: 0.636 | Predicted Text: 634 | Actual Text: 634 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.599 | Actual Noise: 0.645 | Predicted Text: 979 | Actual Text: 272 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.599 | Actual Noise: 0.623 | Predicted Text: 8438 | Actual Text: 8728 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.643 | Actual Noise: 0.623 | Predicted Text: 9950 | Actual Text: 0968 | Correct: 1
# use_train = False Total correct: 1 accuracy:1/10= 0.1 char_accuracy:17/37= 0.4594594594594595
# loss at epoch 6 is 2.5707121536314466
# loss at epoch 7 is 2.183129291036723
# loss at epoch 8 is 1.8614987731436259
# loss at epoch 9 is 1.5986407435435808
# loss at epoch 10 is 1.3565940435828625
# use_train = True Total correct: 2565 accuracy:2565/10000= 0.2565 char_accuracy:27814/40014= 0.6951067126505723
# use_train = False Total correct: 250 accuracy:250/1000= 0.25 char_accuracy:2768/4019= 0.6887285394376711
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.773 | Actual Noise: 0.796 | Predicted Text: 41193 | Actual Text: 49193 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.692 | Actual Noise: 0.744 | Predicted Text: 87207 | Actual Text: 87392 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.692 | Actual Noise: 0.796 | Predicted Text: 111 | Actual Text: 611 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.316 | Actual Noise: 0.144 | Predicted Text: 371 | Actual Text: 371 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.532 | Actual Noise: 0.466 | Predicted Text: 37650 | Actual Text: 73858 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.412 | Actual Noise: 0.416 | Predicted Text: 4948 | Actual Text: 4946 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.519 | Actual Noise: 0.505 | Predicted Text: 26567 | Actual Text: 16562 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.53 | Actual Noise: 0.348 | Predicted Text: 8774 | Actual Text: 9774 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.62 | Actual Noise: 0.851 | Predicted Text: 2224 | Actual Text: 2724 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.394 | Actual Noise: 0.476 | Predicted Text: 1762 | Actual Text: 8752 | Correct: 2
# use_train = False Total correct: 1 accuracy:1/10= 0.1 char_accuracy:26/42= 0.6190476190476191
# loss at epoch 11 is 1.1634638170837643
# loss at epoch 12 is 1.0004634907812513
# loss at epoch 13 is 0.8804814887711634
# loss at epoch 14 is 0.7392832857894803
# loss at epoch 15 is 0.608203025752889
# use_train = True Total correct: 4455 accuracy:4455/10000= 0.4455 char_accuracy:32186/40014= 0.8043684710351378
# use_train = False Total correct: 449 accuracy:449/1000= 0.449 char_accuracy:3217/3966= 0.8111447302067575
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.346 | Actual Noise: 0.268 | Predicted Text: 320 | Actual Text: 320 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.633 | Actual Noise: 0.605 | Predicted Text: 559 | Actual Text: 559 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.415 | Actual Noise: 0.863 | Predicted Text: 7871 | Actual Text: 7870 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.27 | Actual Noise: 0.163 | Predicted Text: 991 | Actual Text: 991 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.405 | Actual Noise: 0.444 | Predicted Text: 7704 | Actual Text: 7704 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.34 | Actual Noise: 0.275 | Predicted Text: 45717 | Actual Text: 42717 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.418 | Actual Noise: 0.901 | Predicted Text: 76191 | Actual Text: 36104 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.288 | Actual Noise: 0.112 | Predicted Text: 1337 | Actual Text: 1337 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.643 | Actual Noise: 0.614 | Predicted Text: 313 | Actual Text: 313 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.574 | Actual Noise: 0.59 | Predicted Text: 36165 | Actual Text: 36165 | Correct: 5
# use_train = False Total correct: 7 accuracy:7/10= 0.7 char_accuracy:34/39= 0.8717948717948718
# loss at epoch 16 is 0.48319364324404984
# loss at epoch 17 is 0.4374463368243531
# loss at epoch 18 is 0.3595197678890185
# loss at epoch 19 is 0.28551456606045506
# loss at epoch 20 is 0.24364760515634826
# use_train = True Total correct: 5337 accuracy:5337/10000= 0.5337 char_accuracy:33965/40014= 0.848827910231419
# use_train = False Total correct: 497 accuracy:497/1000= 0.497 char_accuracy:3384/4049= 0.8357619165225981
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.374 | Actual Noise: 0.238 | Predicted Text: 5684 | Actual Text: 4684 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.659 | Actual Noise: 0.672 | Predicted Text: 845 | Actual Text: 845 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.542 | Actual Noise: 0.542 | Predicted Text: 850 | Actual Text: 850 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.329 | Actual Noise: 0.296 | Predicted Text: 10978 | Actual Text: 10978 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.346 | Actual Noise: 0.296 | Predicted Text: 1167 | Actual Text: 3167 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.398 | Actual Noise: 0.36 | Predicted Text: 8866 | Actual Text: 8066 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.32 | Actual Noise: 0.233 | Predicted Text: 2217 | Actual Text: 2217 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.571 | Actual Noise: 0.54 | Predicted Text: 5002 | Actual Text: 5003 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.815 | Actual Noise: 0.826 | Predicted Text: 007 | Actual Text: 007 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.43 | Actual Noise: 0.451 | Predicted Text: 548 | Actual Text: 548 | Correct: 3
# use_train = False Total correct: 6 accuracy:6/10= 0.6 char_accuracy:33/37= 0.8918918918918919
# loss at epoch 21 is 0.20689065557600805
# loss at epoch 22 is 0.13167056055791027
# loss at epoch 23 is 0.08847430442324249
# loss at epoch 24 is 0.04427688371052641
# loss at epoch 25 is 0.006492394665052778
# use_train = True Total correct: 6008 accuracy:6008/10000= 0.6008 char_accuracy:35140/40014= 0.8781926325785975
# use_train = False Total correct: 596 accuracy:596/1000= 0.596 char_accuracy:3535/4038= 0.8754333828628034
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.265 | Actual Noise: 0.06 | Predicted Text: 671 | Actual Text: 671 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.387 | Actual Noise: 0.343 | Predicted Text: 1847 | Actual Text: 1847 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.474 | Actual Noise: 0.533 | Predicted Text: 7193 | Actual Text: 7193 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.7 | Actual Noise: 0.753 | Predicted Text: 76817 | Actual Text: 76817 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.599 | Actual Noise: 0.665 | Predicted Text: 1831 | Actual Text: 7931 | Correct: 2
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.344 | Actual Noise: 0.25 | Predicted Text: 873 | Actual Text: 873 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.709 | Actual Noise: 0.722 | Predicted Text: 287 | Actual Text: 287 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.681 | Actual Noise: 0.696 | Predicted Text: 5298 | Actual Text: 5298 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.3 | Actual Noise: 0.288 | Predicted Text: 80554 | Actual Text: 80654 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.446 | Actual Noise: 0.439 | Predicted Text: 6040 | Actual Text: 6049 | Correct: 3
# use_train = False Total correct: 7 accuracy:7/10= 0.7 char_accuracy:35/39= 0.8974358974358975
# loss at epoch 26 is -0.004877249835617755
# loss at epoch 27 is -0.031091312512300143
# loss at epoch 28 is -0.055259038934109384
# loss at epoch 29 is -0.12166513620153994
# loss at epoch 30 is -0.18617145654704684
# use_train = True Total correct: 6820 accuracy:6820/10000= 0.682 char_accuracy:36223/40014= 0.9052581596441246
# use_train = False Total correct: 657 accuracy:657/1000= 0.657 char_accuracy:3580/3989= 0.8974680371020306
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.676 | Actual Noise: 0.763 | Predicted Text: 9601 | Actual Text: 9601 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.779 | Actual Noise: 0.768 | Predicted Text: 9477 | Actual Text: 9477 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.306 | Actual Noise: 0.08 | Predicted Text: 55064 | Actual Text: 55054 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.63 | Actual Noise: 0.615 | Predicted Text: 7139 | Actual Text: 7139 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.275 | Actual Noise: 0.282 | Predicted Text: 6326 | Actual Text: 6326 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.639 | Actual Noise: 0.849 | Predicted Text: 3356 | Actual Text: 3356 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.908 | Actual Noise: 0.922 | Predicted Text: 8669 | Actual Text: 8628 | Correct: 2
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.74 | Actual Noise: 0.773 | Predicted Text: 2626 | Actual Text: 2626 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.304 | Actual Noise: 0.114 | Predicted Text: 61531 | Actual Text: 41531 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.293 | Actual Noise: 0.201 | Predicted Text: 364 | Actual Text: 304 | Correct: 2
# use_train = False Total correct: 6 accuracy:6/10= 0.6 char_accuracy:36/41= 0.8780487804878049
# loss at epoch 31 is -0.22829290515900033
# loss at epoch 32 is -0.27448155364332577
# loss at epoch 33 is -0.30469131148741935
# loss at epoch 34 is -0.2911376177539313
# loss at epoch 35 is -0.15557438319699143
# use_train = True Total correct: 7487 accuracy:7487/10000= 0.7487 char_accuracy:37156/40014= 0.9285749987504374
# use_train = False Total correct: 760 accuracy:760/1000= 0.76 char_accuracy:3705/3970= 0.9332493702770781
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.566 | Actual Noise: 0.563 | Predicted Text: 354 | Actual Text: 354 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.918 | Actual Noise: 0.987 | Predicted Text: 6743 | Actual Text: 6743 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.384 | Actual Noise: 0.425 | Predicted Text: 842 | Actual Text: 842 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.323 | Actual Noise: 0.914 | Predicted Text: 318 | Actual Text: 318 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.311 | Actual Noise: 0.162 | Predicted Text: 0618 | Actual Text: 0618 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.579 | Actual Noise: 0.593 | Predicted Text: 7619 | Actual Text: 7619 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.641 | Actual Noise: 0.671 | Predicted Text: 535 | Actual Text: 535 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.341 | Actual Noise: 0.271 | Predicted Text: 0412 | Actual Text: 0412 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.636 | Actual Noise: 0.668 | Predicted Text: 645 | Actual Text: 645 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.591 | Actual Noise: 0.635 | Predicted Text: 9141 | Actual Text: 9141 | Correct: 4
# use_train = False Total correct: 10 accuracy:10/10= 1.0 char_accuracy:35/35= 1.0
# loss at epoch 36 is -0.3859862484834277
# loss at epoch 37 is -0.4089109017185953
# loss at epoch 38 is -0.43321672611303885
# loss at epoch 39 is -0.4274503482787559
# loss at epoch 40 is -0.4874650433941234
# use_train = True Total correct: 7675 accuracy:7675/10000= 0.7675 char_accuracy:37378/40014= 0.9341230569300745
# use_train = False Total correct: 779 accuracy:779/1000= 0.779 char_accuracy:3730/3976= 0.9381287726358148
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.301 | Actual Noise: 0.271 | Predicted Text: 286 | Actual Text: 286 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.498 | Actual Noise: 0.948 | Predicted Text: 222 | Actual Text: 222 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.582 | Actual Noise: 0.592 | Predicted Text: 204 | Actual Text: 204 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.602 | Actual Noise: 0.601 | Predicted Text: 981 | Actual Text: 981 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.283 | Actual Noise: 0.243 | Predicted Text: 2416 | Actual Text: 2416 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.673 | Actual Noise: 0.852 | Predicted Text: 741 | Actual Text: 111 | Correct: 1
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.234 | Actual Noise: 0.028 | Predicted Text: 7868 | Actual Text: 7868 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.368 | Actual Noise: 0.316 | Predicted Text: 44850 | Actual Text: 44850 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.885 | Actual Noise: 0.848 | Predicted Text: 58282 | Actual Text: 58288 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.311 | Actual Noise: 0.164 | Predicted Text: 3162 | Actual Text: 3162 | Correct: 4
# use_train = False Total correct: 8 accuracy:8/10= 0.8 char_accuracy:34/37= 0.918918918918919
# loss at epoch 41 is -0.4814870034238991
# loss at epoch 42 is -0.4977312759312313
# loss at epoch 43 is -0.5201427244119997
# loss at epoch 44 is -0.5289944186963832
# loss at epoch 45 is -0.555047453678934
# use_train = True Total correct: 8036 accuracy:8036/10000= 0.8036 char_accuracy:37866/40014= 0.9463187884240516
# use_train = False Total correct: 770 accuracy:770/1000= 0.77 char_accuracy:3828/4080= 0.9382352941176471
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.28 | Actual Noise: 0.038 | Predicted Text: 535 | Actual Text: 535 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.78 | Actual Noise: 0.828 | Predicted Text: 431 | Actual Text: 431 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.317 | Actual Noise: 0.094 | Predicted Text: 403 | Actual Text: 403 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.703 | Actual Noise: 0.848 | Predicted Text: 34361 | Actual Text: 34361 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.067 | Actual Noise: 0.911 | Predicted Text: 8348 | Actual Text: 8348 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.736 | Actual Noise: 0.714 | Predicted Text: 812 | Actual Text: 812 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.484 | Actual Noise: 0.473 | Predicted Text: 205 | Actual Text: 205 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.319 | Actual Noise: 0.146 | Predicted Text: 481 | Actual Text: 481 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.813 | Actual Noise: 0.802 | Predicted Text: 86567 | Actual Text: 86567 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.354 | Actual Noise: 0.346 | Predicted Text: 1639 | Actual Text: 1639 | Correct: 4
# use_train = False Total correct: 10 accuracy:10/10= 1.0 char_accuracy:36/36= 1.0
# loss at epoch 46 is -0.5806172837645988
# loss at epoch 47 is -0.5810640000001269
# loss at epoch 48 is -0.5841319589612936
# loss at epoch 49 is -0.5107954706878405
# loss at epoch 50 is -0.6420548728766416
# use_train = True Total correct: 8456 accuracy:8456/10000= 0.8456 char_accuracy:38341/40014= 0.9581896336282301
# use_train = False Total correct: 817 accuracy:817/1000= 0.817 char_accuracy:3793/3992= 0.9501503006012024
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.297 | Actual Noise: 0.143 | Predicted Text: 0893 | Actual Text: 0893 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.631 | Actual Noise: 0.898 | Predicted Text: 2839 | Actual Text: 2839 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.304 | Actual Noise: 0.243 | Predicted Text: 32319 | Actual Text: 32019 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.327 | Actual Noise: 0.168 | Predicted Text: 0552 | Actual Text: 0552 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.228 | Actual Noise: 0.153 | Predicted Text: 957 | Actual Text: 957 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.687 | Actual Noise: 0.727 | Predicted Text: 9305 | Actual Text: 9305 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.347 | Actual Noise: 0.309 | Predicted Text: 7866 | Actual Text: 7866 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.607 | Actual Noise: 0.552 | Predicted Text: 284 | Actual Text: 284 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.556 | Actual Noise: 0.561 | Predicted Text: 7294 | Actual Text: 7294 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.275 | Actual Noise: 0.077 | Predicted Text: 4740 | Actual Text: 4740 | Correct: 4
# use_train = False Total correct: 9 accuracy:9/10= 0.9 char_accuracy:38/39= 0.9743589743589743
# loss at epoch 51 is -0.6622832971444587
# loss at epoch 52 is -0.6883299464978166
# loss at epoch 53 is -0.6089463384094367
# loss at epoch 54 is -0.6444508377974442
# loss at epoch 55 is -0.6772058394249366
# use_train = True Total correct: 8331 accuracy:8331/10000= 0.8331 char_accuracy:38187/40014= 0.9543409806567701
# use_train = False Total correct: 838 accuracy:838/1000= 0.838 char_accuracy:3773/3953= 0.9544649633189982
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.611 | Actual Noise: 0.613 | Predicted Text: 786 | Actual Text: 786 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.766 | Actual Noise: 0.744 | Predicted Text: 241 | Actual Text: 241 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.661 | Actual Noise: 0.741 | Predicted Text: 1801 | Actual Text: 1801 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.736 | Actual Noise: 0.891 | Predicted Text: 239 | Actual Text: 239 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.253 | Actual Noise: 0.011 | Predicted Text: 70793 | Actual Text: 70793 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.313 | Actual Noise: 0.295 | Predicted Text: 597 | Actual Text: 597 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.361 | Actual Noise: 0.315 | Predicted Text: 85093 | Actual Text: 85090 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.397 | Actual Noise: 0.324 | Predicted Text: 37589 | Actual Text: 37589 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.293 | Actual Noise: 0.031 | Predicted Text: 0683 | Actual Text: 0683 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.287 | Actual Noise: 0.139 | Predicted Text: 81101 | Actual Text: 81101 | Correct: 5
# use_train = False Total correct: 9 accuracy:9/10= 0.9 char_accuracy:39/40= 0.975
# loss at epoch 56 is -0.7168664107565466
# loss at epoch 57 is -0.7293058935430086
# loss at epoch 58 is -0.733426526872369
# loss at epoch 59 is -0.7629986338918556
# loss at epoch 60 is -0.7678954664339618
# use_train = True Total correct: 8648 accuracy:8648/10000= 0.8648 char_accuracy:38564/40014= 0.9637626830609287
# use_train = False Total correct: 884 accuracy:884/1000= 0.884 char_accuracy:3904/4027= 0.9694561708467843
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.678 | Actual Noise: 0.77 | Predicted Text: 052 | Actual Text: 052 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.885 | Actual Noise: 0.895 | Predicted Text: 59669 | Actual Text: 59669 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.316 | Actual Noise: 0.106 | Predicted Text: 29795 | Actual Text: 29795 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.564 | Actual Noise: 0.571 | Predicted Text: 8424 | Actual Text: 8424 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.272 | Actual Noise: 0.24 | Predicted Text: 70211 | Actual Text: 70211 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.284 | Actual Noise: 0.146 | Predicted Text: 973 | Actual Text: 973 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.362 | Actual Noise: 0.346 | Predicted Text: 91573 | Actual Text: 91573 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.546 | Actual Noise: 0.549 | Predicted Text: 1580 | Actual Text: 1580 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.584 | Actual Noise: 0.56 | Predicted Text: 5180 | Actual Text: 5180 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.793 | Actual Noise: 0.865 | Predicted Text: 18199 | Actual Text: 18199 | Correct: 5
# use_train = False Total correct: 10 accuracy:10/10= 1.0 char_accuracy:43/43= 1.0
# loss at epoch 61 is -0.7944648528155874
# loss at epoch 62 is -0.8070714939678519
# loss at epoch 63 is -0.7887925846186785
# loss at epoch 64 is -0.8021442539070326
# loss at epoch 65 is -0.8211675326622914
# use_train = True Total correct: 8789 accuracy:8789/10000= 0.8789 char_accuracy:38715/40014= 0.9675363622732044
# use_train = False Total correct: 867 accuracy:867/1000= 0.867 char_accuracy:3856/3996= 0.964964964964965
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.575 | Actual Noise: 0.569 | Predicted Text: 42323 | Actual Text: 42323 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.291 | Actual Noise: 0.233 | Predicted Text: 6477 | Actual Text: 5477 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.266 | Actual Noise: 0.164 | Predicted Text: 951 | Actual Text: 951 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.443 | Actual Noise: 0.482 | Predicted Text: 6757 | Actual Text: 6757 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.743 | Actual Noise: 0.823 | Predicted Text: 1465 | Actual Text: 1463 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.496 | Actual Noise: 0.454 | Predicted Text: 984 | Actual Text: 984 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.687 | Actual Noise: 0.756 | Predicted Text: 6721 | Actual Text: 6721 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.568 | Actual Noise: 0.547 | Predicted Text: 34076 | Actual Text: 34075 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.485 | Actual Noise: 0.888 | Predicted Text: 07970 | Actual Text: 07970 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.576 | Actual Noise: 0.589 | Predicted Text: 471 | Actual Text: 471 | Correct: 3
# use_train = False Total correct: 7 accuracy:7/10= 0.7 char_accuracy:37/40= 0.925
# loss at epoch 66 is -0.8381468804529106
# loss at epoch 67 is -0.8318732166332008
# loss at epoch 68 is -0.8509597706744564
# loss at epoch 69 is -0.8569920396649047
# loss at epoch 70 is -0.8778575845256538
# use_train = True Total correct: 8909 accuracy:8909/10000= 0.8909 char_accuracy:38854/40014= 0.971010146448743
# use_train = False Total correct: 902 accuracy:902/1000= 0.902 char_accuracy:3891/3991= 0.9749436231520922
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.633 | Actual Noise: 0.63 | Predicted Text: 235 | Actual Text: 235 | Correct: 3
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.669 | Actual Noise: 0.814 | Predicted Text: 866 | Actual Text: 866 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.751 | Actual Noise: 0.732 | Predicted Text: 7034 | Actual Text: 7034 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.324 | Actual Noise: 0.277 | Predicted Text: 71312 | Actual Text: 71312 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.24 | Actual Noise: 0.857 | Predicted Text: 88303 | Actual Text: 88303 | Correct: 5
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.304 | Actual Noise: 0.233 | Predicted Text: 27811 | Actual Text: 27811 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.746 | Actual Noise: 0.778 | Predicted Text: 258 | Actual Text: 258 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.519 | Actual Noise: 0.477 | Predicted Text: 10945 | Actual Text: 10945 | Correct: 5
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.276 | Actual Noise: 0.088 | Predicted Text: 8568 | Actual Text: 8568 | Correct: 4
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.275 | Actual Noise: 0.131 | Predicted Text: 87172 | Actual Text: 87172 | Correct: 5
# use_train = False Total correct: 10 accuracy:10/10= 1.0 char_accuracy:42/42= 1.0
# loss at epoch 71 is -0.8830493452158582
# loss at epoch 72 is -0.8804874785935131
# loss at epoch 73 is -0.9011582157790501
# loss at epoch 74 is -0.9113095532407102
# loss at epoch 75 is -0.9099011137475718
# use_train = True Total correct: 9037 accuracy:9037/10000= 0.9037 char_accuracy:38992/40014= 0.9744589393712201
# use_train = False Total correct: 895 accuracy:895/1000= 0.895 char_accuracy:3910/4020= 0.972636815920398
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.582 | Actual Noise: 0.549 | Predicted Text: 8278 | Actual Text: 8278 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.672 | Actual Noise: 0.798 | Predicted Text: 2079 | Actual Text: 2079 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.721 | Actual Noise: 0.934 | Predicted Text: 157 | Actual Text: 157 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.485 | Actual Noise: 0.488 | Predicted Text: 3000 | Actual Text: 3000 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.734 | Actual Noise: 0.804 | Predicted Text: 7612 | Actual Text: 7612 | Correct: 4
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.33 | Actual Noise: 0.255 | Predicted Text: 575 | Actual Text: 575 | Correct: 3
# N_predicted: 5 | Actual N: 5 | Predicted Noise: 0.481 | Actual Noise: 0.457 | Predicted Text: 60170 | Actual Text: 60170 | Correct: 5
# N_predicted: 3 | Actual N: 3 | Predicted Noise: 0.483 | Actual Noise: 0.488 | Predicted Text: 129 | Actual Text: 129 | Correct: 3
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.43 | Actual Noise: 0.435 | Predicted Text: 0027 | Actual Text: 0027 | Correct: 4
# N_predicted: 4 | Actual N: 4 | Predicted Noise: 0.287 | Actual Noise: 0.209 | Predicted Text: 8548 | Actual Text: 8548 | Correct: 4
# use_train = False Total correct: 10 accuracy:10/10= 1.0 char_accuracy:38/38= 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-5824fd750920> in <module>
#     114
#     115
# --> 116 optimize(USE_CUDA)
#     117 test_cycle(USE_CUDA)
#
# <ipython-input-11-13f4e1d1fa17> in optimize(use_cuda)
#      20     print("Optimizing...")
#      21     for t in range(1, num_steps + 1):
# ---> 22         L = inference(t, use_cuda)
#      23         loss_sequence.append(L)
#      24         if (t % pause == 0) and (t > 0):
#
# <ipython-input-9-6b4856846cff> in inference(t, use_cuda)
#      13             img = img.cuda()
#      14         IMG = {"captcha" : img}
# ---> 15         imme_loss = csis.step(observations=IMG)
#      16         loss += imme_loss / length
#      17
#
# ~\anaconda3\lib\site-packages\pyro\infer\csis.py in step(self, *args, **kwargs)
#      70         """
#      71         with poutine.trace(param_only=True) as param_capture:
# ---> 72             loss = self.loss_and_grads(True, None, *args, **kwargs)
#      73
#      74         params = set(site["value"].unconstrained()
#
# ~\anaconda3\lib\site-packages\pyro\infer\csis.py in loss_and_grads(self, grads, batch, *args, **kwargs)
#     103
#     104         loss = 0
# --> 105         for model_trace in batch:
#     106             with poutine.trace(param_only=True) as particle_param_capture:
#     107                 guide_trace = self._get_matched_trace(model_trace, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\pyro\infer\csis.py in <genexpr>(.0)
#      96         """
#      97         if batch is None:
# ---> 98             batch = (self._sample_from_joint(*args, **kwargs)
#      99                      for _ in range(self.training_batch_size))
#     100             batch_size = self.training_batch_size
#
# ~\anaconda3\lib\site-packages\pyro\infer\csis.py in _sample_from_joint(self, *args, **kwargs)
#     196         """
#     197         unconditioned_model = pyro.poutine.uncondition(self.model)
# --> 198         return poutine.trace(unconditioned_model).get_trace(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\pyro\poutine\trace_messenger.py in get_trace(self, *args, **kwargs)
#     185         Calls this poutine and returns its trace instead of the function's return value.
#     186         """
# --> 187         self(*args, **kwargs)
#     188         return self.msngr.get_trace()
#
# ~\anaconda3\lib\site-packages\pyro\poutine\trace_messenger.py in __call__(self, *args, **kwargs)
#     163                                       args=args, kwargs=kwargs)
#     164             try:
# --> 165                 ret = self.fn(*args, **kwargs)
#     166             except (ValueError, RuntimeError) as e:
#     167                 exc_type, exc_value, traceback = sys.exc_info()
#
# ~\anaconda3\lib\site-packages\pyro\poutine\messenger.py in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#      13
#      14
#
# <ipython-input-12-5824fd750920> in model(self, observations)
#      98                     chars += self.char_dict[sampled_c[j][i]]
#      99
# --> 100                 rendered_image = render_image(chars, noise=float(noise_batch[i]), use_cuda=self.use_cuda)
#     101                 rendered_images.append(rendered_image)
#     102
#
# <ipython-input-3-f1445ba574c5> in render_image(chars, fonts, size, margin, resample, noise, use_cuda)
#       9
#      10
# ---> 11     _ , rendered_image = render.image
#      12     rendered_image = np.array(rendered_image)[:,:,0] # the generator is gray scale, only keep one channel is enough
#      13     rendered_image = np.subtract(np.divide(rendered_image, 255), 0.5)
#
# ~\OneDrive\Documents\URA\claptchagen\claptcha\claptcha.py in image(self)
#     120
#     121         # Resize
# --> 122         image = image.resize(self.size, resample=self.resample)
#     123
#     124         return (text, image)
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in resize(self, size, resample, box, reducing_gap)
#    1933                 )
#    1934
# -> 1935         return self._new(self.im.resize(size, resample, box))
#    1936
#    1937     def reduce(self, factor, box=None):
#
# KeyboardInterrupt:
